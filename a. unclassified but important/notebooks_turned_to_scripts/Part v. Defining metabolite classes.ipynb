# %% [markdown]
# # Define classes of metabolites

# %%
from libchebipy._chebi_entity import ChebiEntity
import os
import json

import reframed
import pandas as pd
import numpy as np

import collections

# %%
import sys
sys.path.append('../functions/')

import general_functions as general_func

# %% [markdown]
# ### Load universal model

# %%
model_uni = reframed.load_cbmodel("../input/universe_bacteria.xml")

# %% [markdown]
# ### Find the best way to map exchange to classes

# %% [markdown]
# #### Get Chebi ids associated with extracellular metabolites

# %%
chebi_ids = {}
#chebi_frac = {}

all_mets_chebi =[] 

for met in model_uni.metabolites:

    if model_uni.metabolites[met].compartment=="C_e":

        #ex_met.append(met)
        if "chebi" in model_uni.metabolites[met].metadata.keys():
            #chebi_in_met.append(met)
            all_mets_chebi.append(met)
            chebi_ids[met]=model_uni.metabolites[met].metadata["chebi"]
        else:
            chebi_ids[met]=None

# %%
len(all_mets_chebi)/len(chebi_ids.keys())
# Out:
# 0.6791044776119403

# %% [markdown]
# **Find all chebi ids for the exchange reactions in all models (this also includes the ones that do not have chebi_id)**

# %%
super_dict = chebi_ids.copy()

# %%
super_dict["M_but_e"]= ['CHEBI:17968']
super_dict["M_ppa_e"] = ['CHEBI:17272']
super_dict["M_14glucan_e"]= ['CHEBI:15444']

super_dict["M_2h3mp_e"] = ['CHEBI:133085']
super_dict["M_2mba_e"] = ['CHEBI:37070']

super_dict["M_2mpa_e"] = ['CHEBI:16135']

super_dict["M_3mba_e"] =['CHEBI:28484']

super_dict["M_4abzglu_e"] =['CHEBI:60903']

super_dict["M_4hpro_DC_e"] =['CHEBI:16231']

super_dict["M_val__D_e"] =['CHEBI:27477']
super_dict["M_tyr__D_e"] = ['CHEBI:28479']

super_dict["M_leu__D_e"] = ['CHEBI:28225']
super_dict["M_isocap_e"] = ['CHEBI:74903'] # Annotated as isocaproate, but has no charge

# %%
all_mets = [met[2:-2] for met in super_dict.keys()]
len(all_mets)
# Out:
# 670

# %% [markdown]
# #### Get KEGG ids associated with extracellular metabolites

# %%
kegg_ids = {}
all_mets_kegg = []

   

for met in model_uni.metabolites:

    if model_uni.metabolites[met].compartment=="C_e":
        if "kegg.compound" in model_uni.metabolites[met].metadata.keys():
            all_mets_kegg.append(met)
            kegg_ids[met] = model_uni.metabolites[met].metadata["kegg.compound"]
        else:
            kegg_ids[met]=None

len(all_mets_kegg)/len(kegg_ids.keys())
# Out:
# 0.6447761194029851

# %% [markdown]
# #### HMDB

# %%
HMDB_classes = pd.read_csv("../input/files_from_fairdomhub/bigg_classes.tsv",sep="\t")
HMDB_classes
# Out:
#             bigg                           name  \
# 0            thm                       Thiamine
# 1       26dap__M  Meso-2,6-Diaminoheptanedioate
# 2           3cmp                          3 CMP
# 3           5mtr          5-Methylthio-D-ribose
# 4          chols                Choline sulfate
# ...          ...                            ...
# 1611  xylnact__D           D-Xylono-1,5-lactone
# 1612     xylu__D                     D-Xylulose
# 1613     xylu__L            L-Threo-2-pentulose
# 1614        zeax                     Zeaxanthin
# 1615    zym_int2      Zymosterol intermediate 2
#
#                                   super_class  \
# 0                Organoheterocyclic compounds
# 1               Organic acids and derivatives
# 2     Nucleosides, nucleotides, and analogues
# 3                      Organooxygen compounds
# 4             Homogeneous non-metal compounds
# ...                                       ...
# 1611             Organoheterocyclic compounds
# 1612                   Organooxygen compounds
# 1613                 Organic oxygen compounds
# 1614          Lipids and lipid-like molecules
# 1615          Lipids and lipid-like molecules
#
#                                           class  \
# 0                                      Diazines
# 1              Carboxylic acids and derivatives
# 2                  Ribonucleoside 3'-phosphates
# 3     Carbohydrates and carbohydrate conjugates
# 4                Non-metal oxoanionic compounds
# ...                                         ...
# 1611                                   Lactones
# 1612  Carbohydrates and carbohydrate conjugates
# 1613                     Organooxygen compounds
# 1614                              Prenol lipids
# 1615           Steroids and steroid derivatives
#
#                                       sub_class
# 0        Pyrimidines and pyrimidine derivatives
# 1          Amino acids, peptides, and analogues
# 2                  Ribonucleoside 3'-phosphates
# 3                   Sugar acids and derivatives
# 4                            Non-metal sulfates
# ...                                         ...
# 1611                       Delta valerolactones
# 1612                            Monosaccharides
# 1613  Carbohydrates and carbohydrate conjugates
# 1614                            Tetraterpenoids
# 1615                        Cholestane steroids
#
# [1616 rows x 5 columns]

# %%
HMDB_classes[HMDB_classes["bigg"].isin(all_mets)]["sub_class"].dropna().size/len(all_mets)
# Out:
# 0.5447761194029851

# %% [markdown]
# ### Overlap

# %%
chebi_mets = set([met[2:-2] for met in all_mets_chebi])
kegg_mets = set([met[2:-2] for met in all_mets_kegg])
hmdb_mets = set(HMDB_classes[HMDB_classes["bigg"].isin(all_mets)].bigg.values)

# %%
import matplotlib_venn as venn

# %%
fig =venn.venn3([chebi_mets,kegg_mets,hmdb_mets],["chebi","kegg","hmdb"])

# %% [markdown]
# ## Define substrate classes based on ChEBI
#
# It's necessary to define some classes from CHEBI that we are interested in.
#
# Strategy:
#
# - Define main classes. NB: Some compounds might fit into several classes
#     - Define a hierarchy to avoid placing some compounds in a general class
#     - Find the chebi class by recursively walking through the map.

# %%
really_large_classes = collections.OrderedDict({## Really Bigg classes
                "organonitrogen compounds":{
                    "CHEBI:35352":"organonitrogen compound"},
                "organosulfur compounds":{
                    "CHEBI:33261":"organosulfur compound"}, # from thiol CHEBI:29256
                "organophosphorus compounds":{
                    "CHEBI:25710":"organophosphorus compound"},
                "carboxylic acids and anions":{
                    "CHEBI:29067":"carboxylic acid anion",
                    "CHEBI:33575":"carboxylic acid"},
                "carbohydrate derivatives":{
                    "CHEBI:63299":"carbohydrate derivative"}
    })
large_classes = collections.OrderedDict({
                ## Bigg classes
                "alcohols and aldehydes":{
                    "CHEBI:15734": "primary alcohol",
                    "CHEBI:35681":"secondary alcohol",
                    "CHEBI:17478":"aldehyde"},


                "oligosaccharides":{
                    "CHEBI:50699":"oligosaccharide (undefined)"},
#                "lipid":{
#                    "CHEBI:18059":"lipid"
#                },
                "cofactors":{
                    "CHEBI:23357":"cofactor",
                    "CHEBI:33892":"iron coordination entity"}
                #"cofactors":{} #"CHEBI:5975":"iron chelate"
})
medium_classes = collections.OrderedDict({
                "aromatic compounds":{
                    "CHEBI:26195":"polyphenol"
                },
                "alkaloids":{
                    "CHEBI:22315":"alkaloid"
                },
                "polyamine":{
                    "CHEBI:88061":"polyamine"
                },
                "lipids":{
                    "CHEBI:16247":"phospholipid"},
                "steroid":{
                    "CHEBI:35341":"steroid"
                },
                "gases":{
                    "CHEBI:138675":"gas molecular entity"}
                
})

main_classes = collections.OrderedDict({
                "amino acids and derivatives":{
                    "CHEBI:37022":"amino-acid anion",
                    "CHEBI:33709":"amino acid",
                    "CHEBI:83821":"amino acid derivative"
},
                "oligopeptides":{                    
                    "CHEBI:25676":"oligopeptide"},
    
                "fatty acids":{
                    "CHEBI:58954":"straight-chain saturated fatty acid anion",
                    "CHEBI:58956":"branched-chain saturated fatty acid anion"},


                "carboxylic acids and anions":{
                    "CHEBI:33576":"sulfur-containing carboxylic acid"}, #From M_sulfac_e

                ## Carbohydrates
                "simple sugars":{
                    "CHEBI:35381":"monosaccharide",
                    "CHEBI:36233": "disaccharide"},
                "carbohydrate derivatives":{
                    "CHEBI:23639":"deoxy sugar",
                    "CHEBI:33720":"carbohydrate acid",# From M_galctn__L_e 
                },
                "oligosaccharides":{
                    "CHEBI:22590":"arabinan",
                    "CHEBI:37163":"glucan (undefined)"},
                "nucleotides and derivatives":{
                    "CHEBI:18282":"nucleobase", # From ura
                    "CHEBI:33838":"nucleoside",
                    "CHEBI:26401":"purines",
                    "CHEBI:39447":"pyrimidines",
                    "CHEBI:25608":"nucleoside phosphate"},
                    #"CHEBI:35241":"nucleotide-sugar",
                "B-vitamins":{
                   "CHEBI:75769": "B vitamin"},

                "other vitamins":{"CHEBI:12777":"vitamin A",
                                 "CHEBI:33234":"vitamin E",
                                 "CHEBI:27300":"vitamin D",
                                 "CHEBI:176783":"vitamin C",
                                 "CHEBI:28384":"vitamin K"},
                "inorganic ions and atoms":{
                    "CHEBI:24835":"inorganic ion",
                    "CHEBI:25585": "nonmetal atom"},

             
                "urea and urea derivatives":{
                    "CHEBI:47857":"ureas",
                    "CHEBI:16199":"urea"},
    
                "aromatic compounds":{
                    "CHEBI:33853":"phenols",
                    "CHEBI:27338": "xylene",
                    "CHEBI:27024":"toluenes"}, # From M_tol_e
                "other":{
                    "CHEBI:26191":"polyol",
                    "CHEBI:23217": "cholines",
                    "CHEBI:24828": "indoles",
                    "CHEBI:26188":"polyketide"} # Based on ttrcyc

               })

# %% [markdown]
# **Recursive function to find first parent matching with main classes**

# %%
def find_main_class(chebi_id, main_classes):
    # If chebi_id is the id of a  main class -> return value
    if chebi_id in main_classes:
        return chebi_id  

    entity = ChebiEntity(chebi_id)
    parents = [rel.get_target_chebi_id() for rel in entity.get_outgoings() if rel.get_type() == "is_a"]
    
    # If we have reached the end of the graph
    if len(parents)==0:
        return None
    
    
    for parent in parents:
        result = find_main_class(parent, main_classes)  
        if result is not None:
            return result  

    return None

# %%
met_chebi_dict = {} # previously called main_class_dict

for main_class_dict_nested in [main_classes,medium_classes,large_classes,really_large_classes]:
    main_class_dict = collections.OrderedDict()
    for d in main_class_dict_nested.values():
        for k, v in d.items():  
            main_class_dict[k]=v
    
    for met_id,chebi_list in super_dict.items():
        if chebi_list is None:
            continue
        
        if met_id in met_chebi_dict.keys():
            continue

        for chebi_id in chebi_list:
            main_class = find_main_class(chebi_id,main_class_dict.keys())
            if main_class is not None:
                met_chebi_dict[met_id]=main_class
                break

# %% [markdown]
# #### Define class chebi ids for new metabolites

# %%
iIB746 = reframed.load_cbmodel("../input/curated_models/iIB746.xml") # Make sure that this is up to date!

# %%
xylo_gluc = [rxn for rxn in iIB746.get_exchange_reactions() if "Q" in rxn and rxn.split("_")[2].isupper()]
ara_xyl = [rxn for rxn in iIB746.get_exchange_reactions() if "A" in rxn and rxn.split("_")[2].isupper()]

cellulose = [rxn for rxn in iIB746.get_exchange_reactions() if "cell" in rxn]
cellulose.append("R_EX_cell6_e")

xylan = [rxn for rxn in iIB746.get_exchange_reactions() if "xyla" in rxn]

new_classes_rxns = {"CHEBI:18233":xylo_gluc,"CHEBI:28427":ara_xyl,"CHEBI:3523":cellulose,"CHEBI:60938":xylan}

new_classes = {"oligosaccharides":{"CHEBI:60938":"glucuronoxylan","CHEBI:28427":"arabinoxylan","CHEBI:18233":"xyloglucan","CHEBI:3523":"cellodextrin"}}

# %%
for chebi_id,rxns in new_classes_rxns.items():
    for rxn in rxns:
        met_id = rxn.replace("R_EX_","M_")
        met_id = met_id.replace("EX_","M_")
        met_chebi_dict[met_id]=chebi_id

# %%
len(met_chebi_dict.keys())
# Out:
# 476

# %%
len(super_dict.keys())
# Out:
# 670

# %%
len(super_dict.keys())-len(met_chebi_dict.keys())
# Out:
# 194

# %%
set(super_dict.keys())-set(met_chebi_dict.keys())
# Out:
# {'M_12dgr160_e',
#  'M_12dgr180_e',
#  'M_13dampp_e',
#  'M_1ag160_e',
#  'M_1ag180_e',
#  'M_1ag181d9_e',
#  'M_1ag182d9d12_e',
#  'M_23dhbzs3_e',
#  'M_2h3mb_e',
#  'M_2m35mdntha_e',
#  'M_34dhphe_e',
#  'M_35dnta_e',
#  'M_3h4atb_e',
#  'M_4hphac_e',
#  'M_4hptn_e',
#  'M_4oxptn_e',
#  'M_6atha_e',
#  'M_LalaDgluMdapDala_e',
#  'M_LalaDgluMdap_e',
#  'M_R3hdec4e_e',
#  'M_R_3h4atba_e',
#  'M_R_3h6atha_e',
#  'M_R_3hcmrs7e_e',
#  'M_R_3hdcaa_e',
#  'M_R_3hdd5ea_e',
#  'M_R_3hdd6e_e',
#  'M_R_3hdda_e',
#  'M_R_3hhdca_e',
#  'M_R_3hhpa_e',
#  'M_R_3hhxa_e',
#  'M_R_3hnonaa_e',
#  'M_R_3hocta_e',
#  'M_R_3hpba_e',
#  'M_R_3hpdeca_e',
#  'M_R_3hphpa_e',
#  'M_R_3hphxa_e',
#  'M_R_3hpnona_e',
#  'M_R_3hpocta_e',
#  'M_R_3hppta_e',
#  'M_R_3hpt_e',
#  'M_R_3htd58e_e',
#  'M_R_3htd5e_e',
#  'M_R_3httdca_e',
#  'M_abg4_e',
#  'M_acetone_e',
#  'M_acysbmn_e',
#  'M_airs_e',
#  'M_ala_L_glu__L_e',
#  'M_ala_L_thr__L_e',
#  'M_ala_gln_e',
#  'M_ala_his_e',
#  'M_ala_leu_e',
#  'M_alagly_e',
#  'M_alahis_e',
#  'M_alaleu_e',
#  'M_alathr_e',
#  'M_alatrp_e',
#  'M_algac_MG_14_e',
#  'M_algac_MG_23_e',
#  'M_algac_MG_32_e',
#  'M_algac_MG_41_e',
#  'M_algac__M_e',
#  'M_anhgm_e',
#  'M_apc_e',
#  'M_araban__L_e',
#  'M_asn__D_e',
#  'M_aso4_e',
#  'M_balaala_e',
#  'M_balabala_e',
#  'M_balagly_e',
#  'M_balaleu_e',
#  'M_balamd_e',
#  'M_btd_RR_e',
#  'M_buts_e',
#  'M_butso3_e',
#  'M_carn_e',
#  'M_chtbs_e',
#  'M_cmcbtt_e',
#  'M_cpgn_un_e',
#  'M_cresol_e',
#  'M_crtn_e',
#  'M_cyan_e',
#  'M_d23hb_e',
#  'M_dachi_e',
#  'M_dag181d9_e',
#  'M_dag182d9d12_e',
#  'M_dca_e',
#  'M_ddca_e',
#  'M_dgudbutn_e',
#  'M_diact_e',
#  'M_dmanur_e',
#  'M_dmso2_e',
#  'M_dxylnt_e',
#  'M_ecto__L_e',
#  'M_fcmcbtt_e',
#  'M_fe3dcit_e',
#  'M_fe3dhbzs3_e',
#  'M_fe3dhbzs_e',
#  'M_fe3hox_un_e',
#  'M_fe3mcbtt_e',
#  'M_fe3pyovd_kt_e',
#  'M_feoxam_un_e',
#  'M_fuc_e',
#  'M_galam_e',
#  'M_galman4_e',
#  'M_galman6_e',
#  'M_glcman4_e',
#  'M_glcman6_e',
#  'M_glucan4_e',
#  'M_glucan6_e',
#  'M_gly_asn__L_e',
#  'M_gly_cys_e',
#  'M_gly_gln_e',
#  'M_gly_glu__L_e',
#  'M_gly_leu_e',
#  'M_gly_met_e',
#  'M_gly_phe_e',
#  'M_gly_pro__L_e',
#  'M_gly_tyr_e',
#  'M_glycol_e',
#  'M_glygln_e',
#  'M_glyglu_e',
#  'M_glyglygln_e',
#  'M_glymet_e',
#  'M_glyser_e',
#  'M_gudac_e',
#  'M_gudptn_e',
#  'M_h2co3_e',
#  'M_hco3_e',
#  'M_hdcea_e',
#  'M_hexs_e',
#  'M_hia_e',
#  'M_hisgly_e',
#  'M_hishis_e',
#  'M_hpta_e',
#  'M_ibtol_e',
#  'M_isobuta_e',
#  'M_istfrnA_e',
#  'M_istfrnB_e',
#  'M_ival_e',
#  'M_lysglugly_e',
#  'M_m2but_e',
#  'M_m4po_e',
#  'M_manb_e',
#  'M_mantr_e',
#  'M_manur_e',
#  'M_mbdg_e',
#  'M_mcbtt_e',
#  'M_met_L_ala__L_e',
#  'M_metglcur_e',
#  'M_metox__R_e',
#  'M_mevR_e',
#  'M_octscoa_e',
#  'M_pea_e',
#  'M_pentso3_e',
#  'M_phe__D_e',
#  'M_phedca_e',
#  'M_phehpa_e',
#  'M_phehxa_e',
#  'M_phenona_e',
#  'M_pheocta_e',
#  'M_phept_e',
#  'M_ppat_e',
#  'M_prealg_MG_14_e',
#  'M_prealg_MG_23_e',
#  'M_prealg_MG_32_e',
#  'M_prealg_MG_41_e',
#  'M_prealginate_G_e',
#  'M_pro__D_e',
#  'M_prohisglu_e',
#  'M_psuri_e',
#  'M_ptsla_e',
#  'M_pyovd_kt_e',
#  'M_salchs2_e',
#  'M_salchs2fe_e',
#  'M_salchs4_e',
#  'M_salchs4fe_e',
#  'M_salchsx_e',
#  'M_serglugly_e',
#  'M_slnt_e',
#  'M_stfrnA_e',
#  'M_stfrnB_e',
#  'M_tag160_e',
#  'M_tag180_e',
#  'M_tag181d9_e',
#  'M_tag182d9d12_e',
#  'M_tgt_e',
#  'M_tmam_e',
#  'M_tmanur_e',
#  'M_tmao_e',
#  'M_tnt_e',
#  'M_ttdca_e',
#  'M_ttdcea_e',
#  'M_vacc_e'}

# %% [markdown]
# **Coverage of all external metabolites in our model**

# %%
len(met_chebi_dict.keys())/len(super_dict.keys())
# Out:
# 0.7104477611940299

# %% [markdown]
# #### Combine data as dataframe

# %% [markdown]
# **First we need a dict to map chebi id to class and the self defined super class**

# %%
chebi_classes = collections.defaultdict(set)

for class_dict in [medium_classes,large_classes,really_large_classes,main_classes,new_classes]:
    for met_super_class_name,sub_class_dict in class_dict.items():
        
        for chebi_id, chebi_class_name in sub_class_dict.items():  

            chebi_classes[chebi_id]={"chebi class":chebi_class_name,"self defined super class":met_super_class_name}

# %% [markdown]
# **Make a df for all the metabolites we were able to classify**

# %%
met_chebi_df = pd.DataFrame(met_chebi_dict.values(),index=met_chebi_dict.keys())
met_chebi_df.columns=["chebi id"]

# %% [markdown]
# **Combine data**

# %%
met_chebi_df["chebi class"]=met_chebi_df["chebi id"].map(lambda x:chebi_classes[x]["chebi class"])
met_chebi_df["self defined super class"]=met_chebi_df["chebi id"].map(lambda x:chebi_classes[x]["self defined super class"])

# %%
met_chebi_df
# Out:
#                  chebi id           chebi class     self defined super class
# M_12ppd__R_e  CHEBI:26191                polyol                        other
# M_12ppd__S_e  CHEBI:26191                polyol                        other
# M_13ppd_e     CHEBI:26191                polyol                        other
# M_14glucan_e  CHEBI:37163    glucan (undefined)             oligosaccharides
# M_23camp_e    CHEBI:25608  nucleoside phosphate  nucleotides and derivatives
# ...                   ...                   ...                          ...
# M_cell4_e      CHEBI:3523          cellodextrin             oligosaccharides
# M_cell3_e      CHEBI:3523          cellodextrin             oligosaccharides
# M_cell6_e      CHEBI:3523          cellodextrin             oligosaccharides
# M_xylan4_e    CHEBI:60938        glucuronoxylan             oligosaccharides
# M_xylan8_e    CHEBI:60938        glucuronoxylan             oligosaccharides
#
# [476 rows x 3 columns]

# %%
met_chebi_df
# Out:
#                  chebi id           chebi class     self defined super class
# M_12ppd__R_e  CHEBI:26191                polyol                        other
# M_12ppd__S_e  CHEBI:26191                polyol                        other
# M_13ppd_e     CHEBI:26191                polyol                        other
# M_14glucan_e  CHEBI:37163    glucan (undefined)             oligosaccharides
# M_23camp_e    CHEBI:25608  nucleoside phosphate  nucleotides and derivatives
# ...                   ...                   ...                          ...
# M_cell4_e      CHEBI:3523          cellodextrin             oligosaccharides
# M_cell3_e      CHEBI:3523          cellodextrin             oligosaccharides
# M_cell6_e      CHEBI:3523          cellodextrin             oligosaccharides
# M_xylan4_e    CHEBI:60938        glucuronoxylan             oligosaccharides
# M_xylan8_e    CHEBI:60938        glucuronoxylan             oligosaccharides
#
# [476 rows x 3 columns]

# %% [markdown]
# **Add remaining compounds into 'other'**

# %%
not_in_chebi = [met for met in super_dict.keys() if met not in met_chebi_df.index.values ]

for met in not_in_chebi:
    met_chebi_df.loc[met] = [None, "not classified", "other"]

# %% [markdown]
# ### Overview

# %%
met_chebi_df["self defined super class"].value_counts()
# Out:
# self defined super class
# other                          217
# amino acids and derivatives     70
# nucleotides and derivatives     57
# carboxylic acids and anions     51
# inorganic ions and atoms        43
# carbohydrate derivatives        40
# oligosaccharides                29
# aromatic compounds              28
# simple sugars                   25
# alcohols and aldehydes          21
# organophosphorus compounds      18
# organonitrogen compounds        13
# oligopeptides                   11
# organosulfur compounds          10
# B-vitamins                       7
# fatty acids                      7
# cofactors                        6
# urea and urea derivatives        4
# polyamine                        4
# lipids                           3
# steroid                          2
# gases                            2
# alkaloids                        1
# other vitamins                   1
# Name: count, dtype: int64

# %%
met_chebi_df[met_chebi_df["self defined super class"]=="carboxylic acids and anions"]
# Out:
#                   chebi id                        chebi class  \
# M_lipoate_e    CHEBI:33576  sulfur-containing carboxylic acid
# M_sula_e       CHEBI:33576  sulfur-containing carboxylic acid
# M_sulfac_e     CHEBI:33576  sulfur-containing carboxylic acid
# M_2h3mp_e      CHEBI:29067              carboxylic acid anion
# M_2mba_e       CHEBI:33575                    carboxylic acid
# M_2mpa_e       CHEBI:33575                    carboxylic acid
# M_2obut_e      CHEBI:29067              carboxylic acid anion
# M_3hcinnm_e    CHEBI:33575                    carboxylic acid
# M_3hpppn_e     CHEBI:33575                    carboxylic acid
# M_3mba_e       CHEBI:33575                    carboxylic acid
# M_3oxoadp_e    CHEBI:29067              carboxylic acid anion
# M_4abzglu_e    CHEBI:29067              carboxylic acid anion
# M_5g2oxpt_e    CHEBI:29067              carboxylic acid anion
# M_6apa_e       CHEBI:29067              carboxylic acid anion
# M_6pgc_e       CHEBI:29067              carboxylic acid anion
# M_T4hcinnm_e   CHEBI:29067              carboxylic acid anion
# M_ac_e         CHEBI:29067              carboxylic acid anion
# M_acac_e       CHEBI:29067              carboxylic acid anion
# M_acnam_e      CHEBI:29067              carboxylic acid anion
# M_acon_C_e     CHEBI:33575                    carboxylic acid
# M_akg_e        CHEBI:29067              carboxylic acid anion
# M_but_e        CHEBI:29067              carboxylic acid anion
# M_bz_e         CHEBI:29067              carboxylic acid anion
# M_chor_e       CHEBI:29067              carboxylic acid anion
# M_cinnm_e      CHEBI:33575                    carboxylic acid
# M_cit_e        CHEBI:29067              carboxylic acid anion
# M_for_e        CHEBI:29067              carboxylic acid anion
# M_fum_e        CHEBI:29067              carboxylic acid anion
# M_glutar_e     CHEBI:29067              carboxylic acid anion
# M_hdca_e       CHEBI:33575                    carboxylic acid
# M_isocap_e     CHEBI:33575                    carboxylic acid
# M_lac__D_e     CHEBI:29067              carboxylic acid anion
# M_lac__L_e     CHEBI:29067              carboxylic acid anion
# M_lnlc_e       CHEBI:29067              carboxylic acid anion
# M_mal__D_e     CHEBI:29067              carboxylic acid anion
# M_mal__L_e     CHEBI:29067              carboxylic acid anion
# M_man6pglyc_e  CHEBI:29067              carboxylic acid anion
# M_oaa_e        CHEBI:29067              carboxylic acid anion
# M_ocdcea_e     CHEBI:33575                    carboxylic acid
# M_oxa_e        CHEBI:29067              carboxylic acid anion
# M_pac_e        CHEBI:29067              carboxylic acid anion
# M_pep_e        CHEBI:29067              carboxylic acid anion
# M_phpyr_e      CHEBI:29067              carboxylic acid anion
# M_pime_e       CHEBI:29067              carboxylic acid anion
# M_ppa_e        CHEBI:29067              carboxylic acid anion
# M_pppn_e       CHEBI:29067              carboxylic acid anion
# M_pyr_e        CHEBI:29067              carboxylic acid anion
# M_quin_e       CHEBI:29067              carboxylic acid anion
# M_skm_e        CHEBI:29067              carboxylic acid anion
# M_succ_e       CHEBI:33575                    carboxylic acid
# M_tcb_e        CHEBI:33575                    carboxylic acid
#
#                   self defined super class
# M_lipoate_e    carboxylic acids and anions
# M_sula_e       carboxylic acids and anions
# M_sulfac_e     carboxylic acids and anions
# M_2h3mp_e      carboxylic acids and anions
# M_2mba_e       carboxylic acids and anions
# M_2mpa_e       carboxylic acids and anions
# M_2obut_e      carboxylic acids and anions
# M_3hcinnm_e    carboxylic acids and anions
# M_3hpppn_e     carboxylic acids and anions
# M_3mba_e       carboxylic acids and anions
# M_3oxoadp_e    carboxylic acids and anions
# M_4abzglu_e    carboxylic acids and anions
# M_5g2oxpt_e    carboxylic acids and anions
# M_6apa_e       carboxylic acids and anions
# M_6pgc_e       carboxylic acids and anions
# M_T4hcinnm_e   carboxylic acids and anions
# M_ac_e         carboxylic acids and anions
# M_acac_e       carboxylic acids and anions
# M_acnam_e      carboxylic acids and anions
# M_acon_C_e     carboxylic acids and anions
# M_akg_e        carboxylic acids and anions
# M_but_e        carboxylic acids and anions
# M_bz_e         carboxylic acids and anions
# M_chor_e       carboxylic acids and anions
# M_cinnm_e      carboxylic acids and anions
# M_cit_e        carboxylic acids and anions
# M_for_e        carboxylic acids and anions
# M_fum_e        carboxylic acids and anions
# M_glutar_e     carboxylic acids and anions
# M_hdca_e       carboxylic acids and anions
# M_isocap_e     carboxylic acids and anions
# M_lac__D_e     carboxylic acids and anions
# M_lac__L_e     carboxylic acids and anions
# M_lnlc_e       carboxylic acids and anions
# M_mal__D_e     carboxylic acids and anions
# M_mal__L_e     carboxylic acids and anions
# M_man6pglyc_e  carboxylic acids and anions
# M_oaa_e        carboxylic acids and anions
# M_ocdcea_e     carboxylic acids and anions
# M_oxa_e        carboxylic acids and anions
# M_pac_e        carboxylic acids and anions
# M_pep_e        carboxylic acids and anions
# M_phpyr_e      carboxylic acids and anions
# M_pime_e       carboxylic acids and anions
# M_ppa_e        carboxylic acids and anions
# M_pppn_e       carboxylic acids and anions
# M_pyr_e        carboxylic acids and anions
# M_quin_e       carboxylic acids and anions
# M_skm_e        carboxylic acids and anions
# M_succ_e       carboxylic acids and anions
# M_tcb_e        carboxylic acids and anions

# %%
met_chebi_df[met_chebi_df["self defined super class"]=="fatty acids"]
# Out:
#               chebi id                                chebi class  \
# M_3mb_e    CHEBI:58956  branched-chain saturated fatty acid anion
# M_hxa_e    CHEBI:58954  straight-chain saturated fatty acid anion
# M_ibt_e    CHEBI:58956  branched-chain saturated fatty acid anion
# M_nona_e   CHEBI:58954  straight-chain saturated fatty acid anion
# M_ocdca_e  CHEBI:58954  straight-chain saturated fatty acid anion
# M_octa_e   CHEBI:58954  straight-chain saturated fatty acid anion
# M_pta_e    CHEBI:58954  straight-chain saturated fatty acid anion
#
#           self defined super class
# M_3mb_e                fatty acids
# M_hxa_e                fatty acids
# M_ibt_e                fatty acids
# M_nona_e               fatty acids
# M_ocdca_e              fatty acids
# M_octa_e               fatty acids
# M_pta_e                fatty acids

# %%
met_chebi_df[met_chebi_df["self defined super class"]=="amino acids and derivatives"].head(20)
# Out:
#                  chebi id            chebi class     self defined super class
# M_23dappa_e   CHEBI:33709             amino acid  amino acids and derivatives
# M_26dap__M_e  CHEBI:33709             amino acid  amino acids and derivatives
# M_4abut_e     CHEBI:37022       amino-acid anion  amino acids and derivatives
# M_4abz_e      CHEBI:33709             amino acid  amino acids and derivatives
# M_4hpro_DC_e  CHEBI:83821  amino acid derivative  amino acids and derivatives
# M_4hpro_LT_e  CHEBI:83821  amino acid derivative  amino acids and derivatives
# M_4hthr_e     CHEBI:33709             amino acid  amino acids and derivatives
# M_5aptn_e     CHEBI:33709             amino acid  amino acids and derivatives
# M_5oxpro_e    CHEBI:83821  amino acid derivative  amino acids and derivatives
# M_Lcyst_e     CHEBI:83821  amino acid derivative  amino acids and derivatives
# M_acglu_e     CHEBI:83821  amino acid derivative  amino acids and derivatives
# M_acser_e     CHEBI:83821  amino acid derivative  amino acids and derivatives
# M_ala_B_e     CHEBI:33709             amino acid  amino acids and derivatives
# M_ala__D_e    CHEBI:33709             amino acid  amino acids and derivatives
# M_ala__L_e    CHEBI:33709             amino acid  amino acids and derivatives
# M_arg__D_e    CHEBI:33709             amino acid  amino acids and derivatives
# M_arg__L_e    CHEBI:33709             amino acid  amino acids and derivatives
# M_argp_e      CHEBI:83821  amino acid derivative  amino acids and derivatives
# M_asn__L_e    CHEBI:33709             amino acid  amino acids and derivatives
# M_asp__D_e    CHEBI:37022       amino-acid anion  amino acids and derivatives

# %%
met_chebi_df[met_chebi_df["self defined super class"]=="other"]
# Out:
#                  chebi id     chebi class self defined super class
# M_12ppd__R_e  CHEBI:26191          polyol                    other
# M_12ppd__S_e  CHEBI:26191          polyol                    other
# M_13ppd_e     CHEBI:26191          polyol                    other
# M_abt__D_e    CHEBI:26191          polyol                    other
# M_abt__L_e    CHEBI:26191          polyol                    other
# ...                   ...             ...                      ...
# M_tmao_e             None  not classified                    other
# M_tnt_e              None  not classified                    other
# M_ttdca_e            None  not classified                    other
# M_ttdcea_e           None  not classified                    other
# M_vacc_e             None  not classified                    other
#
# [217 rows x 3 columns]

# %%
met_chebi_df[met_chebi_df["self defined super class"]=="inorganic ions and atoms"]
# Out:
#                 chebi id    chebi class  self defined super class
# M_ag_e       CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_aso3_e     CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_ca2_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_cd2_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_cl_e       CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_cobalt2_e  CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_cro4_e     CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_cu2_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_cu_e       CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_fe2_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_fe3_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_h2_e       CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_h2o2_e     CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_h2o_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_h2s_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_h_e        CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_ham_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_hg2_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_k_e        CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_mg2_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_mn2_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_mobd_e     CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_n2_e       CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_n2o_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_na1_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_nh4_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_ni2_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_no2_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_no3_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_no_e       CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_o2_e       CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_o2s_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_pi_e       CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_ppi_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_ppt_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_s_e        CHEBI:25585  nonmetal atom  inorganic ions and atoms
# M_sel_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_so3_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_so4_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_tet_e      CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_tsul_e     CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_tton_e     CHEBI:24835  inorganic ion  inorganic ions and atoms
# M_zn2_e      CHEBI:24835  inorganic ion  inorganic ions and atoms

# %%
met_chebi_df.loc["M_h2s_e"] = ["CHEBI:138675","gas molecular entity","gases"]
met_chebi_df.loc["M_h2_e"] = ["CHEBI:138675","gas molecular entity","gases"]
met_chebi_df.loc["M_no2_e"] = ["CHEBI:138675","gas molecular entity","gases"]
met_chebi_df.loc["M_no_e"] = ["CHEBI:138675","gas molecular entity","gases"]
met_chebi_df.loc["M_so3_e"] = ["CHEBI:138675","gas molecular entity","gases"]
met_chebi_df.loc["M_o2_e"] = ["CHEBI:138675","gas molecular entity","gases"]
met_chebi_df.loc["M_o2s_e"] = ["CHEBI:138675","gas molecular entity","gases"]
met_chebi_df.loc["M_n2_e"] = ["CHEBI:138675","gas molecular entity","gases"]
met_chebi_df[met_chebi_df["self defined super class"]=="gases"]
# Out:
#              chebi id           chebi class self defined super class
# M_h2_e   CHEBI:138675  gas molecular entity                    gases
# M_h2s_e  CHEBI:138675  gas molecular entity                    gases
# M_n2_e   CHEBI:138675  gas molecular entity                    gases
# M_no2_e  CHEBI:138675  gas molecular entity                    gases
# M_no_e   CHEBI:138675  gas molecular entity                    gases
# M_o2_e   CHEBI:138675  gas molecular entity                    gases
# M_o2s_e  CHEBI:138675  gas molecular entity                    gases
# M_so3_e  CHEBI:138675  gas molecular entity                    gases
# M_co2_e  CHEBI:138675  gas molecular entity                    gases
# M_co_e   CHEBI:138675  gas molecular entity                    gases

# %%
met_chebi_df.loc["M_pydxn_e"]
# Out:
# chebi id                    CHEBI:75769
# chebi class                   B vitamin
# self defined super class     B-vitamins
# Name: M_pydxn_e, dtype: object

# %% [markdown]
# **The selected compounds used here cover most of the interesting compounds**

# %%
selected_compounds = general_func.chebi_selected(rxn_based=False)["self defined super class"].unique()

# %%
met_chebi_df[~met_chebi_df["self defined super class"].isin(selected_compounds)].groupby("self defined super class").count()
# Out:
#                             chebi id  chebi class
# self defined super class
# alkaloids                          1            1
# aromatic compounds                28           28
# inorganic ions and atoms          35           35
# organonitrogen compounds          13           13
# organophosphorus compounds        18           18
# organosulfur compounds            10           10
# other                             23          217
# other vitamins                     1            1
# polyamine                          4            4
# steroid                            2            2

# %% [markdown]
# ### Save data

# %%
met_chebi_df.to_csv("../output/met_chebi_class.tsv",sep="\t")
