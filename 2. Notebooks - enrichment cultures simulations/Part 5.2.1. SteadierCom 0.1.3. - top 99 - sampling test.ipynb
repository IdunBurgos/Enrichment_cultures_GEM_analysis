# %% [markdown]
# # Process samples

# %%
import pandas as pd

# %% [markdown]
# ### Read data

# %%
SC1_C = pd.read_csv("../output/steadiercom_sample_0.1.3/test/results_99_SC1_C.tsv",sep="\t")


SC1_X = pd.read_csv("../output/steadiercom_sample_0.1.3/test/results_99_SC1_X.tsv",sep="\t")


SC2_C = pd.read_csv("../output/steadiercom_sample_0.1.3/test/results_99_SC2_C.tsv",sep="\t")

# %%
results = pd.concat([SC1_C,SC2_C,SC1_X])
results
# Out:
#           donor     receiver     compound     mass_rate      rate  frequency  \
# 0   environment  CH13-bin.12    M_cell4_e  2.654945e-02  0.039830        1.0
# 1   environment   CH15-bin.0    M_cell4_e  1.775557e-02  0.026637        1.0
# 2   environment  CH13-bin.25    M_cellb_e  1.765391e-02  0.051575        1.0
# 3   CH13-bin.12  environment       M_ac_e  1.150473e-02  0.194850        1.0
# 4   CH13-bin.12  environment      M_co2_e  1.104099e-02  0.250878        1.0
# ..          ...          ...          ...           ...       ...        ...
# 79  environment   CH14-bin.1  M_pnto__R_e  8.023300e-07  0.000004        1.0
# 80  environment   CH14-bin.2      M_fol_e  6.458346e-07  0.000001        1.0
# 81  environment   CH14-bin.2      M_nac_e  6.111222e-07  0.000005        1.0
# 82  environment   CH14-bin.2  M_pnto__R_e  2.761747e-07  0.000001        1.0
# 83  environment    CH3-bin.1  M_pnto__R_e  2.467803e-07  0.000001        1.0
#
#    community medium
# 0       CD_A  SC1_C
# ...

# %%
results[results.donor=="environment"].sort_values("mass_rate").head(20)
# Out:
#            donor     receiver     compound     mass_rate          rate  \
# 719  environment   CH7-bin.15    M_acald_e  5.199411e-11  1.180279e-09
# 559  environment   CH15-bin.2      M_fum_e  2.679221e-10  2.349036e-09
# 717  environment    CH7-bin.8    M_acald_e  4.605681e-10  1.045501e-08
# 715  environment   CH7-bin.18    M_acald_e  1.436579e-09  3.261069e-08
# 713  environment    CH7-bin.6      M_no2_e  2.035558e-09  4.424598e-08
# 709  environment    CH8-bin.7     M_succ_e  3.562561e-09  3.069268e-08
# 554  environment   CH15-bin.1      M_fum_e  5.568008e-09  4.881811e-08
# 553  environment  CH15-bin.10      M_fum_e  5.600656e-09  4.910436e-08
# 681  environment   CH7-bin.17   M_glyclt_e  2.919681e-08  3.890662e-07
# 670  environment   CH7-bin.17    M_gcald_e  4.666593e-08  7.770946e-07
# 537  environment  CH15-bin.17   M_glyclt_e  6.023358e-08  8.026509e-07
# 527  environment   CH13-bin.0      M_nac_e  1.286488e-07  1.053623e-06
# ...
