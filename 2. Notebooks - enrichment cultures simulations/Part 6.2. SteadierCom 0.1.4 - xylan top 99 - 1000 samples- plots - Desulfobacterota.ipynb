# %% [markdown]
# ## SteadierCom 0.1.4 samples1000

# %%
import pandas as pd

# %%
import sys
sys.path.append("../functions_steadiercom/")
sys.path.append("../functions/")
import steadiercom_samples_plotting
import steadiercom_samples_processing

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
SC1_X = pd.read_csv("../output/steadiercom_sample_0.1.3/results_desulfo_1000/results_99_SC1_X.tsv",sep="\t")

# %%
steadier_sample = SC1_X.copy()

# %%
steadier_sample = steadier_sample[(steadier_sample.rate>1e-6)].copy()
steadier_sample
# Out:
#            donor     receiver    compound     mass_rate      rate  frequency  \
# 0    environment    CH9-bin.0    M_xylb_e  6.771346e-02  0.239911      1.000
# 1    environment    CH9-bin.6  M_xylan4_e  6.523696e-02  0.090407      1.000
# 2      CH9-bin.0  environment      M_ac_e  6.030953e-02  1.021435      1.000
# 3    environment    CH3-bin.2  M_xylan4_e  5.240927e-02  0.072630      0.999
# 4      CH9-bin.6    CH9-bin.0  M_xyl__D_e  4.897177e-02  0.326197      1.000
# ..           ...          ...         ...           ...       ...        ...
# 398    CH9-bin.2    CH9-bin.4     M_h2s_e  1.533560e-07  0.000004      0.236
# 399   CH14-bin.2   CH14-bin.4     M_h2s_e  8.057807e-08  0.000002      0.024
# 400    CH3-bin.1  environment   M_gcald_e  7.887382e-08  0.000001      1.000
# 401   CH14-bin.0  environment   M_gcald_e  6.476837e-08  0.000001      0.122
# 403   CH14-bin.0   CH14-bin.4      M_h2_e  2.459239e-08  0.000012      0.001
#
#     community medium
# 0        CM_X  SC1_X
# ...

# %% [markdown]
# ## CD_X

# %%
community_id="CD_X"

# %%
links,members = steadiercom_samples_plotting.circos_plot_process_data(steadier_sample,community_id=community_id,min_flux=0,min_frequency=0.1)
fig,mag2color_circos,line_legend,genus_legend = steadiercom_samples_plotting.plot_circos_plot(links,members,fontsize=15,title=community_id)

# %%
fig.savefig("Figures/circos_plots_6_2/circos_1000_"+community_id+".png",bbox_extra_artists=(line_legend,genus_legend),bbox_inches='tight')

# %%
mag2color_circos
# Out:
# {'CH14-bin.1': 0.1,
#  'CH14-bin.2': 0.325,
#  'CH14-bin.0': 0.55,
#  'CH14-bin.4': 0.775}

# %%
steadier_sample_pre = steadiercom_samples_processing.preprocessing_func(steadier_sample)

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.0") & (steadier_sample_pre.donor=="CH14-bin.1")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound  mass_rate      rate  frequency  \
# 252  CH14-bin.1  CH14-bin.0      M_h2_e   0.000059  0.029147      0.008
# 36   CH14-bin.1  CH14-bin.0     M_orn_e   0.004343  0.032614      0.002
# 116  CH14-bin.1  CH14-bin.0  M_rib__D_e   0.000670  0.004462      0.022
# 210  CH14-bin.1  CH14-bin.0   M_gcald_e   0.000121  0.002010      0.169
# 256  CH14-bin.1  CH14-bin.0     M_ura_e   0.000053  0.000477      0.424
# 255  CH14-bin.1  CH14-bin.0     M_gua_e   0.000055  0.000367      1.000
# 71   CH14-bin.1  CH14-bin.0    M_glyc_e   0.001961  0.021293      0.682
# 27   CH14-bin.1  CH14-bin.0  M_glyald_e   0.005813  0.064530      0.512
# 30   CH14-bin.1  CH14-bin.0  M_xyl__D_e   0.004933  0.032858      0.768
#
#     community medium  mass_rate*frequency                  super_class
# 252      CD_X  SC1_X         4.700286e-07                        gases
# 36       CD_X  SC1_X         8.686321e-06  amino acids and derivatives
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.0") & (steadier_sample_pre.donor=="CH14-bin.2")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound  mass_rate      rate  frequency  \
# 192  CH14-bin.2  CH14-bin.0    M_glyc_e   0.000235  0.002547      0.170
# 40   CH14-bin.2  CH14-bin.0  M_xyl__D_e   0.003681  0.024518      0.311
#
#     community medium  mass_rate*frequency    super_class
# 192      CD_X  SC1_X             0.000040          other
# 40       CD_X  SC1_X             0.001145  simple sugars

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.0") & (steadier_sample_pre.donor=="CH14-bin.4")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound  mass_rate      rate  frequency  \
# 351  CH14-bin.4  CH14-bin.0      M_h2_e   0.000002  0.001074      0.008
# 163  CH14-bin.4  CH14-bin.0  M_lac__L_e   0.000326  0.003656      0.015
#
#     community medium  mass_rate*frequency                  super_class
# 351      CD_X  SC1_X         1.732240e-08                        gases
# 163      CD_X  SC1_X         4.884621e-06  carboxylic acids and anions

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.2") & (steadier_sample_pre.donor=="CH14-bin.0")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver   compound  mass_rate      rate  frequency  \
# 261  CH14-bin.0  CH14-bin.2  M_acald_e   0.000044  0.001000      0.024
# 320  CH14-bin.0  CH14-bin.2    M_h2s_e   0.000007  0.000216      0.920
# 259  CH14-bin.0  CH14-bin.2    M_ura_e   0.000045  0.000405      0.302
# 121  CH14-bin.0  CH14-bin.2   M_g3pg_e   0.000625  0.002548      0.231
# 159  CH14-bin.0  CH14-bin.2    M_co2_e   0.000344  0.007823      0.707
#
#     community medium  mass_rate*frequency                  super_class
# 261      CD_X  SC1_X             0.000001       alcohols and aldehydes
# 320      CD_X  SC1_X             0.000007                        gases
# 259      CD_X  SC1_X             0.000014  nucleotides and derivatives
# 121      CD_X  SC1_X             0.000144                       lipids
# 159      CD_X  SC1_X             0.000243                        gases

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.2") & (steadier_sample_pre.donor=="CH14-bin.1")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound  mass_rate      rate  frequency  \
# 120  CH14-bin.1  CH14-bin.2  M_rib__D_e   0.000636  0.004236      0.001
# 343  CH14-bin.1  CH14-bin.2     M_h2s_e   0.000003  0.000100      0.742
# 228  CH14-bin.1  CH14-bin.2   M_anhgm_e   0.000087  0.000182      0.045
# 242  CH14-bin.1  CH14-bin.2     M_ura_e   0.000067  0.000597      0.806
# 243  CH14-bin.1  CH14-bin.2     M_gua_e   0.000067  0.000442      1.000
# 102  CH14-bin.1  CH14-bin.2  M_asp__D_e   0.000872  0.006598      0.925
# 46   CH14-bin.1  CH14-bin.2   M_acald_e   0.003327  0.075527      0.295
# 76   CH14-bin.1  CH14-bin.2     M_co2_e   0.001534  0.034857      0.707
# 37   CH14-bin.1  CH14-bin.2  M_xyl__D_e   0.004283  0.028528      0.310
#
#     community medium  mass_rate*frequency                  super_class
# 120      CD_X  SC1_X         6.359727e-07                simple sugars
# 343      CD_X  SC1_X         2.536211e-06                        gases
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.2") & (steadier_sample_pre.donor=="CH14-bin.4")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver  compound     mass_rate      rate  frequency  \
# 378  CH14-bin.4  CH14-bin.2   M_h2s_e  6.834127e-07  0.000020      0.372
# 288  CH14-bin.4  CH14-bin.2  M_quin_e  2.422757e-05  0.000127      1.000
# 257  CH14-bin.4  CH14-bin.2   M_co2_e  5.083450e-05  0.001155      0.707
#
#     community medium  mass_rate*frequency                  super_class
# 378      CD_X  SC1_X         2.542295e-07                        gases
# 288      CD_X  SC1_X         2.422757e-05  carboxylic acids and anions
# 257      CD_X  SC1_X         3.593999e-05                        gases

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.4") & (steadier_sample_pre.donor=="CH14-bin.0")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound     mass_rate      rate  frequency  \
# 403  CH14-bin.0  CH14-bin.4      M_h2_e  2.459239e-08  0.000012      0.001
# 375  CH14-bin.0  CH14-bin.4    M_thym_e  8.762367e-07  0.000007      0.003
# 372  CH14-bin.0  CH14-bin.4     M_h2s_e  1.005152e-06  0.000029      0.495
# 324  CH14-bin.0  CH14-bin.4     M_ura_e  6.623584e-06  0.000059      0.302
# 245  CH14-bin.0  CH14-bin.4    M_g3pg_e  6.407126e-05  0.000261      0.913
# 93   CH14-bin.0  CH14-bin.4  M_lac__L_e  1.156836e-03  0.012988      0.693
#
#     community medium  mass_rate*frequency                  super_class
# 403      CD_X  SC1_X         2.459239e-11                        gases
# 375      CD_X  SC1_X         2.628710e-09  nucleotides and derivatives
# 372      CD_X  SC1_X         4.975501e-07                        gases
# 324      CD_X  SC1_X         2.000322e-06  nucleotides and derivatives
# 245      CD_X  SC1_X         5.849706e-05                       lipids
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.4") & (steadier_sample_pre.donor=="CH14-bin.1")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver     compound     mass_rate      rate  frequency  \
# 370  CH14-bin.1  CH14-bin.4  M_istfrnB_e  1.109474e-06  0.000002      0.001
# 390  CH14-bin.1  CH14-bin.4       M_h2_e  3.470350e-07  0.000172      0.006
# 376  CH14-bin.1  CH14-bin.4     M_thym_e  8.762367e-07  0.000007      0.018
# 385  CH14-bin.1  CH14-bin.4      M_h2s_e  4.810287e-07  0.000014      0.394
# 313  CH14-bin.1  CH14-bin.4      M_ura_e  9.732777e-06  0.000087      0.806
# 312  CH14-bin.1  CH14-bin.4      M_gua_e  9.760597e-06  0.000065      1.000
# 201  CH14-bin.1  CH14-bin.4   M_asp__D_e  1.420144e-04  0.001075      0.993
# 145  CH14-bin.1  CH14-bin.4   M_glyc3p_e  4.230262e-04  0.002488      0.761
# 95   CH14-bin.1  CH14-bin.4   M_mal__L_e  1.125890e-03  0.008525      0.654
#
#     community medium  mass_rate*frequency                  super_class
# 370      CD_X  SC1_X         1.109474e-09                        other
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.4") & (steadier_sample_pre.donor=="CH14-bin.2")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound     mass_rate      rate  frequency  \
# 399  CH14-bin.2  CH14-bin.4     M_h2s_e  8.057807e-08  0.000002      0.024
# 208  CH14-bin.2  CH14-bin.4  M_asp__D_e  1.233436e-04  0.000934      0.006
# 140  CH14-bin.2  CH14-bin.4  M_glyc3p_e  4.333109e-04  0.002548      0.231
# 166  CH14-bin.2  CH14-bin.4  M_mal__L_e  3.174068e-04  0.002403      0.592
#
#     community medium  mass_rate*frequency                  super_class
# 399      CD_X  SC1_X         1.933874e-09                        gases
# 208      CD_X  SC1_X         7.400615e-07  amino acids and derivatives
# 140      CD_X  SC1_X         1.000948e-04                        other
# 166      CD_X  SC1_X         1.879048e-04  carboxylic acids and anions

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.0")&(steadier_sample_pre.receiver=="CH14-bin.1")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor    receiver   compound  mass_rate      rate  frequency  \
# 315  CH14-bin.0  CH14-bin.1   M_thym_e   0.000009  0.000073      0.187
# 258  CH14-bin.0  CH14-bin.1  M_acald_e   0.000046  0.001049      0.043
# 269  CH14-bin.0  CH14-bin.1    M_h2s_e   0.000038  0.001128      0.142
# 54   CH14-bin.0  CH14-bin.1   M_ptrc_e   0.002941  0.032614      0.002
# 198  CH14-bin.0  CH14-bin.1    M_ura_e   0.000187  0.001667      0.149
# 122  CH14-bin.0  CH14-bin.1   M_g3pg_e   0.000610  0.002488      0.761
#
#     community medium  mass_rate*frequency                  super_class
# 315      CD_X  SC1_X             0.000002  nucleotides and derivatives
# 258      CD_X  SC1_X             0.000002       alcohols and aldehydes
# 269      CD_X  SC1_X             0.000005                        gases
# 54       CD_X  SC1_X             0.000006                        other
# 198      CD_X  SC1_X             0.000028  nucleotides and derivatives
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.0")&(steadier_sample_pre.receiver=="environment")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor     receiver    compound     mass_rate      rate  frequency  \
# 401  CH14-bin.0  environment   M_gcald_e  6.476837e-08  0.000001      0.122
# 304  CH14-bin.0  environment   M_acald_e  1.191637e-05  0.000271      0.004
# 220  CH14-bin.0  environment     M_pta_e  1.123041e-04  0.001111      0.004
# 79   CH14-bin.0  environment  M_lac__L_e  1.461971e-03  0.016414      0.002
# 212  CH14-bin.0  environment      M_h2_e  1.197470e-04  0.059404      0.415
# 86   CH14-bin.0  environment     M_hxa_e  1.326224e-03  0.011517      0.056
# 101  CH14-bin.0  environment     M_but_e  8.732452e-04  0.010026      0.440
# 91   CH14-bin.0  environment     M_h2s_e  1.190712e-03  0.034938      1.000
# 51   CH14-bin.0  environment     M_co2_e  3.159694e-03  0.071796      1.000
# 41   CH14-bin.0  environment      M_ac_e  3.672703e-03  0.062203      0.998
#
#     community medium  mass_rate*frequency                  super_class
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.1")&(steadier_sample_pre.receiver=="environment")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor     receiver    compound  mass_rate      rate  frequency  \
# 186  CH14-bin.1  environment     M_ppa_e   0.000250  0.003422      0.001
# 156  CH14-bin.1  environment     M_ibt_e   0.000364  0.004181      0.004
# 264  CH14-bin.1  environment    M_glyc_e   0.000041  0.000441      0.038
# 69   CH14-bin.1  environment   M_man1p_e   0.002042  0.007909      0.001
# 89   CH14-bin.1  environment     M_but_e   0.001313  0.015081      0.006
# 42   CH14-bin.1  environment   M_acald_e   0.003670  0.083318      0.009
# 61   CH14-bin.1  environment     M_for_e   0.002498  0.055482      0.035
# 218  CH14-bin.1  environment   M_gcald_e   0.000115  0.001907      1.000
# 174  CH14-bin.1  environment    M_4hba_e   0.000302  0.002433      0.922
# 113  CH14-bin.1  environment     M_thm_e   0.000695  0.002620      0.856
# 108  CH14-bin.1  environment     M_h2s_e   0.000775  0.022751      0.803
# 106  CH14-bin.1  environment      M_h2_e   0.000798  0.396060      0.947
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.2")&(steadier_sample_pre.receiver=="environment")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor     receiver      compound  mass_rate      rate  frequency  \
# 222  CH14-bin.2  environment       M_h2s_e   0.000101  0.002956      0.042
# 151  CH14-bin.2  environment     M_ibtol_e   0.000385  0.004475      0.055
# 124  CH14-bin.2  environment       M_ppa_e   0.000600  0.008206      0.036
# 60   CH14-bin.2  environment     M_acald_e   0.002570  0.058348      0.012
# 109  CH14-bin.2  environment       M_but_e   0.000774  0.008881      0.042
# 115  CH14-bin.2  environment       M_co2_e   0.000678  0.015402      0.146
# 75   CH14-bin.2  environment  M_12ppd__R_e   0.001609  0.021149      0.105
# 35   CH14-bin.2  environment    M_xyl__D_e   0.004502  0.029988      0.102
# 57   CH14-bin.2  environment        M_co_e   0.002829  0.100988      0.891
# 29   CH14-bin.2  environment        M_ac_e   0.005353  0.090657      0.999
#
#     community medium  mass_rate*frequency                  super_class
# 222      CD_X  SC1_X             0.000004                        gases
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.4")&(steadier_sample_pre.receiver=="environment")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor     receiver  compound  mass_rate      rate  frequency  \
# 221  CH14-bin.4  environment   M_ppa_e   0.000103  0.001409      0.002
# 262  CH14-bin.4  environment  M_succ_e   0.000042  0.000360      0.139
# 273  CH14-bin.4  environment    M_h2_e   0.000037  0.018316      0.904
# 215  CH14-bin.4  environment   M_h2s_e   0.000118  0.003456      0.398
# 134  CH14-bin.4  environment   M_co2_e   0.000503  0.011436      1.000
# 110  CH14-bin.4  environment   M_for_e   0.000763  0.016943      0.723
# 98   CH14-bin.4  environment    M_ac_e   0.000946  0.016014      0.998
#
#     community medium  mass_rate*frequency                  super_class
# 221      CD_X  SC1_X         2.059398e-07  carboxylic acids and anions
# 262      CD_X  SC1_X         5.813659e-06  carboxylic acids and anions
# 273      CD_X  SC1_X         3.337756e-05                        gases
# 215      CD_X  SC1_X         4.687149e-05                        gases
# ...

# %%
links,members = steadiercom_samples_plotting.circos_plot_process_data(steadier_sample,community_id=community_id,compound_type=["amino acids and derivatives","nucleotides and derivatives","urea and urea derivatives","B-vitamins","cofactors"],min_frequency=0.1)
fig,mag2color_circos,line_legend,genus_legend = steadiercom_samples_plotting.plot_circos_plot(links,members,fontsize=15,title=community_id)

# %%
data_receiver_df,data_donor_df,community_abundance = steadiercom_samples_plotting.data_uptake_prod(steadier_sample,community_id=community_id,compound_type=False,only_media=False)
fig,mag2color_bar = steadiercom_samples_plotting.plot_uptake_prod(data_receiver_df,data_donor_df,community_abundance,title=community_id)
# Out:
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
fig.savefig("Figures/circos_plots_6_2/bar_abund_1000_"+community_id+".png")

# %%
mag2color_circos==mag2color_bar
# Out:
# True

# %%
mag2color_circos
# Out:
# {'CH14-bin.1': 0.1,
#  'CH14-bin.2': 0.325,
#  'CH14-bin.0': 0.55,
#  'CH14-bin.4': 0.775}

# %% [markdown]
# ## CM_X

# %%
community_id="CM_X"

# %%
links,members = steadiercom_samples_plotting.circos_plot_process_data(steadier_sample,community_id=community_id,min_flux=0,min_frequency=0.1)
fig,mag2color_circos,line_legend,genus_legend = steadiercom_samples_plotting.plot_circos_plot(links,members,fontsize=15,title=community_id)

# %%
links,members = steadiercom_samples_plotting.circos_plot_process_data(steadier_sample,community_id=community_id,compound_type=["amino acids and derivatives","nucleotides and derivatives","urea and urea derivatives","B-vitamins","cofactors"],min_frequency=0.1)
fig,mag2color_circos,line_legend,genus_legend = steadiercom_samples_plotting.plot_circos_plot(links,members,fontsize=15,title=community_id)

# %%
data_receiver_df,data_donor_df,community_abundance = steadiercom_samples_plotting.data_uptake_prod(steadier_sample,community_id=community_id,compound_type=False,only_media=False)
fig,mag2color_bar = steadiercom_samples_plotting.plot_uptake_prod(data_receiver_df,data_donor_df,community_abundance,title=community_id)
# Out:
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
mag2color_circos==mag2color_bar
# Out:
# True

# %%
mag2color_circos.keys()
# Out:
# dict_keys(['CH9-bin.0', 'CH9-bin.6', 'CH9-bin.5', 'CH9-bin.1', 'CH9-bin.2', 'CH9-bin.4'])

# %% [markdown]
# ## M_X

# %%
community_id="M_X"

# %%
links,members = steadiercom_samples_plotting.circos_plot_process_data(steadier_sample,community_id=community_id,min_flux=0,min_frequency=0.1)
fig,mag2color_circos,line_legend,genus_legend = steadiercom_samples_plotting.plot_circos_plot(links,members,fontsize=15,title=community_id)

# %%
links,members = steadiercom_samples_plotting.circos_plot_process_data(steadier_sample,community_id=community_id,compound_type=["amino acids and derivatives","nucleotides and derivatives","urea and urea derivatives","B-vitamins","cofactors"],min_frequency=0.1)
fig,mag2color_circos,line_legend,genus_legend = steadiercom_samples_plotting.plot_circos_plot(links,members,fontsize=15,title=community_id)

# %%
data_receiver_df,data_donor_df,community_abundance = steadiercom_samples_plotting.data_uptake_prod(steadier_sample,community_id=community_id,compound_type=False,only_media=False)
fig,mag2color_bar = steadiercom_samples_plotting.plot_uptake_prod(data_receiver_df,data_donor_df,community_abundance,title=community_id)
# Out:
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
mag2color_circos==mag2color_bar
# Out:
# True
