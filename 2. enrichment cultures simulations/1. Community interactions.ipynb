# %% [markdown]
# # SteadierCom 0.1.4 samples

# %%
import pandas as pd

# %%
import sys
sys.path.append("../functions_steadiercom/")
sys.path.append("../functions/")
import steadiercom_samples_plotting
import general_functions as general_func

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Main Figure

# %%
SC1_X = pd.read_csv("../output_30_08_24/steadiercom_sample_0.1.3/results_desulfo_1000/results_99_SC1_X.tsv",sep="\t")

# %%
steadier_sample = SC1_X.copy()

# %%
steadier_sample = steadier_sample[(steadier_sample.rate>1e-6)].copy()
steadier_sample["mass_rate"] = steadier_sample["mass_rate"]*1000

# %% [markdown]
# ## CD_X

# %%
community_id="CD_X"

# %%
steadiercom_samples_plotting.combined_figure(steadier_sample,community_id,path = "Figures/circos_plots/1000_",move_legend=-0.2)

# %%
steadier_sample[(steadier_sample.community=="CD_X")&(steadier_sample.compound=="M_but_e")].sort_values("mass_rate",ascending=False)
# Out:
#           donor     receiver compound  mass_rate      rate  frequency  \
# 89   CH14-bin.1  environment  M_but_e   1.313491  0.015081      0.006
# 101  CH14-bin.0  environment  M_but_e   0.873245  0.010026      0.440
# 109  CH14-bin.2  environment  M_but_e   0.773512  0.008881      0.042
#
#     community medium
# 89       CD_X  SC1_X
# 101      CD_X  SC1_X
# 109      CD_X  SC1_X

# %%
steadier_sample[(steadier_sample.community=="CD_X")&(steadier_sample.compound=="M_hxa_e")].sort_values("mass_rate",ascending=False)
# Out:
#          donor     receiver compound  mass_rate      rate  frequency  \
# 86  CH14-bin.0  environment  M_hxa_e   1.326224  0.011517      0.056
#
#    community medium
# 86      CD_X  SC1_X

# %% [markdown]
# # Supplementary Figures

# %%
SC1_C = pd.read_csv("../output_30_08_24/steadiercom_sample_0.1.3/results/results_99_SC1_C.tsv",sep="\t")
SC2_C = pd.read_csv("../output_30_08_24/steadiercom_sample_0.1.3/results/results_99_SC2_C.tsv",sep="\t")
SC1_X = pd.read_csv("../output_30_08_24/steadiercom_sample_0.1.3/results/results_99_SC1_X.tsv",sep="\t")

steadier_sample = pd.concat([SC1_C,SC2_C,SC1_X])

steadier_sample["mass_rate"] = steadier_sample["mass_rate"]*1000

steadier_sample = steadier_sample[(steadier_sample.frequency>0.1) & (steadier_sample.rate>1e-6)].copy()

# %%
steadier_sample.community.unique()
# Out:
# array(['CD_A', 'CD_P', 'CM_P', 'M_P', 'CM_A', 'CM_X', 'M_X', 'CD_X'],
#       dtype=object)

# %% [markdown]
# ## CD_A

# %%
community_id="CD_A"

# %%
steadiercom_samples_plotting.combined_figure(steadier_sample,community_id,path = "Figures/circos_plots/")

# %% [markdown]
# ## CD_P

# %%
community_id="CD_P"

# %%
steadiercom_samples_plotting.combined_figure(steadier_sample,community_id,path = "Figures/circos_plots/")

# %% [markdown]
# ## CM_A

# %%
community_id="CM_A"

# %%
steadiercom_samples_plotting.combined_figure(steadier_sample,community_id,path = "Figures/circos_plots/",move_legend =0)

# %% [markdown]
# ## CM_P

# %%
community_id="CM_P"

# %%
steadiercom_samples_plotting.combined_figure(steadier_sample,community_id,path = "Figures/circos_plots/",move_legend =0)

# %% [markdown]
# ## CM_X

# %%
community_id="CM_X"

# %%
steadiercom_samples_plotting.combined_figure(steadier_sample,community_id,path = "Figures/circos_plots/",move_legend =-0.2)

# %% [markdown]
# ## M_P

# %%
community_id="M_P"

# %%
steadiercom_samples_plotting.combined_figure(steadier_sample,community_id,path = "Figures/circos_plots/",move_legend =-0.2)

# %% [markdown]
# ## M_X

# %%
community_id="M_X"

# %%
steadiercom_samples_plotting.combined_figure(steadier_sample,community_id,path = "Figures/circos_plots/",move_legend =-0.2)
