# %% [markdown]
# ## SteadierCom 0.1.4 samples1000

# %%
import pandas as pd

# %%
import sys
sys.path.append("../functions_steadiercom/")
sys.path.append("../functions/")
import steadiercom_samples_plotting
import steadiercom_samples_processing

# %%
# %load_ext autoreload
# %autoreload 2

# %%
SC1_X = pd.read_csv("../output_30_08_24/steadiercom_sample_0.1.3/results_desulfo_1000/results_99_SC1_X.tsv",sep="\t")

# %%
steadier_sample = SC1_X.copy()

# %%
steadier_sample = steadier_sample[(steadier_sample.rate>1e-6)].copy()
steadier_sample["mass_rate"] = steadier_sample["mass_rate"]*1000

# %% [markdown]
# ## CD_X

# %%
community_id="CD_X"

# %%
steadiercom_samples_plotting.combined_figure(steadier_sample,community_id,path = "Figures/circos_plots/1000_",move_legend=-0.2)

# %%
steadier_sample_pre = steadiercom_samples_processing.preprocessing_func(steadier_sample)

# %%
steadier_sample_pre[(steadier_sample_pre.community=="CD_X")&(steadier_sample_pre.compound=="M_h2_e")].groupby("donor").sum()
# Out:
#             mass_rate      rate  frequency  mass_rate*frequency
# donor
# CH14-bin.0   0.119772  0.059416      0.416             0.049695
# CH14-bin.1   0.857477  0.425378      0.961             0.756535
# CH14-bin.4   0.039087  0.019391      0.912             0.033395

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.0") & (steadier_sample_pre.donor=="CH14-bin.1")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound  mass_rate      rate  frequency  \
# 252  CH14-bin.1  CH14-bin.0      M_h2_e   0.058754  0.029147      0.008
# 36   CH14-bin.1  CH14-bin.0     M_orn_e   4.343160  0.032614      0.002
# 116  CH14-bin.1  CH14-bin.0  M_rib__D_e   0.669908  0.004462      0.022
# 210  CH14-bin.1  CH14-bin.0   M_gcald_e   0.120680  0.002010      0.169
# 256  CH14-bin.1  CH14-bin.0     M_ura_e   0.053440  0.000477      0.424
# 255  CH14-bin.1  CH14-bin.0     M_gua_e   0.055495  0.000367      1.000
# 71   CH14-bin.1  CH14-bin.0    M_glyc_e   1.960910  0.021293      0.682
# 27   CH14-bin.1  CH14-bin.0  M_glyald_e   5.812738  0.064530      0.512
# 30   CH14-bin.1  CH14-bin.0  M_xyl__D_e   4.932886  0.032858      0.768
#
#     community medium  mass_rate*frequency                  super_class
# 252      CD_X  SC1_X             0.000470                        gases
# 36       CD_X  SC1_X             0.008686  amino acids and derivatives
# 116      CD_X  SC1_X             0.014738                simple sugars
# 210      CD_X  SC1_X             0.020395                        other
# 256      CD_X  SC1_X             0.022659  nucleotides and derivatives
# 255      CD_X  SC1_X             0.055495  nucleotides and derivatives
# 71       CD_X  SC1_X             1.337341                        other
# 27       CD_X  SC1_X             2.976122                simple sugars
# 30       CD_X  SC1_X             3.788457                simple sugars

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.0") & (steadier_sample_pre.donor=="CH14-bin.2")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound  mass_rate      rate  frequency  \
# 192  CH14-bin.2  CH14-bin.0    M_glyc_e    0.23454  0.002547      0.170
# 40   CH14-bin.2  CH14-bin.0  M_xyl__D_e    3.68087  0.024518      0.311
#
#     community medium  mass_rate*frequency    super_class
# 192      CD_X  SC1_X             0.039872          other
# 40       CD_X  SC1_X             1.144751  simple sugars

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.0") & (steadier_sample_pre.donor=="CH14-bin.4")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound  mass_rate      rate  frequency  \
# 351  CH14-bin.4  CH14-bin.0      M_h2_e   0.002165  0.001074      0.008
# 163  CH14-bin.4  CH14-bin.0  M_lac__L_e   0.325641  0.003656      0.015
#
#     community medium  mass_rate*frequency                  super_class
# 351      CD_X  SC1_X             0.000017                        gases
# 163      CD_X  SC1_X             0.004885  carboxylic acids and anions

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.2") & (steadier_sample_pre.donor=="CH14-bin.0")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver   compound  mass_rate      rate  frequency  \
# 261  CH14-bin.0  CH14-bin.2  M_acald_e   0.044042  0.001000      0.024
# 320  CH14-bin.0  CH14-bin.2    M_h2s_e   0.007345  0.000216      0.920
# 259  CH14-bin.0  CH14-bin.2    M_ura_e   0.045366  0.000405      0.302
# 121  CH14-bin.0  CH14-bin.2   M_g3pg_e   0.624632  0.002548      0.231
# 159  CH14-bin.0  CH14-bin.2    M_co2_e   0.344269  0.007823      0.707
#
#     community medium  mass_rate*frequency                  super_class
# 261      CD_X  SC1_X             0.001057       alcohols and aldehydes
# 320      CD_X  SC1_X             0.006758                        gases
# 259      CD_X  SC1_X             0.013700  nucleotides and derivatives
# 121      CD_X  SC1_X             0.144290                       lipids
# 159      CD_X  SC1_X             0.243398                        gases

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.2") & (steadier_sample_pre.donor=="CH14-bin.1")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound  mass_rate      rate  frequency  \
# 120  CH14-bin.1  CH14-bin.2  M_rib__D_e   0.635973  0.004236      0.001
# 343  CH14-bin.1  CH14-bin.2     M_h2s_e   0.003418  0.000100      0.742
# 228  CH14-bin.1  CH14-bin.2   M_anhgm_e   0.087072  0.000182      0.045
# 242  CH14-bin.1  CH14-bin.2     M_ura_e   0.066872  0.000597      0.806
# 243  CH14-bin.1  CH14-bin.2     M_gua_e   0.066730  0.000442      1.000
# 102  CH14-bin.1  CH14-bin.2  M_asp__D_e   0.871521  0.006598      0.925
# 46   CH14-bin.1  CH14-bin.2   M_acald_e   3.327135  0.075527      0.295
# 76   CH14-bin.1  CH14-bin.2     M_co2_e   1.534042  0.034857      0.707
# 37   CH14-bin.1  CH14-bin.2  M_xyl__D_e   4.282912  0.028528      0.310
#
#     community medium  mass_rate*frequency                  super_class
# 120      CD_X  SC1_X             0.000636                simple sugars
# 343      CD_X  SC1_X             0.002536                        gases
# 228      CD_X  SC1_X             0.003918                        other
# 242      CD_X  SC1_X             0.053899  nucleotides and derivatives
# 243      CD_X  SC1_X             0.066730  nucleotides and derivatives
# 102      CD_X  SC1_X             0.806157  amino acids and derivatives
# 46       CD_X  SC1_X             0.981505       alcohols and aldehydes
# 76       CD_X  SC1_X             1.084568                        gases
# 37       CD_X  SC1_X             1.327703                simple sugars

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.2") & (steadier_sample_pre.donor=="CH14-bin.4")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver  compound  mass_rate      rate  frequency  \
# 378  CH14-bin.4  CH14-bin.2   M_h2s_e   0.000683  0.000020      0.372
# 288  CH14-bin.4  CH14-bin.2  M_quin_e   0.024228  0.000127      1.000
# 257  CH14-bin.4  CH14-bin.2   M_co2_e   0.050834  0.001155      0.707
#
#     community medium  mass_rate*frequency                  super_class
# 378      CD_X  SC1_X             0.000254                        gases
# 288      CD_X  SC1_X             0.024228  carboxylic acids and anions
# 257      CD_X  SC1_X             0.035940                        gases

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.4") & (steadier_sample_pre.donor=="CH14-bin.0")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound  mass_rate      rate  frequency  \
# 403  CH14-bin.0  CH14-bin.4      M_h2_e   0.000025  0.000012      0.001
# 375  CH14-bin.0  CH14-bin.4    M_thym_e   0.000876  0.000007      0.003
# 372  CH14-bin.0  CH14-bin.4     M_h2s_e   0.001005  0.000029      0.495
# 324  CH14-bin.0  CH14-bin.4     M_ura_e   0.006624  0.000059      0.302
# 245  CH14-bin.0  CH14-bin.4    M_g3pg_e   0.064071  0.000261      0.913
# 93   CH14-bin.0  CH14-bin.4  M_lac__L_e   1.156836  0.012988      0.693
#
#     community medium  mass_rate*frequency                  super_class
# 403      CD_X  SC1_X         2.459239e-08                        gases
# 375      CD_X  SC1_X         2.628710e-06  nucleotides and derivatives
# 372      CD_X  SC1_X         4.975501e-04                        gases
# 324      CD_X  SC1_X         2.000322e-03  nucleotides and derivatives
# 245      CD_X  SC1_X         5.849706e-02                       lipids
# 93       CD_X  SC1_X         8.016874e-01  carboxylic acids and anions

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.4") & (steadier_sample_pre.donor=="CH14-bin.1")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver     compound  mass_rate      rate  frequency  \
# 370  CH14-bin.1  CH14-bin.4  M_istfrnB_e   0.001109  0.000002      0.001
# 390  CH14-bin.1  CH14-bin.4       M_h2_e   0.000347  0.000172      0.006
# 376  CH14-bin.1  CH14-bin.4     M_thym_e   0.000876  0.000007      0.018
# 385  CH14-bin.1  CH14-bin.4      M_h2s_e   0.000481  0.000014      0.394
# 313  CH14-bin.1  CH14-bin.4      M_ura_e   0.009733  0.000087      0.806
# 312  CH14-bin.1  CH14-bin.4      M_gua_e   0.009761  0.000065      1.000
# 201  CH14-bin.1  CH14-bin.4   M_asp__D_e   0.142014  0.001075      0.993
# 145  CH14-bin.1  CH14-bin.4   M_glyc3p_e   0.423026  0.002488      0.761
# 95   CH14-bin.1  CH14-bin.4   M_mal__L_e   1.125890  0.008525      0.654
#
#     community medium  mass_rate*frequency                  super_class
# 370      CD_X  SC1_X             0.000001                        other
# 390      CD_X  SC1_X             0.000002                        gases
# 376      CD_X  SC1_X             0.000016  nucleotides and derivatives
# 385      CD_X  SC1_X             0.000190                        gases
# 313      CD_X  SC1_X             0.007845  nucleotides and derivatives
# 312      CD_X  SC1_X             0.009761  nucleotides and derivatives
# 201      CD_X  SC1_X             0.141020  amino acids and derivatives
# 145      CD_X  SC1_X             0.321923                        other
# 95       CD_X  SC1_X             0.736332  carboxylic acids and anions

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.4") & (steadier_sample_pre.donor=="CH14-bin.2")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound  mass_rate      rate  frequency  \
# 399  CH14-bin.2  CH14-bin.4     M_h2s_e   0.000081  0.000002      0.024
# 208  CH14-bin.2  CH14-bin.4  M_asp__D_e   0.123344  0.000934      0.006
# 140  CH14-bin.2  CH14-bin.4  M_glyc3p_e   0.433311  0.002548      0.231
# 166  CH14-bin.2  CH14-bin.4  M_mal__L_e   0.317407  0.002403      0.592
#
#     community medium  mass_rate*frequency                  super_class
# 399      CD_X  SC1_X             0.000002                        gases
# 208      CD_X  SC1_X             0.000740  amino acids and derivatives
# 140      CD_X  SC1_X             0.100095                        other
# 166      CD_X  SC1_X             0.187905  carboxylic acids and anions

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.0")&(steadier_sample_pre.receiver=="CH14-bin.1")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor    receiver   compound  mass_rate      rate  frequency  \
# 315  CH14-bin.0  CH14-bin.1   M_thym_e   0.009237  0.000073      0.187
# 258  CH14-bin.0  CH14-bin.1  M_acald_e   0.046218  0.001049      0.043
# 269  CH14-bin.0  CH14-bin.1    M_h2s_e   0.038451  0.001128      0.142
# 54   CH14-bin.0  CH14-bin.1   M_ptrc_e   2.940704  0.032614      0.002
# 198  CH14-bin.0  CH14-bin.1    M_ura_e   0.186843  0.001667      0.149
# 122  CH14-bin.0  CH14-bin.1   M_g3pg_e   0.609807  0.002488      0.761
#
#     community medium  mass_rate*frequency                  super_class
# 315      CD_X  SC1_X             0.001727  nucleotides and derivatives
# 258      CD_X  SC1_X             0.001987       alcohols and aldehydes
# 269      CD_X  SC1_X             0.005460                        gases
# 54       CD_X  SC1_X             0.005881                        other
# 198      CD_X  SC1_X             0.027840  nucleotides and derivatives
# 122      CD_X  SC1_X             0.464063                       lipids

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.0")&(steadier_sample_pre.receiver=="environment")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor     receiver    compound  mass_rate      rate  frequency  \
# 401  CH14-bin.0  environment   M_gcald_e   0.000065  0.000001      0.122
# 304  CH14-bin.0  environment   M_acald_e   0.011916  0.000271      0.004
# 220  CH14-bin.0  environment     M_pta_e   0.112304  0.001111      0.004
# 79   CH14-bin.0  environment  M_lac__L_e   1.461971  0.016414      0.002
# 212  CH14-bin.0  environment      M_h2_e   0.119747  0.059404      0.415
# 86   CH14-bin.0  environment     M_hxa_e   1.326224  0.011517      0.056
# 101  CH14-bin.0  environment     M_but_e   0.873245  0.010026      0.440
# 91   CH14-bin.0  environment     M_h2s_e   1.190712  0.034938      1.000
# 51   CH14-bin.0  environment     M_co2_e   3.159694  0.071796      1.000
# 41   CH14-bin.0  environment      M_ac_e   3.672703  0.062203      0.998
#
#     community medium  mass_rate*frequency                  super_class
# 401      CD_X  SC1_X             0.000008                        other
# 304      CD_X  SC1_X             0.000048       alcohols and aldehydes
# 220      CD_X  SC1_X             0.000449                  fatty acids
# 79       CD_X  SC1_X             0.002924  carboxylic acids and anions
# 212      CD_X  SC1_X             0.049695                        gases
# 86       CD_X  SC1_X             0.074269                  fatty acids
# 101      CD_X  SC1_X             0.384228  carboxylic acids and anions
# 91       CD_X  SC1_X             1.190712                        gases
# 51       CD_X  SC1_X             3.159694                        gases
# 41       CD_X  SC1_X             3.665358  carboxylic acids and anions

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.1")&(steadier_sample_pre.receiver=="environment")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor     receiver    compound  mass_rate      rate  frequency  \
# 186  CH14-bin.1  environment     M_ppa_e   0.250048  0.003422      0.001
# 156  CH14-bin.1  environment     M_ibt_e   0.364152  0.004181      0.004
# 264  CH14-bin.1  environment    M_glyc_e   0.040648  0.000441      0.038
# 69   CH14-bin.1  environment   M_man1p_e   2.041594  0.007909      0.001
# 89   CH14-bin.1  environment     M_but_e   1.313491  0.015081      0.006
# 42   CH14-bin.1  environment   M_acald_e   3.670363  0.083318      0.009
# 61   CH14-bin.1  environment     M_for_e   2.497662  0.055482      0.035
# 218  CH14-bin.1  environment   M_gcald_e   0.114547  0.001907      1.000
# 174  CH14-bin.1  environment    M_4hba_e   0.302068  0.002433      0.922
# 113  CH14-bin.1  environment     M_thm_e   0.695146  0.002620      0.856
# 108  CH14-bin.1  environment     M_h2s_e   0.775365  0.022751      0.803
# 106  CH14-bin.1  environment      M_h2_e   0.798377  0.396060      0.947
# 38   CH14-bin.1  environment    M_etoh_e   4.184040  0.090823      0.289
# 7    CH14-bin.1  environment  M_xyl__D_e  22.974781  0.153033      0.192
# 15   CH14-bin.1  environment     M_co2_e  13.395651  0.304381      1.000
# 11   CH14-bin.1  environment      M_ac_e  17.460153  0.295715      0.997
#
#     community medium  mass_rate*frequency                  super_class
# 186      CD_X  SC1_X             0.000250  carboxylic acids and anions
# 156      CD_X  SC1_X             0.001457                  fatty acids
# 264      CD_X  SC1_X             0.001545                        other
# 69       CD_X  SC1_X             0.002042                        other
# 89       CD_X  SC1_X             0.007881  carboxylic acids and anions
# 42       CD_X  SC1_X             0.033033       alcohols and aldehydes
# 61       CD_X  SC1_X             0.087418  carboxylic acids and anions
# 218      CD_X  SC1_X             0.114547                        other
# 174      CD_X  SC1_X             0.278507                        other
# 113      CD_X  SC1_X             0.595045  nucleotides and derivatives
# 108      CD_X  SC1_X             0.622618                        gases
# 106      CD_X  SC1_X             0.756063                        gases
# 38       CD_X  SC1_X             1.209187       alcohols and aldehydes
# 7        CD_X  SC1_X             4.411158                simple sugars
# 15       CD_X  SC1_X            13.395651                        gases
# 11       CD_X  SC1_X            17.407773  carboxylic acids and anions

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.2")&(steadier_sample_pre.receiver=="environment")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor     receiver      compound  mass_rate      rate  frequency  \
# 222  CH14-bin.2  environment       M_h2s_e   0.100755  0.002956      0.042
# 151  CH14-bin.2  environment     M_ibtol_e   0.385402  0.004475      0.055
# 124  CH14-bin.2  environment       M_ppa_e   0.599597  0.008206      0.036
# 60   CH14-bin.2  environment     M_acald_e   2.570389  0.058348      0.012
# 109  CH14-bin.2  environment       M_but_e   0.773512  0.008881      0.042
# 115  CH14-bin.2  environment       M_co2_e   0.677833  0.015402      0.146
# 75   CH14-bin.2  environment  M_12ppd__R_e   1.609343  0.021149      0.105
# 35   CH14-bin.2  environment    M_xyl__D_e   4.502062  0.029988      0.102
# 57   CH14-bin.2  environment        M_co_e   2.828693  0.100988      0.891
# 29   CH14-bin.2  environment        M_ac_e   5.352757  0.090657      0.999
#
#     community medium  mass_rate*frequency                  super_class
# 222      CD_X  SC1_X             0.004232                        gases
# 151      CD_X  SC1_X             0.021197                        other
# 124      CD_X  SC1_X             0.021585  carboxylic acids and anions
# 60       CD_X  SC1_X             0.030845       alcohols and aldehydes
# 109      CD_X  SC1_X             0.032488  carboxylic acids and anions
# 115      CD_X  SC1_X             0.098964                        gases
# 75       CD_X  SC1_X             0.168981                        other
# 35       CD_X  SC1_X             0.459210                simple sugars
# 57       CD_X  SC1_X             2.520365                        gases
# 29       CD_X  SC1_X             5.347404  carboxylic acids and anions

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.4")&(steadier_sample_pre.receiver=="environment")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor     receiver  compound  mass_rate      rate  frequency  \
# 221  CH14-bin.4  environment   M_ppa_e   0.102970  0.001409      0.002
# 262  CH14-bin.4  environment  M_succ_e   0.041825  0.000360      0.139
# 273  CH14-bin.4  environment    M_h2_e   0.036922  0.018316      0.904
# 215  CH14-bin.4  environment   M_h2s_e   0.117768  0.003456      0.398
# 134  CH14-bin.4  environment   M_co2_e   0.503298  0.011436      1.000
# 110  CH14-bin.4  environment   M_for_e   0.762750  0.016943      0.723
# 98   CH14-bin.4  environment    M_ac_e   0.945529  0.016014      0.998
#
#     community medium  mass_rate*frequency                  super_class
# 221      CD_X  SC1_X             0.000206  carboxylic acids and anions
# 262      CD_X  SC1_X             0.005814  carboxylic acids and anions
# 273      CD_X  SC1_X             0.033378                        gases
# 215      CD_X  SC1_X             0.046871                        gases
# 134      CD_X  SC1_X             0.503298                        gases
# 110      CD_X  SC1_X             0.551468  carboxylic acids and anions
# 98       CD_X  SC1_X             0.943638  carboxylic acids and anions
