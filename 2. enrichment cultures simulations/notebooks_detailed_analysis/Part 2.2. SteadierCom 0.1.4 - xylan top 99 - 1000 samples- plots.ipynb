# %% [markdown]
# ## SteadierCom 0.1.4 samples1000

# %%
import pandas as pd

# %%
import sys
sys.path.append("../functions_steadiercom/")
sys.path.append("../functions/")
import steadiercom_samples_plotting
import steadiercom_samples_processing

# %%
# %load_ext autoreload
# %autoreload 2

# %%
SC1_X = pd.read_csv("../output_30_08_24/steadiercom_sample_0.1.3/results_1000/results_99_SC1_X.tsv",sep="\t")

# %%
steadier_sample = SC1_X.copy()
steadier_sample["mass_rate"] = steadier_sample["mass_rate"]*1000

# %%
steadier_sample = steadier_sample[(steadier_sample.rate>1e-6)].copy()
steadier_sample
# Out:
#            donor     receiver    compound  mass_rate      rate  frequency  \
# 0    environment    CH9-bin.0    M_xylb_e  67.717085  0.239924      1.000
# 1    environment    CH9-bin.6  M_xylan4_e  65.280081  0.090467      1.000
# 2      CH9-bin.0  environment      M_ac_e  60.327984  1.021748      1.000
# 3    environment    CH3-bin.2  M_xylan4_e  52.582889  0.072871      0.998
# 4      CH9-bin.6    CH9-bin.0  M_xyl__D_e  48.856680  0.325430      1.000
# ..           ...          ...         ...        ...       ...        ...
# 430    CH3-bin.1  environment   M_gcald_e   0.000079  0.000001      1.000
# 431   CH14-bin.0   CH14-bin.4      M_h2_e   0.000075  0.000037      0.095
# 432    CH9-bin.5  environment   M_acald_e   0.000071  0.000002      0.023
# 433   CH14-bin.0  environment   M_gcald_e   0.000065  0.000001      0.128
# 434    CH3-bin.1    CH3-bin.0     M_co2_e   0.000050  0.000001      0.002
#
#     community medium
# 0        CM_X  SC1_X
# 1        CM_X  SC1_X
# ...

# %% [markdown]
# ## CD_X

# %%
community_id="CD_X"

# %%
steadiercom_samples_plotting.combined_figure(steadier_sample,community_id,path = "Figures/circos_plots_2_1/1000_",move_legend=-0.2)

# %%
steadier_sample_pre = steadiercom_samples_processing.preprocessing_func(steadier_sample)

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.0") & (steadier_sample_pre.donor=="CH14-bin.1")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound  mass_rate      rate  frequency  \
# 284  CH14-bin.1  CH14-bin.0      M_h2_e   0.000030  0.014920      0.015
# 50   CH14-bin.1  CH14-bin.0     M_orn_e   0.003056  0.022948      0.001
# 110  CH14-bin.1  CH14-bin.0  M_rib__D_e   0.000774  0.005156      0.017
# 221  CH14-bin.1  CH14-bin.0   M_gcald_e   0.000113  0.001885      0.153
# 256  CH14-bin.1  CH14-bin.0     M_ura_e   0.000054  0.000480      0.427
# 254  CH14-bin.1  CH14-bin.0     M_gua_e   0.000055  0.000367      1.000
# 71   CH14-bin.1  CH14-bin.0    M_glyc_e   0.001825  0.019818      0.326
# 30   CH14-bin.1  CH14-bin.0  M_glyald_e   0.004556  0.050580      0.436
# 36   CH14-bin.1  CH14-bin.0  M_xyl__D_e   0.004410  0.029377      0.793
#
#     community medium  mass_rate*frequency                  super_class
# 284      CD_X  SC1_X         4.511326e-07                        gases
# 50       CD_X  SC1_X         3.055921e-06  amino acids and derivatives
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.0") & (steadier_sample_pre.donor=="CH14-bin.2")].sort_values(["donor","mass_rate*frequency"])
# Out:
#          donor    receiver    compound  mass_rate      rate  frequency  \
# 45  CH14-bin.2  CH14-bin.0  M_xyl__D_e   0.003514  0.023403      0.291
#
#    community medium  mass_rate*frequency    super_class
# 45      CD_X  SC1_X             0.001022  simple sugars

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.0") & (steadier_sample_pre.donor=="CH14-bin.4")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound     mass_rate      rate  frequency  \
# 400  CH14-bin.4  CH14-bin.0      M_h2_e  8.697849e-07  0.000431      0.008
# 189  CH14-bin.4  CH14-bin.0  M_lac__L_e  2.379338e-04  0.002671      0.161
#
#     community medium  mass_rate*frequency                  super_class
# 400      CD_X  SC1_X         6.958279e-09                        gases
# 189      CD_X  SC1_X         3.830734e-05  carboxylic acids and anions

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.2") & (steadier_sample_pre.donor=="CH14-bin.1")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound  mass_rate      rate  frequency  \
# 170  CH14-bin.1  CH14-bin.2  M_rib__D_e   0.000307  0.002045      0.001
# 360  CH14-bin.1  CH14-bin.2     M_h2s_e   0.000003  0.000085      0.727
# 231  CH14-bin.1  CH14-bin.2   M_anhgm_e   0.000086  0.000181      0.042
# 245  CH14-bin.1  CH14-bin.2     M_ura_e   0.000067  0.000597      0.802
# 246  CH14-bin.1  CH14-bin.2     M_gua_e   0.000067  0.000442      1.000
# 113  CH14-bin.1  CH14-bin.2  M_asp__D_e   0.000717  0.005426      0.914
# 39   CH14-bin.1  CH14-bin.2   M_acald_e   0.004029  0.091451      0.256
# 73   CH14-bin.1  CH14-bin.2     M_co2_e   0.001615  0.036694      0.706
# 43   CH14-bin.1  CH14-bin.2  M_xyl__D_e   0.003629  0.024170      0.365
#
#     community medium  mass_rate*frequency                  super_class
# 170      CD_X  SC1_X         3.070183e-07                simple sugars
# 360      CD_X  SC1_X         2.105783e-06                        gases
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.2") & (steadier_sample_pre.donor=="CH14-bin.0")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver   compound  mass_rate      rate  frequency  \
# 261  CH14-bin.0  CH14-bin.2  M_acald_e   0.000046  0.001052      0.031
# 183  CH14-bin.0  CH14-bin.2    M_gal_e   0.000262  0.001454      0.014
# 334  CH14-bin.0  CH14-bin.2    M_h2s_e   0.000008  0.000230      0.925
# 262  CH14-bin.0  CH14-bin.2    M_ura_e   0.000046  0.000409      0.304
# 164  CH14-bin.0  CH14-bin.2    M_co2_e   0.000329  0.007470      0.706
#
#     community medium  mass_rate*frequency                  super_class
# 261      CD_X  SC1_X             0.000001       alcohols and aldehydes
# 183      CD_X  SC1_X             0.000004                simple sugars
# 334      CD_X  SC1_X             0.000007                        gases
# 262      CD_X  SC1_X             0.000014  nucleotides and derivatives
# 164      CD_X  SC1_X             0.000232                        gases

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.2") & (steadier_sample_pre.donor=="CH14-bin.4")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver   compound     mass_rate      rate  frequency  \
# 419  CH14-bin.4  CH14-bin.2    M_h2s_e  3.812856e-07  0.000011      0.706
# 225  CH14-bin.4  CH14-bin.2  M_acald_e  1.058330e-04  0.002402      0.007
# 295  CH14-bin.4  CH14-bin.2    M_co2_e  2.497554e-05  0.000568      0.702
#
#     community medium  mass_rate*frequency             super_class
# 419      CD_X  SC1_X         2.691877e-07                   gases
# 225      CD_X  SC1_X         7.408307e-07  alcohols and aldehydes
# 295      CD_X  SC1_X         1.753283e-05                   gases

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.4") & (steadier_sample_pre.donor=="CH14-bin.0")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound     mass_rate      rate  frequency  \
# 398  CH14-bin.0  CH14-bin.4    M_thym_e  8.762367e-07  0.000007      0.001
# 427  CH14-bin.0  CH14-bin.4  M_mal__L_e  1.825381e-07  0.000001      0.007
# 351  CH14-bin.0  CH14-bin.4  M_ala__D_e  4.731480e-06  0.000053      0.001
# 431  CH14-bin.0  CH14-bin.4      M_h2_e  7.499204e-08  0.000037      0.095
# 275  CH14-bin.0  CH14-bin.4    M_g3pg_e  3.741468e-05  0.000153      0.002
# 391  CH14-bin.0  CH14-bin.4     M_h2s_e  1.071044e-06  0.000031      0.144
# 339  CH14-bin.0  CH14-bin.4     M_ura_e  6.679171e-06  0.000060      0.304
# 293  CH14-bin.0  CH14-bin.4   M_acald_e  2.527369e-05  0.000574      0.091
# 186  CH14-bin.0  CH14-bin.4  M_lac__L_e  2.491114e-04  0.002797      0.146
#
#     community medium  mass_rate*frequency                  super_class
# 398      CD_X  SC1_X         8.762367e-10  nucleotides and derivatives
# 427      CD_X  SC1_X         1.277766e-09  carboxylic acids and anions
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.4") & (steadier_sample_pre.donor=="CH14-bin.1")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver     compound     mass_rate      rate  frequency  \
# 390  CH14-bin.1  CH14-bin.4  M_istfrnB_e  1.109474e-06  0.000002      0.001
# 399  CH14-bin.1  CH14-bin.4     M_thym_e  8.762367e-07  0.000007      0.006
# 418  CH14-bin.1  CH14-bin.4      M_h2s_e  3.831017e-07  0.000011      0.118
# 412  CH14-bin.1  CH14-bin.4       M_h2_e  4.635700e-07  0.000230      0.175
# 195  CH14-bin.1  CH14-bin.4     M_etoh_e  2.115566e-04  0.004592      0.004
# 329  CH14-bin.1  CH14-bin.4      M_ura_e  9.737589e-06  0.000087      0.802
# 328  CH14-bin.1  CH14-bin.4      M_gua_e  9.760597e-06  0.000065      1.000
# 258  CH14-bin.1  CH14-bin.4   M_mal__L_e  4.931624e-05  0.000373      0.416
# 199  CH14-bin.1  CH14-bin.4   M_rib__D_e  2.021991e-04  0.001347      0.553
# 212  CH14-bin.1  CH14-bin.4   M_asp__D_e  1.332052e-04  0.001008      0.971
# 128  CH14-bin.1  CH14-bin.4   M_xyl__D_e  5.601365e-04  0.003731      0.774
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.receiver=="CH14-bin.4") & (steadier_sample_pre.donor=="CH14-bin.2")].sort_values(["donor","mass_rate*frequency"])
# Out:
#           donor    receiver    compound     mass_rate      rate  frequency  \
# 426  CH14-bin.2  CH14-bin.4     M_h2s_e  1.885008e-07  0.000006      0.006
# 232  CH14-bin.2  CH14-bin.4  M_rib__D_e  8.573260e-05  0.000571      0.001
# 219  CH14-bin.2  CH14-bin.4  M_asp__D_e  1.174700e-04  0.000889      0.020
# 188  CH14-bin.2  CH14-bin.4   M_cell4_e  2.423670e-04  0.000364      0.014
# 306  CH14-bin.2  CH14-bin.4  M_mal__L_e  2.103303e-05  0.000159      0.574
# 123  CH14-bin.2  CH14-bin.4   M_acald_e  5.932441e-04  0.013467      0.124
# 142  CH14-bin.2  CH14-bin.4  M_xyl__D_e  4.651413e-04  0.003098      0.275
#
#     community medium  mass_rate*frequency                  super_class
# 426      CD_X  SC1_X         1.131005e-09                        gases
# 232      CD_X  SC1_X         8.573260e-08                simple sugars
# 219      CD_X  SC1_X         2.349399e-06  amino acids and derivatives
# 188      CD_X  SC1_X         3.393138e-06             oligosaccharides
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.0")&(steadier_sample_pre.receiver=="environment")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor     receiver    compound     mass_rate      rate  frequency  \
# 433  CH14-bin.0  environment   M_gcald_e  6.476837e-08  0.000001      0.128
# 324  CH14-bin.0  environment   M_acald_e  1.077324e-05  0.000245      0.006
# 163  CH14-bin.0  environment     M_pta_e  3.332782e-04  0.003296      0.005
# 94   CH14-bin.0  environment  M_lac__L_e  9.989730e-04  0.011216      0.005
# 226  CH14-bin.0  environment      M_h2_e  1.040545e-04  0.051619      0.474
# 95   CH14-bin.0  environment     M_hxa_e  9.960225e-04  0.008650      0.078
# 137  CH14-bin.0  environment     M_but_e  4.885079e-04  0.005609      0.516
# 93   CH14-bin.0  environment     M_h2s_e  1.025404e-03  0.030087      1.000
# 55   CH14-bin.0  environment     M_co2_e  2.739219e-03  0.062242      1.000
# 47   CH14-bin.0  environment      M_ac_e  3.276292e-03  0.055489      0.997
#
#     community medium  mass_rate*frequency                  super_class
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.1")&(steadier_sample_pre.receiver=="environment")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor     receiver    compound  mass_rate      rate  frequency  \
# 182  CH14-bin.1  environment     M_ppa_e   0.000265  0.003630      0.001
# 97   CH14-bin.1  environment   M_ibtol_e   0.000984  0.011427      0.001
# 91   CH14-bin.1  environment   M_man1p_e   0.001069  0.004140      0.001
# 102  CH14-bin.1  environment   M_acald_e   0.000859  0.019498      0.008
# 109  CH14-bin.1  environment     M_but_e   0.000778  0.008928      0.009
# 99   CH14-bin.1  environment     M_ibt_e   0.000914  0.010499      0.010
# 60   CH14-bin.1  environment     M_for_e   0.002350  0.052193      0.036
# 220  CH14-bin.1  environment   M_gcald_e   0.000117  0.001949      1.000
# 174  CH14-bin.1  environment    M_4hba_e   0.000298  0.002397      0.932
# 141  CH14-bin.1  environment     M_h2s_e   0.000466  0.013673      0.785
# 116  CH14-bin.1  environment     M_thm_e   0.000687  0.002590      0.862
# 107  CH14-bin.1  environment      M_h2_e   0.000792  0.393004      0.954
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.2")&(steadier_sample_pre.receiver=="environment")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor     receiver      compound  mass_rate      rate  frequency  \
# 205  CH14-bin.2  environment       M_h2s_e   0.000159  0.004670      0.034
# 40   CH14-bin.2  environment     M_acald_e   0.003979  0.090317      0.007
# 143  CH14-bin.2  environment     M_ibtol_e   0.000462  0.005366      0.064
# 92   CH14-bin.2  environment       M_but_e   0.001026  0.011781      0.032
# 118  CH14-bin.2  environment       M_ppa_e   0.000633  0.008657      0.056
# 105  CH14-bin.2  environment       M_co2_e   0.000816  0.018532      0.148
# 74   CH14-bin.2  environment  M_12ppd__R_e   0.001600  0.021031      0.103
# 42   CH14-bin.2  environment    M_xyl__D_e   0.003779  0.025170      0.105
# 54   CH14-bin.2  environment        M_co_e   0.002813  0.100428      0.898
# 27   CH14-bin.2  environment        M_ac_e   0.005355  0.090689      0.997
#
#     community medium  mass_rate*frequency                  super_class
# 205      CD_X  SC1_X             0.000005                        gases
# ...

# %%
steadier_sample_pre[(steadier_sample_pre.donor=="CH14-bin.4")&(steadier_sample_pre.receiver=="environment")].sort_values(["receiver","mass_rate*frequency"])
# Out:
#           donor     receiver    compound  mass_rate      rate  frequency  \
# 341  CH14-bin.4  environment   M_acald_e   0.000006  0.000145      0.002
# 392  CH14-bin.4  environment    M_fald_e   0.000001  0.000035      0.044
# 387  CH14-bin.4  environment    M_meoh_e   0.000001  0.000042      0.366
# 206  CH14-bin.4  environment  M_lac__L_e   0.000158  0.001776      0.009
# 287  CH14-bin.4  environment    M_succ_e   0.000029  0.000246      0.486
# 298  CH14-bin.4  environment      M_h2_e   0.000024  0.012153      0.618
# 260  CH14-bin.4  environment     M_h2s_e   0.000047  0.001391      0.762
# 193  CH14-bin.4  environment     M_for_e   0.000215  0.004771      0.335
# 146  CH14-bin.4  environment    M_etoh_e   0.000441  0.009578      0.226
# 196  CH14-bin.4  environment     M_co2_e   0.000206  0.004689      0.996
# 111  CH14-bin.4  environment      M_ac_e   0.000768  0.013006      0.996
#
#     community medium  mass_rate*frequency                  super_class
# ...

# %% [markdown]
# ## CM_X

# %%
community_id="CM_X"

# %%
steadiercom_samples_plotting.combined_figure(steadier_sample,community_id,path = "Figures/circos_plots_2_1/1000_",move_legend=-0.2)

# %% [markdown]
# ## M_X

# %%
community_id="M_X"

# %%
steadiercom_samples_plotting.combined_figure(steadier_sample,community_id,path = "Figures/circos_plots_2_1/1000_",move_legend=-0.2)
