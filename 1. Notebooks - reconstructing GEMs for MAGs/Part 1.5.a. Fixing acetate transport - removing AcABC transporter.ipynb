# %% [markdown]
# ### Changing acetate transporters.

# %%
import reframed
import pandas as pd
import numpy as np

import seaborn as sns

import os
import json

import copy

from reframed.io.sbml import parse_gpr_rule
import functions.general_functions as general_func

# %% [markdown]
# #### Load data

# %% [raw]
# all_mags_paper = pd.read_excel("input/files_from_fairdomhub/All_Mags_for_paper_analysis.xlsx",sheet_name="Coverage")
# all_mags_paper.set_index("MAG",inplace=True)
# all_mags_paper.head(2)

# %%
all_mags_paper = general_func.read_allmags_data()
all_mags_paper.head(2)
# Out:
#                        Source Substrate  Completeness (%)  Contamination (%)  \
# MAG
# CH14-bin.1  Compost_Digestate     Xylan             99.37               0.32
# CH14-bin.2  Compost_Digestate     Xylan             99.37               0.63
#
#               Domain      Phylum       Class           Order           Family  \
# MAG
# CH14-bin.1  Bacteria  Firmicutes  Clostridia  Lachnospirales  Lachnospiraceae
# CH14-bin.2  Bacteria  Firmicutes  Clostridia  Lachnospirales  Lachnospiraceae
#
#                     Genus                    Species  Genome size (bp)  \
# MAG
# CH14-bin.1   Lacrimispora  Lacrimispora amygdalina_A         5147597.0
# CH14-bin.2  Robinsoniella   Robinsoniella peoriensis         5647052.0
#
#             Scaffolds       N50  CDS prediction (DRAM)     Column1  \
# MAG
# CH14-bin.1       48.0  197896.0                 4902.0  CH14-bin.1
# CH14-bin.2       70.0  172899.0                 4618.0  CH14-bin.2
#
#             new_coverage
# MAG
# CH14-bin.1     54.707294
# CH14-bin.2     18.831114

# %%
with open("output/relevant_MAGs_99.txt") as text_file:
    relevant_MAGs = text_file.read().split("\n")

relevant_MAGs = [string.replace("\t","") for string in relevant_MAGs]

# %% [markdown]
# #### Load models

# %%
GEMs_dict = {}

directory = os.fsencode("output/GEMs/GEMs_adapt_media/")

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)

    GEMs_dict[filename[:-4]]= reframed.load_cbmodel("output/GEMs/GEMs_adapt_media/"+filename)
# Out:
# CH7-bin.18.xml
# CH15-bin.7.xml
# CH13-bin.0.xml
# CH1-bin.4.xml
# CH13-bin.1.xml
# CH13-bin.11.xml
# CH15-bin.6.xml
# CH7-bin.2.xml
# CH13-bin.13.xml
# CH1-bin.10.xml
# CH1-bin.6.xml
# CH13-bin.2.xml
# CH13-bin.12.xml
# CH15-bin.5.xml
# CH7-bin.1.xml
# CH15-bin.1.xml
# CH1-bin.3.xml
# CH13-bin.17.xml
# CH15-bin.0.xml
# CH7-bin.4.xml
# CH7-bin.23.xml
# CH7-bin.6.xml
# CH15-bin.22.xml
# CH15-bin.2.xml
# CH1-bin.1.xml
# CH13-bin.4.xml
# CH13-bin.14.xml
# CH15-bin.23.xml
# CH7-bin.20.xml
# CH8-bin.8.xml
# CH8-bin.9.xml
# CH8-bin.25.xml
# CH14-bin.4.xml
# CH14-bin.1.xml
# CH8-bin.21.xml
# CH14-bin.2.xml
# CH8-bin.22.xml
# CH8-bin.2.xml
# CH8-bin.29.xml
# CH8-bin.7.xml
# CH8-bin.6.xml
# CH3-bin.2.xml
# CH8-bin.14.xml
# CH8-bin.16.xml
# CH3-bin.0.xml
# CH8-bin.5.xml
# CH3-bin.1.xml
# CH8-bin.17.xml
# CH7-bin.11.xml
# CH9-bin.1.xml
# CH15-bin.12.xml
# CH13-bin.25.xml
# CH15-bin.13.xml
# CH9-bin.0.xml
# CH7-bin.12.xml
# CH9-bin.2.xml
# CH7-bin.9.xml
# CH15-bin.10.xml
# CH7-bin.8.xml
# CH7-bin.13.xml
# CH7-bin.17.xml
# CH15-bin.8.xml
# CH15-bin.15.xml
# CH7-bin.16.xml
# CH9-bin.6.xml
# CH9-bin.4.xml
# CH15-bin.17.xml
# CH1-bin.8.xml
# CH1-bin.9.xml
# CH15-bin.16.xml
# CH7-bin.15.xml
# CH9-bin.5.xml

# %% [markdown]
# ## Find acetate producers/consumers

# %% [markdown]
# #### Find which models has GPRs for producing acetate through phosphotransacetylase(R_PTAr) and acetate kinase (R_ACKr)

# %%
has_enzymes_for_acetate = {}
for MAG in GEMs_dict.keys():
    
    has_enzyme = []
    if "R_ACKr" in GEMs_dict[MAG].reactions:
        if GEMs_dict[MAG].reactions["R_ACKr"].gpr!=None:
            has_enzyme.append("R_ACKr")
    if "R_PTAr" in GEMs_dict[MAG].reactions:
        
        if GEMs_dict[MAG].reactions["R_PTAr"].gpr!=None:
            has_enzyme.append("R_PTAr")
    
    has_enzymes_for_acetate[MAG]= len(has_enzyme)==2

# %%
has_enzymes_for_acetate_MAGs = list(pd.Series(has_enzymes_for_acetate)[pd.Series(has_enzymes_for_acetate)].index)

# %% [markdown]
# #### Find hits on the ACt2r protein from the TCDB database

# %%
ACt2r_MAGs = []

ACt2r_MAGs_data = []
for filename in os.listdir("transporters/"):
    
    if filename.endswith(".tsv"):

        transport= pd.read_csv("transporters/"+filename,sep="\t",header=None)
        transport.columns = ["query acc.ver", "subject acc.ver", "% identity", "alignment length", "mismatches", "gap opens", "q. start", "q. end", "s. start", "s. end", "evalue", "bit score"]
        transport.reset_index(inplace=True)
        
        if transport.shape[0]>1:
            
            transport.sort_values(by="evalue",ascending=True,inplace=True)
            transport.reset_index(inplace=True)
            
            query = transport.loc[0,"query acc.ver"]
            gene = transport.loc[0,"subject acc.ver"]
            best_evalue = transport.loc[0,"evalue"]
            bit_score = transport.loc[0,"bit score"]
            
            if best_evalue<1e-5 and bit_score>20:
                if "2.A.1.13.1" in query:
                    ACt2r_MAGs.append(filename[:-4])
                    
                    ACt2r_MAGs_data.append((filename[:-4],gene,best_evalue,bit_score,"2.A.1.13.1"))

                elif "2.A.21.7.3" in query: 
                    ACt2r_MAGs.append(filename[:-4])
                    ACt2r_MAGs_data.append((filename[:-4],gene,best_evalue,bit_score,"2.A.21.7.3"))

# %%
ACt2r_MAGs_df = pd.DataFrame(ACt2r_MAGs_data,columns=["MAG","gene","evalue","bit_score","TCDB_id"]).sort_values("evalue")
ACt2r_MAGs_df.set_index("MAG",inplace=True)
ACt2r_MAGs_df
# Out:
#                  gene         evalue  bit_score     TCDB_id
# MAG
# CH15-bin.17   gene545  4.900000e-157      456.0  2.A.21.7.3
# CH13-bin.1    gene374  4.910000e-157      456.0  2.A.21.7.3
# CH7-bin.16   gene2185  8.200000e-156      452.0  2.A.21.7.3
# CH7-bin.4    gene3341  4.480000e-153      445.0  2.A.21.7.3
# CH8-bin.25   gene3105  2.220000e-151      441.0  2.A.21.7.3
# CH1-bin.9     gene769  1.280000e-150      439.0  2.A.21.7.3
# CH15-bin.6   gene1704  1.430000e-142      420.0  2.A.21.7.3
# CH1-bin.1     gene727   3.590000e-56      191.0  2.A.21.7.3
# CH14-bin.2   gene1003   9.490000e-23       99.0  2.A.21.7.3
# CH9-bin.1    gene3888   1.190000e-22       99.0  2.A.21.7.3
# CH13-bin.10  gene2510   4.490000e-19       87.0  2.A.21.7.3
# CH9-bin.8       gene1   1.140000e-18       84.3  2.A.1.13.1
# CH15-bin.18   gene948   2.010000e-17       82.4  2.A.21.7.3
# CH13-bin.14  gene5876   2.620000e-17       82.4  2.A.21.7.3
# CH7-bin.11   gene2382   4.360000e-17       80.5  2.A.21.7.3
# CH8-bin.2     gene979   4.580000e-17       80.5  2.A.21.7.3
# CH8-bin.12    gene529   5.030000e-17       80.1  2.A.21.7.3
# CH8-bin.11   gene2414   8.090000e-17       79.7  2.A.21.7.3
# CH8-bin.4      gene68   8.480000e-17       78.6  2.A.1.13.1
# CH8-bin.14    gene546   9.540000e-17       79.7  2.A.21.7.3
# CH13-bin.0   gene2567   1.030000e-16       79.3  2.A.21.7.3
# CH7-bin.24    gene385   6.930000e-16       75.5  2.A.1.13.1
# CH7-bin.13   gene2195   1.170000e-15       75.9  2.A.21.7.3
# CH13-bin.4   gene2613   1.580000e-15       75.9  2.A.21.7.3
# CH15-bin.1   gene2599   1.620000e-15       75.9  2.A.21.7.3
# CH8-bin.16   gene1114   2.510000e-15       75.1  2.A.21.7.3
# CH13-bin.13   gene458   2.780000e-15       74.7  2.A.21.7.3
# CH8-bin.9     gene614   3.530000e-15       73.9  2.A.21.7.3
# CH3-bin.1    gene4869   3.850000e-15       75.1  2.A.21.7.3
# CH15-bin.23  gene1853   7.300000e-15       73.6  2.A.21.7.3
# CH8-bin.27    gene588   7.450000e-15       73.6  2.A.21.7.3
# CH7-bin.20    gene898   2.310000e-14       70.9  2.A.1.13.1
# CH3-bin.2    gene2757   2.650000e-14       72.4  2.A.21.7.3
# CH14-bin.1   gene1344   6.140000e-14       71.2  2.A.21.7.3
# CH13-bin.2   gene1742   6.680000e-14       70.9  2.A.21.7.3
# CH7-bin.8    gene2703   1.350000e-13       69.7  2.A.21.7.3
# CH7-bin.15   gene1972   3.030000e-13       68.6  2.A.21.7.3
# CH1-bin.0    gene2609   3.480000e-13       68.2  2.A.21.7.3
# CH15-bin.7    gene621   3.000000e-12       65.1  2.A.21.7.3
# CH13-bin.25   gene855   3.060000e-12       65.1  2.A.21.7.3
# CH1-bin.4    gene2269   8.890000e-12       63.2  2.A.1.13.1
# CH13-bin.20  gene1181   4.790000e-11       61.2  2.A.21.7.3
# CH15-bin.10    gene75   7.650000e-11       60.8  2.A.21.7.3
# CH7-bin.21   gene1580   1.220000e-10       60.1  2.A.21.7.3
# CH8-bin.0    gene1211   1.460000e-10       58.5  2.A.1.13.1
# CH13-bin.16   gene888   1.740000e-10       58.9  2.A.21.7.3
# CH7-bin.9    gene1470   4.890000e-10       58.5  2.A.21.7.3
# CH1-bin.8    gene2827   1.340000e-08       54.3  2.A.21.7.3
# CH13-bin.24   gene534   2.740000e-08       51.6  2.A.1.13.1
# CH7-bin.25    gene808   3.460000e-07       48.9  2.A.21.7.3
# CH8-bin.17     gene51   3.780000e-07       48.9  2.A.21.7.3
# CH15-bin.0   gene1303   6.750000e-07       48.1  2.A.21.7.3
# CH13-bin.17   gene572   8.200000e-07       47.8  2.A.21.7.3
# CH8-bin.5    gene1101   8.840000e-07       47.8  2.A.21.7.3
# CH15-bin.13  gene1023   4.300000e-06       45.4  2.A.1.13.1

# %% [markdown]
# ### Add acetate transport
#
# Two different conditions.
#
# 1. The MAG has a hit in the TCDB database -> add reversible reaction
# 2. The MAG has a hit for the enzymes in acetate production -> add only producing reaction

# %%
GEMs_dict2 = {}

for MAG,model in GEMs_dict.items():
    model_copy = model.copy()
    
    if "R_Acabc" in model_copy.reactions.keys(): 
        model_copy.remove_reaction("R_Acabc")
      
    if "R_ACt2r" in model_copy.reactions.keys():
        model_copy.remove_reaction("R_ACt2r")
        
    if MAG in ACt2r_MAGs_df.index.values:
        model_copy.add_reaction_from_str("R_ACt2r: M_ac_c + M_h_c --> M_ac_e + M_h_e")
        model_copy.reversible=True
        model_copy.lb=-1000
        
        GPR = parse_gpr_rule(ACt2r_MAGs_df.loc[MAG,"gene"])
        model_copy.set_gpr_association("R_ACt2r",GPR)
        
        
    elif has_enzymes_for_acetate_MAGs:
        model_copy.add_reaction_from_str("R_ACt2r: M_ac_c + M_h_c --> M_ac_e + M_h_e")
        
    GEMs_dict2[MAG]=model_copy

# %% [markdown]
# ### Look for energy generating cycles

# %%
import functions.EGC as EGC

# %%
for MAG,model in GEMs_dict2.items():
    print(MAG)
    EGC.EGC_identifier(model,print_results=False)
# Out:
# CH7-bin.18
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-03-14
# There are NO energy producing cycles in the model
# CH15-bin.7
# There are NO energy producing cycles in the model
# CH13-bin.0
# There are NO energy producing cycles in the model
# CH1-bin.4
# There are NO energy producing cycles in the model
# CH13-bin.1
# There are NO energy producing cycles in the model
# CH13-bin.11
# There are NO energy producing cycles in the model
# CH15-bin.6
# There are NO energy producing cycles in the model
# CH7-bin.2
# There are NO energy producing cycles in the model
# CH13-bin.13
# There are NO energy producing cycles in the model
# CH1-bin.10
# There are NO energy producing cycles in the model
# CH1-bin.6
# There are NO energy producing cycles in the model
# CH13-bin.2
# There are NO energy producing cycles in the model
# CH13-bin.12
# There are NO energy producing cycles in the model
# CH15-bin.5
# There are NO energy producing cycles in the model
# CH7-bin.1
# There are NO energy producing cycles in the model
# CH15-bin.1
# There are NO energy producing cycles in the model
# CH1-bin.3
# There are NO energy producing cycles in the model
# CH13-bin.17
# There are NO energy producing cycles in the model
# CH15-bin.0
# There are NO energy producing cycles in the model
# CH7-bin.4
# There are NO energy producing cycles in the model
# CH7-bin.23
# There are NO energy producing cycles in the model
# CH7-bin.6
# There are NO energy producing cycles in the model
# CH15-bin.22
# There are NO energy producing cycles in the model
# CH15-bin.2
# There are NO energy producing cycles in the model
# CH1-bin.1
# There are NO energy producing cycles in the model
# CH13-bin.4
# There are NO energy producing cycles in the model
# CH13-bin.14
# There are NO energy producing cycles in the model
# CH15-bin.23
# There are NO energy producing cycles in the model
# CH7-bin.20
# There are NO energy producing cycles in the model
# CH8-bin.8
# There are NO energy producing cycles in the model
# CH8-bin.9
# There are NO energy producing cycles in the model
# CH8-bin.25
# There are NO energy producing cycles in the model
# CH14-bin.4
# There are NO energy producing cycles in the model
# CH14-bin.1
# There are NO energy producing cycles in the model
# CH8-bin.21
# There are NO energy producing cycles in the model
# CH14-bin.2
# There are NO energy producing cycles in the model
# CH8-bin.22
# There are NO energy producing cycles in the model
# CH8-bin.2
# There are NO energy producing cycles in the model
# CH8-bin.29
# There are NO energy producing cycles in the model
# CH8-bin.7
# There are NO energy producing cycles in the model
# CH8-bin.6
# There are NO energy producing cycles in the model
# CH3-bin.2
# There are NO energy producing cycles in the model
# CH8-bin.14
# There are NO energy producing cycles in the model
# CH8-bin.16
# There are NO energy producing cycles in the model
# CH3-bin.0
# There are NO energy producing cycles in the model
# CH8-bin.5
# There are NO energy producing cycles in the model
# CH3-bin.1
# There are NO energy producing cycles in the model
# CH8-bin.17
# There are NO energy producing cycles in the model
# CH7-bin.11
# There are NO energy producing cycles in the model
# CH9-bin.1
# There are NO energy producing cycles in the model
# CH15-bin.12
# There are NO energy producing cycles in the model
# CH13-bin.25
# There are NO energy producing cycles in the model
# CH15-bin.13
# There are NO energy producing cycles in the model
# CH9-bin.0
# There are NO energy producing cycles in the model
# CH7-bin.12
# There are NO energy producing cycles in the model
# CH9-bin.2
# There are NO energy producing cycles in the model
# CH7-bin.9
# There are NO energy producing cycles in the model
# CH15-bin.10
# There are NO energy producing cycles in the model
# CH7-bin.8
# There are NO energy producing cycles in the model
# CH7-bin.13
# There are NO energy producing cycles in the model
# CH7-bin.17
# There are NO energy producing cycles in the model
# CH15-bin.8
# There are NO energy producing cycles in the model
# CH15-bin.15
# There are NO energy producing cycles in the model
# CH7-bin.16
# There are NO energy producing cycles in the model
# CH9-bin.6
# There ARE energy producing cycles in the model
# CH9-bin.4
# There are NO energy producing cycles in the model
# CH15-bin.17
# There are NO energy producing cycles in the model
# CH1-bin.8
# There are NO energy producing cycles in the model
# CH1-bin.9
# There are NO energy producing cycles in the model
# CH15-bin.16
# There are NO energy producing cycles in the model
# CH7-bin.15
# There are NO energy producing cycles in the model
# CH9-bin.5
# There ARE energy producing cycles in the model

# %%
model_uni = reframed.load_cbmodel("/Users/idunmariaburgos/universal_model_extension/output/universe_bacteria.xml")

# %%
EGC.EGC_identifier(model_uni,print_results=True)
# Out:
# There are NO energy producing cycles in the model for R_ATPM
# There are NO energy producing cycles in the model for R_CTPM
# There are NO energy producing cycles in the model for R_GTPM
# There are NO energy producing cycles in the model for R_UTPM
# There are NO energy producing cycles in the model for R_ITPM
# There are NO energy producing cycles in the model for R_nadhM
# There are NO energy producing cycles in the model for R_nadphM
# There are NO energy producing cycles in the model for R_fadh2M
# There are NO energy producing cycles in the model for R_fmnh2M
# There are NO energy producing cycles in the model for R_q8h2M
# There are NO energy producing cycles in the model for R_mql8M
# There are NO energy producing cycles in the model for R_dmmql8M
# There are NO energy producing cycles in the model for R_accoaM
# There are NO energy producing cycles in the model for R_gluM
# There are NO energy producing cycles in the model for R_protonM
# There are NO energy producing cycles in the model for R_ferredoxinM
# There are NO energy producing cycles in the model
# {}

# %%
EGC_results = EGC.EGC_identifier(GEMs_dict2["CH9-bin.5"],print_results=True)
set.intersection(*map(set,[[value[0] for value in values] for source,values in EGC_results.items()]))
# Out:
# There are energy producing cycles in the model for R_ATPM
# 	R_ALAD_L: 1000.0
# 	R_ATPS4rpp: 1000.0
# 	R_CYTBO3_4pp: 1000.0
# 	R_GLYCLTDx: 1000.0
# 	R_GLYCTO2: 1000.0
# 	R_ATPM: 1000.0
# 	R_CAT: 1000.0
# 	R_PDYXPT_c: 1000.0
# 	R_PYDXO: 1000.0
# There are energy producing cycles in the model for R_CTPM
# 	R_ALAD_L: 1000.0
# 	R_ATPS4rpp: 1000.0
# 	R_CYTBO3_4pp: 1000.0
# 	R_CYTK2: 1000.0
# 	R_CYTK2_1: -1000.0
# 	R_GLYCLTDx: 1000.0
# 	R_GLYCTO2: 1000.0
# 	R_CAT: 1000.0
# 	R_PDYXPT_c: 1000.0
# 	R_PYDXO: 1000.0
# 	R_CTPM: 1000.0
# There are energy producing cycles in the model for R_GTPM
# 	R_ADOCBIK: 1000.0
# 	R_ALAD_L: 1000.0
# 	R_ATPS4rpp: 1000.0
# 	R_CYTBO3_4pp: 1000.0
# 	R_GDOCBIK: -1000.0
# 	R_GLYCLTDx: 1000.0
# 	R_GLYCTO2: 1000.0
# 	R_CAT: 1000.0
# 	R_PDYXPT_c: 1000.0
# 	R_PYDXO: 1000.0
# 	R_GTPM: 1000.0
# There are energy producing cycles in the model for R_UTPM
# 	R_ALAD_L: 1000.0
# 	R_ATPS4rpp: 1000.0
# 	R_CYTBO3_4pp: 1000.0
# 	R_GLYCLTDx: 1000.0
# 	R_GLYCTO2: 1000.0
# 	R_NDPK2: 1000.0
# 	R_CAT: 1000.0
# 	R_PDYXPT_c: 1000.0
# 	R_PYDXO: 1000.0
# 	R_UTPM: 1000.0
# There are energy producing cycles in the model for R_ITPM
# 	R_ALAD_L: 1000.0000000000002
# 	R_ATPS4rpp: 1000.0000000000002
# 	R_CYTBO3_4pp: 1000.0000000000002
# 	R_GLYCLTDx: 1000.0000000000002
# 	R_GLYCTO2: 1000.0000000000002
# 	R_NDPK9: 1000.0
# 	R_CAT: 1000.0000000000002
# 	R_PDYXPT_c: 1000.0000000000002
# 	R_PYDXO: 1000.0000000000002
# 	R_ITPM: 1000.0
# There are NO energy producing cycles in the model for R_nadhM
# There are NO energy producing cycles in the model for R_nadphM
# There are NO energy producing cycles in the model for R_fadh2M
# There are NO energy producing cycles in the model for R_fmnh2M
# There are NO energy producing cycles in the model for R_q8h2M
# There are NO energy producing cycles in the model for R_mql8M
# There are NO energy producing cycles in the model for R_dmmql8M
# There are energy producing cycles in the model for R_accoaM
# 	R_ACKr: 1000.0
# 	R_ALAD_L: 1000.0
# 	R_ATPS4rpp: 1000.0
# 	R_CYTBO3_4pp: 1000.0
# 	R_GLYCLTDx: 1000.0
# 	R_GLYCTO2: 1000.0
# 	R_PTAr: -1000.0
# 	R_CAT: 1000.0
# 	R_PDYXPT_c: 1000.0
# 	R_PYDXO: 1000.0
# 	R_accoaM: 1000.0
# There are NO energy producing cycles in the model for R_gluM
# There are energy producing cycles in the model for R_protonM
# 	R_ALAD_L: 250.0
# 	R_CYTBO3_4pp: 250.0
# 	R_GLYCLTDx: 250.0
# 	R_GLYCTO2: 250.0
# 	R_CAT: 250.0
# 	R_PDYXPT_c: 250.0
# 	R_PYDXO: 250.0
# 	R_protonM: 1000.0
# There are NO energy producing cycles in the model for R_ferredoxinM
# There ARE energy producing cycles in the model
# {'R_ALAD_L',
#  'R_CAT',
#  'R_CYTBO3_4pp',
#  'R_GLYCLTDx',
#  'R_GLYCTO2',
#  'R_PDYXPT_c',
#  'R_PYDXO'}

# %%
model_uni.reactions.R_PYDXO
# Out:
# R_PYDXO: 2.0 M_h2o_c + M_nh4_c + 0.5 M_o2_c + M_pydx_c <-> 2.0 M_h2o2_c + M_pydam_c [-inf, 0.0]

# %%
GEMs_dict2["CH9-bin.5"].reactions.R_PYDXO
# Out:
# R_PYDXO: 2.0 M_h2o_c + M_nh4_c + 0.5 M_o2_c + M_pydx_c <-> 2.0 M_h2o2_c + M_pydam_c

# %%
model_9_5 = reframed.load_cbmodel("output/GEMs/GEMs_adapt/CH9-bin.5.xml")

# %%
GEMs_dict2["CH9-bin.5"].remove_reactions(list(set(GEMs_dict2["CH9-bin.5"].reactions)-set(model_9_5.reactions)))

# %%
EGC_results = EGC.EGC_identifier(GEMs_dict2["CH9-bin.5"],print_results=False)
# Out:
# There are NO energy producing cycles in the model

# %%
EGC_results = EGC.EGC_identifier(GEMs_dict2["CH9-bin.6"],print_results=True)
set.intersection(*map(set,[[value[0] for value in values] for source,values in EGC_results.items()]))
# Out:
# There are energy producing cycles in the model for R_ATPM
# 	R_ATPS4rpp: 1000.0
# 	R_MG2tex: 2000.0
# 	R_MGt5: 2000.0
# 	R_ATPM: 1000.0
# 	R_MG2t3_2pp: 2000.0
# There are energy producing cycles in the model for R_CTPM
# 	R_ADK1: 1000.0
# 	R_ATPS4rpp: 2000.0
# 	R_MG2tex: 4000.0
# 	R_MGt5: 4000.0
# 	R_PPA: 1000.0
# 	R_PPDK: 1000.0
# 	R_PYK4: 1000.0
# 	R_MG2t3_2pp: 4000.0
# 	R_CTPM: 1000.0
# There are energy producing cycles in the model for R_GTPM
# 	R_ADK1: 1000.0
# 	R_ADK3: -1000.0
# 	R_ATPS4rpp: 1000.0
# 	R_MG2tex: 2000.0
# 	R_MGt5: 2000.0
# 	R_MG2t3_2pp: 2000.0
# 	R_GTPM: 1000.0
# There are energy producing cycles in the model for R_UTPM
# 	R_ADK1: 1000.0
# 	R_ATPS4rpp: 2000.0
# 	R_MG2tex: 4000.0
# 	R_MGt5: 4000.0
# 	R_PPA: 1000.0
# 	R_PPDK: 1000.0
# 	R_PYK2: 1000.0
# 	R_MG2t3_2pp: 4000.0
# 	R_UTPM: 1000.0
# There are energy producing cycles in the model for R_ITPM
# 	R_ADK1: 1000.0
# 	R_ADK4: -1000.0
# 	R_ATPS4rpp: 1000.0
# 	R_MG2tex: 2000.0
# 	R_MGt5: 2000.0
# 	R_MG2t3_2pp: 2000.0
# 	R_ITPM: 1000.0
# There are NO energy producing cycles in the model for R_nadhM
# There are NO energy producing cycles in the model for R_nadphM
# There are NO energy producing cycles in the model for R_fadh2M
# There are NO energy producing cycles in the model for R_fmnh2M
# There are NO energy producing cycles in the model for R_q8h2M
# There are NO energy producing cycles in the model for R_mql8M
# There are NO energy producing cycles in the model for R_accoaM
# There are NO energy producing cycles in the model for R_gluM
# There are energy producing cycles in the model for R_protonM
# 	R_MG2tex: 500.0
# 	R_MGt5: 500.0
# 	R_MG2t3_2pp: 500.0
# 	R_protonM: 1000.0
# There are NO energy producing cycles in the model for R_ferredoxinM
# There ARE energy producing cycles in the model
# {'R_MG2t3_2pp', 'R_MG2tex', 'R_MGt5'}

# %%
model_uni.reactions.R_MG2t3_2pp
# Out:
# R_MG2t3_2pp: 2.0 M_h_c + M_mg2_p <-> 2.0 M_h_p + M_mg2_c [-inf, 0.0]

# %%
GEMs_dict2["CH9-bin.6"].reactions.R_MG2t3_2pp
# Out:
# R_MG2t3_2pp: 2.0 M_h_c + M_mg2_p <-> 2.0 M_h_p + M_mg2_c

# %%
model_9_6 = reframed.load_cbmodel("output/GEMs/GEMs_adapt/CH9-bin.6.xml")

# %%
GEMs_dict2["CH9-bin.6"].remove_reactions(list(set(GEMs_dict2["CH9-bin.6"].reactions)-set(model_9_6.reactions)))

# %%
EGC.EGC_identifier(GEMs_dict2["CH9-bin.6"],print_results=False)
# Out:
# There are NO energy producing cycles in the model
# {}

# %%
GEMs_dict3 = {}
for MAG, model in GEMs_dict2.items():
    
    model_copy = model.copy()
    
    print(model_copy.get_metabolite_reactions("M_o2_e"))
    model_copy.remove_reactions(model_copy.get_metabolite_reactions("M_o2_e"))
    model_copy.remove_metabolite("M_o2_e")
    model_copy.remove_reaction("R_EX_o2_e")
    
    GEMs_dict3[MAG]=model_copy
# Out:
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/model.py:471: UserWarning: No such reaction R_EX_o2_e
#   warn(f"No such reaction {r_id}")
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']
# ['R_O2tex', 'R_EX_o2_e']

# %% [markdown]
# ### Save models

# %%
for MAG,model in GEMs_dict3.items():
    model.update()
    reframed.save_cbmodel(model,"output/GEMs/GEMs_adapt_media_ACt2r/"+MAG+".xml")
