# %% [markdown]
# # Analyzing GEMs from MAGs

# %%
import reframed
import pandas as pd
from sklearn.metrics.pairwise import pairwise_distances

# %%
import os

# %% [markdown]
# ## No constraints

# %%
directory = os 

directory = os.fsencode("output/GEMs/GEMs_no_constraints/")

GEMs_dict = {}
for file in os.listdir(directory):
    print(file)
    
    filename = os.fsdecode(file)
    if filename.endswith(".xml"): 
        print(filename)
        GEMs_dict[filename[:-4]]= reframed.load_cbmodel("output/GEMs/GEMs_no_constraints/"+filename)
        continue
    else:
        continue
# Out:
# b'CH1-bin.3.tsv'
# b'CH9-bin.8.xml'
# CH9-bin.8.xml
# b'CH7-bin.24.xml'
# CH7-bin.24.xml
# b'CH7-bin.18.xml'
# CH7-bin.18.xml
# b'CH13-bin.17.tsv'
# b'CH15-bin.7.xml'
# CH15-bin.7.xml
# b'CH15-bin.0.tsv'
# b'CH15-bin.20.tsv'
# b'CH7-bin.4.tsv'
# b'CH13-bin.10.xml'
# CH13-bin.10.xml
# b'CH7-bin.23.tsv'
# b'CH13-bin.0.xml'
# CH13-bin.0.xml
# b'CH1-bin.4.xml'
# CH1-bin.4.xml
# b'CH1-bin.5.xml'
# CH1-bin.5.xml
# b'CH13-bin.1.xml'
# CH13-bin.1.xml
# b'CH13-bin.11.xml'
# CH13-bin.11.xml
# b'CH15-bin.1.tsv'
# b'CH15-bin.6.xml'
# CH15-bin.6.xml
# b'CH13-bin.16.tsv'
# b'CH7-bin.2.xml'
# CH7-bin.2.xml
# b'CH13-bin.6.tsv'
# b'CH7-bin.25.xml'
# CH7-bin.25.xml
# b'CH1-bin.2.tsv'
# b'CH1-bin.0.tsv'
# b'CH13-bin.4.tsv'
# b'CH13-bin.14.tsv'
# b'CH15-bin.4.xml'
# CH15-bin.4.xml
# b'CH15-bin.18.xml'
# CH15-bin.18.xml
# b'CH15-bin.3.tsv'
# b'CH15-bin.23.tsv'
# b'CH13-bin.13.xml'
# CH13-bin.13.xml
# b'CH7-bin.20.tsv'
# b'CH1-bin.10.xml'
# CH1-bin.10.xml
# b'CH1-bin.7.xml'
# CH1-bin.7.xml
# ...

# %%
GEMs_stats = {}

for model_id, model in GEMs_dict.items():
    print(model_id)
    GEMs_stats[model_id]={"reactions":len(model.reactions.keys()),
                          "metabolites":len(model.metabolites.keys()),
                         "genes": len(model.genes.keys())}
# Out:
# CH9-bin.8
# CH7-bin.24
# CH7-bin.18
# CH15-bin.7
# CH13-bin.10
# CH13-bin.0
# CH1-bin.4
# CH1-bin.5
# CH13-bin.1
# CH13-bin.11
# CH15-bin.6
# CH7-bin.2
# CH7-bin.25
# CH15-bin.4
# CH15-bin.18
# CH13-bin.13
# CH1-bin.10
# CH1-bin.7
# CH1-bin.6
# CH13-bin.2
# CH13-bin.12
# CH15-bin.5
# CH7-bin.1
# CH15-bin.1
# CH13-bin.16
# CH13-bin.6
# CH1-bin.2
# CH1-bin.3
# CH13-bin.17
# CH15-bin.0
# CH15-bin.20
# CH7-bin.4
# CH7-bin.23
# CH7-bin.21
# CH7-bin.6
# CH15-bin.22
# CH15-bin.2
# CH1-bin.1
# CH1-bin.0
# CH13-bin.4
# CH13-bin.14
# CH15-bin.3
# CH15-bin.23
# CH7-bin.20
# CH8-bin.8
# CH8-bin.9
# CH8-bin.27
# CH8-bin.25
# CH14-bin.4
# CH8-bin.20
# CH14-bin.1
# CH8-bin.21
# CH14-bin.2
# CH8-bin.22
# CH8-bin.0
# CH8-bin.12
# CH8-bin.2
# CH8-bin.11
# CH8-bin.29
# CH8-bin.7
# CH8-bin.6
# CH3-bin.2
# CH8-bin.14
# CH8-bin.16
# CH3-bin.0
# CH8-bin.4
# CH8-bin.5
# CH3-bin.1
# CH8-bin.17
# CH7-bin.11
# CH9-bin.1
# CH15-bin.12
# CH13-bin.19
# CH13-bin.25
# CH13-bin.8
# CH13-bin.24
# CH15-bin.13
# ...

# %%
pd.DataFrame(GEMs_stats).transpose().sort_values(by="genes").plot(kind="hist",bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Soft constraints 0.5

# %%
directory = os 

directory = os.fsencode("output/GEMs/GEMs_soft_constraints_score_0.5/")

GEMs_soft_0_5_dict = {}
for file in os.listdir(directory):
    print(file)
    
    filename = os.fsdecode(file)
    if filename.endswith(".xml"): 
        print(filename)
        GEMs_soft_0_5_dict[filename[:-4]]= reframed.load_cbmodel("output/GEMs/GEMs_soft_constraints_score_0.5/"+filename)
        continue
    else:
        continue
# Out:
# b'CH1-bin.3.tsv'
# b'CH7-bin.18.xml'
# CH7-bin.18.xml
# b'CH13-bin.17.tsv'
# b'CH15-bin.7.xml'
# CH15-bin.7.xml
# b'CH15-bin.0.tsv'
# b'CH7-bin.4.tsv'
# b'CH7-bin.23.tsv'
# b'CH13-bin.0.xml'
# CH13-bin.0.xml
# b'CH1-bin.4.xml'
# CH1-bin.4.xml
# b'CH13-bin.1.xml'
# CH13-bin.1.xml
# b'CH13-bin.11.xml'
# CH13-bin.11.xml
# b'CH15-bin.1.tsv'
# b'CH15-bin.6.xml'
# CH15-bin.6.xml
# b'CH7-bin.2.xml'
# CH7-bin.2.xml
# b'CH13-bin.4.tsv'
# b'CH13-bin.14.tsv'
# b'CH15-bin.23.tsv'
# b'CH13-bin.13.xml'
# CH13-bin.13.xml
# b'CH7-bin.20.tsv'
# b'CH1-bin.7.xml'
# CH1-bin.7.xml
# b'CH1-bin.6.xml'
# CH1-bin.6.xml
# b'CH13-bin.2.xml'
# CH13-bin.2.xml
# b'CH13-bin.12.xml'
# CH13-bin.12.xml
# b'CH15-bin.22.tsv'
# b'CH15-bin.5.xml'
# CH15-bin.5.xml
# b'CH7-bin.1.xml'
# CH7-bin.1.xml
# b'CH13-bin.1.tsv'
# b'CH13-bin.11.tsv'
# b'CH15-bin.1.xml'
# CH15-bin.1.xml
# b'CH15-bin.6.tsv'
# b'CH7-bin.2.tsv'
# b'CH1-bin.3.xml'
# CH1-bin.3.xml
# b'CH7-bin.18.tsv'
# b'CH13-bin.17.xml'
# CH13-bin.17.xml
# ...

# %%
GEMs_soft_0_5_stats = {}

for model_id, model in GEMs_soft_0_5_dict.items():
    print(model_id)
    GEMs_soft_0_5_stats[model_id]={"reactions":len(model.reactions.keys()),
                          "metabolites":len(model.metabolites.keys()),
                         "genes": len(model.genes.keys())}
# Out:
# CH7-bin.18
# CH15-bin.7
# CH13-bin.0
# CH1-bin.4
# CH13-bin.1
# CH13-bin.11
# CH15-bin.6
# CH7-bin.2
# CH13-bin.13
# CH1-bin.7
# CH1-bin.6
# CH13-bin.2
# CH13-bin.12
# CH15-bin.5
# CH7-bin.1
# CH15-bin.1
# CH1-bin.3
# CH13-bin.17
# CH15-bin.0
# CH7-bin.4
# CH7-bin.23
# CH15-bin.22
# CH13-bin.4
# CH13-bin.14
# CH15-bin.23
# CH7-bin.20
# CH8-bin.8
# CH8-bin.9
# CH8-bin.25
# CH14-bin.1
# CH8-bin.21
# CH14-bin.2
# CH8-bin.22
# CH8-bin.2
# CH8-bin.7
# CH8-bin.6
# CH3-bin.2
# CH8-bin.14
# CH8-bin.16
# CH8-bin.4
# CH8-bin.5
# CH3-bin.1
# CH8-bin.17
# CH7-bin.11
# CH9-bin.1
# CH15-bin.12
# CH13-bin.25
# CH15-bin.13
# CH9-bin.0
# CH7-bin.12
# CH9-bin.2
# CH7-bin.9
# CH15-bin.10
# CH7-bin.8
# CH7-bin.13
# CH7-bin.17
# CH15-bin.8
# CH15-bin.15
# CH7-bin.16
# CH9-bin.6
# CH9-bin.4
# CH15-bin.17
# CH1-bin.8
# CH1-bin.9
# CH15-bin.16
# CH9-bin.5

# %%
pd.DataFrame(GEMs_soft_0_5_stats).transpose().sort_values(by="genes").plot(kind="hist",bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Soft constraints 0.1

# %%
directory = os 

directory = os.fsencode("output/GEMs/GEMs_soft_constraints_score_0.1/")

GEMs_soft_0_1_dict = {}
for file in os.listdir(directory):
    print(file)
    
    filename = os.fsdecode(file)
    if filename.endswith(".xml"): 
        print(filename)
        GEMs_soft_0_1_dict[filename[:-4]]= reframed.load_cbmodel("output/GEMs/GEMs_soft_constraints_score_0.1/"+filename)
        continue
    else:
        continue
# Out:
# b'CH1-bin.3.tsv'
# b'CH7-bin.18.xml'
# CH7-bin.18.xml
# b'CH13-bin.17.tsv'
# b'CH15-bin.7.xml'
# CH15-bin.7.xml
# b'CH15-bin.0.tsv'
# b'CH7-bin.4.tsv'
# b'CH7-bin.23.tsv'
# b'CH13-bin.0.xml'
# CH13-bin.0.xml
# b'CH1-bin.4.xml'
# CH1-bin.4.xml
# b'CH13-bin.1.xml'
# CH13-bin.1.xml
# b'CH13-bin.11.xml'
# CH13-bin.11.xml
# b'CH15-bin.1.tsv'
# b'CH15-bin.6.xml'
# CH15-bin.6.xml
# b'CH7-bin.2.xml'
# CH7-bin.2.xml
# b'CH13-bin.4.tsv'
# b'CH13-bin.14.tsv'
# b'CH15-bin.23.tsv'
# b'CH13-bin.13.xml'
# CH13-bin.13.xml
# b'CH7-bin.20.tsv'
# b'CH1-bin.7.xml'
# CH1-bin.7.xml
# b'CH1-bin.6.xml'
# CH1-bin.6.xml
# b'CH13-bin.2.xml'
# CH13-bin.2.xml
# b'CH13-bin.12.xml'
# CH13-bin.12.xml
# b'CH15-bin.22.tsv'
# b'CH15-bin.5.xml'
# CH15-bin.5.xml
# b'CH7-bin.1.xml'
# CH7-bin.1.xml
# b'CH13-bin.1.tsv'
# b'CH13-bin.11.tsv'
# b'CH15-bin.1.xml'
# CH15-bin.1.xml
# b'CH15-bin.6.tsv'
# b'CH7-bin.2.tsv'
# b'CH1-bin.3.xml'
# CH1-bin.3.xml
# b'CH7-bin.18.tsv'
# b'CH13-bin.17.xml'
# CH13-bin.17.xml
# ...

# %%
GEMs_soft_0_1_stats = {}

for model_id, model in c.items():
    print(model_id)
    GEMs_soft_0_1_stats[model_id]={"reactions":len(model.reactions.keys()),
                          "metabolites":len(model.metabolites.keys()),
                         "genes": len(model.genes.keys())}
# Out:
# CH7-bin.18
# CH15-bin.7
# CH13-bin.0
# CH1-bin.4
# CH13-bin.1
# CH13-bin.11
# CH15-bin.6
# CH7-bin.2
# CH13-bin.13
# CH1-bin.7
# CH1-bin.6
# CH13-bin.2
# CH13-bin.12
# CH15-bin.5
# CH7-bin.1
# CH15-bin.1
# CH1-bin.3
# CH13-bin.17
# CH15-bin.0
# CH7-bin.4
# CH7-bin.23
# CH15-bin.22
# CH13-bin.4
# CH13-bin.14
# CH15-bin.23
# CH7-bin.20
# CH8-bin.8
# CH8-bin.9
# CH8-bin.25
# CH14-bin.1
# CH8-bin.21
# CH14-bin.2
# CH8-bin.22
# CH8-bin.2
# CH8-bin.7
# CH8-bin.6
# CH3-bin.2
# CH8-bin.14
# CH8-bin.16
# CH8-bin.4
# CH8-bin.5
# CH3-bin.1
# CH8-bin.17
# CH7-bin.11
# CH9-bin.1
# CH15-bin.12
# CH13-bin.25
# CH15-bin.13
# CH9-bin.0
# CH7-bin.12
# CH9-bin.2
# CH7-bin.9
# CH15-bin.10
# CH7-bin.8
# CH7-bin.13
# CH7-bin.17
# CH15-bin.8
# CH7-bin.16
# CH9-bin.6
# CH9-bin.4
# CH15-bin.17
# CH1-bin.8
# CH1-bin.9
# CH15-bin.16
# CH9-bin.5

# %%
pd.DataFrame(GEMs_soft_0_1_stats).transpose().sort_values(by="genes").plot(kind="hist",bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Soft constraints 0.01

# %%
directory = os 

directory = os.fsencode("output/GEMs/GEMs_soft_constraints_score_0.01/")

GEMs_soft_0_0_1_dict = {}
for file in os.listdir(directory):
    print(file)
    
    filename = os.fsdecode(file)
    if filename.endswith(".xml"): 
        print(filename)
        GEMs_soft_0_0_1_dict[filename[:-4]]= reframed.load_cbmodel("output/GEMs/GEMs_soft_constraints_score_0.01/"+filename)
        continue
    else:
        continue
# Out:
# b'CH1-bin.3.tsv'
# b'CH7-bin.18.xml'
# CH7-bin.18.xml
# b'CH13-bin.17.tsv'
# b'CH15-bin.7.xml'
# CH15-bin.7.xml
# b'CH15-bin.0.tsv'
# b'CH7-bin.4.tsv'
# b'CH7-bin.23.tsv'
# b'CH13-bin.0.xml'
# CH13-bin.0.xml
# b'CH1-bin.4.xml'
# CH1-bin.4.xml
# b'CH13-bin.1.xml'
# CH13-bin.1.xml
# b'CH13-bin.11.xml'
# CH13-bin.11.xml
# b'CH15-bin.1.tsv'
# b'CH15-bin.6.xml'
# CH15-bin.6.xml
# b'CH7-bin.2.xml'
# CH7-bin.2.xml
# b'CH13-bin.4.tsv'
# b'CH13-bin.14.tsv'
# b'CH15-bin.18.xml'
# CH15-bin.18.xml
# b'CH15-bin.23.tsv'
# b'CH13-bin.13.xml'
# CH13-bin.13.xml
# b'CH7-bin.20.tsv'
# b'CH1-bin.7.xml'
# CH1-bin.7.xml
# b'CH1-bin.6.xml'
# CH1-bin.6.xml
# b'CH13-bin.2.xml'
# CH13-bin.2.xml
# b'CH13-bin.12.xml'
# CH13-bin.12.xml
# b'CH15-bin.22.tsv'
# b'CH15-bin.5.xml'
# CH15-bin.5.xml
# b'CH7-bin.1.xml'
# CH7-bin.1.xml
# b'CH13-bin.1.tsv'
# b'CH13-bin.11.tsv'
# b'CH15-bin.1.xml'
# CH15-bin.1.xml
# b'CH15-bin.6.tsv'
# b'CH7-bin.2.tsv'
# b'CH1-bin.3.xml'
# CH1-bin.3.xml
# b'CH7-bin.18.tsv'
# ...

# %%
GEMs_soft_0_0_1_stats = {}

for model_id, model in GEMs_soft_0_0_1_dict.items():
    print(model_id)
    GEMs_soft_0_0_1_stats[model_id]={"reactions":len(model.reactions.keys()),
                          "metabolites":len(model.metabolites.keys()),
                         "genes": len(model.genes.keys())}
# Out:
# CH7-bin.18
# CH15-bin.7
# CH13-bin.0
# CH1-bin.4
# CH13-bin.1
# CH13-bin.11
# CH15-bin.6
# CH7-bin.2
# CH15-bin.18
# CH13-bin.13
# CH1-bin.7
# CH1-bin.6
# CH13-bin.2
# CH13-bin.12
# CH15-bin.5
# CH7-bin.1
# CH15-bin.1
# CH1-bin.3
# CH13-bin.17
# CH15-bin.0
# CH7-bin.4
# CH7-bin.23
# CH15-bin.22
# CH13-bin.4
# CH13-bin.14
# CH15-bin.23
# CH7-bin.20
# CH8-bin.8
# CH8-bin.9
# CH8-bin.25
# CH14-bin.1
# CH8-bin.21
# CH14-bin.2
# CH8-bin.22
# CH8-bin.2
# CH8-bin.7
# CH8-bin.6
# CH3-bin.2
# CH8-bin.14
# CH8-bin.16
# CH8-bin.4
# CH8-bin.5
# CH3-bin.1
# CH8-bin.17
# CH7-bin.11
# CH9-bin.1
# CH15-bin.12
# CH13-bin.25
# CH15-bin.13
# CH9-bin.0
# CH7-bin.12
# CH9-bin.2
# CH7-bin.9
# CH15-bin.10
# CH7-bin.8
# CH7-bin.13
# CH7-bin.17
# CH15-bin.8
# CH7-bin.16
# CH9-bin.6
# CH9-bin.4
# CH15-bin.17
# CH1-bin.8
# CH1-bin.9
# CH15-bin.16
# CH9-bin.5

# %%
pd.DataFrame(GEMs_soft_0_0_1_stats).transpose().sort_values(by="genes").plot(kind="hist",bins=100)
# Out:
# <Axes: ylabel='Frequency'>
