# %% [markdown]
# # Studying difference in the models

# %%
import reframed
import pandas as pd
import numpy as np

import seaborn as sns

import os
import json

import copy

# %% [markdown]
# #### Load data

# %%
all_mags_paper = pd.read_excel("input/files_from_fairdomhub/All_Mags_for_paper_analysis.xlsx",sheet_name="Coverage")
all_mags_paper.set_index("MAG",inplace=True)
all_mags_paper.head(2)
# Out:
#                Source Substrate  Completeness (%)  Contamination (%)  \
# MAG
# CH3-bin.2   Marshland     Xylan             99.19               1.61
# CH9-bin.0  Cow_Manure     Xylan             99.03               2.82
#
#              Domain            Phylum          Class            Order  \
# MAG
# CH3-bin.2  Bacteria      Firmicutes_A     Clostridia    Clostridiales
# CH9-bin.0  Bacteria  Actinobacteriota  Actinomycetia  Actinomycetales
#
#                        Family            Genus                  Species  \
# MAG
# CH3-bin.2      Clostridiaceae      Clostridium  Clostridium sp000230835
# CH9-bin.0  Bifidobacteriaceae  Bifidobacterium                      NaN
#
#            Genome size (bp)  Scaffolds     N50  CDS prediction (DRAM)  \
# MAG
# CH3-bin.2           6175525         63  230012                   5840
# CH9-bin.0           2513253         38  128964                   2055
#
#            Coverage (%)
# MAG
# CH3-bin.2         74.31
# CH9-bin.0         65.10

# %%
with open("output/soft_constraints_v2/relevant_MAGs_99.txt") as text_file:
    relevant_MAGs = text_file.read().split("\n")

relevant_MAGs = [string.replace("\t","") for string in relevant_MAGs]

# %% [markdown]
# #### Load models

# %%
GEMs_adapt_media = {}

directory = os.fsencode("output/GEMs/GEMs_adapt_media/")

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)

    GEMs_adapt_media[filename[:-4]]= reframed.load_cbmodel("output/GEMs/GEMs_adapt_media/"+filename)
# Out:
# CH7-bin.18.xml
# CH15-bin.7.xml
# CH13-bin.0.xml
# CH1-bin.4.xml
# CH13-bin.1.xml
# CH13-bin.11.xml
# CH15-bin.6.xml
# CH7-bin.2.xml
# CH15-bin.18.xml
# CH13-bin.13.xml
# CH1-bin.7.xml
# CH1-bin.6.xml
# CH13-bin.2.xml
# CH13-bin.12.xml
# CH15-bin.5.xml
# CH7-bin.1.xml
# CH15-bin.1.xml
# CH1-bin.3.xml
# CH13-bin.17.xml
# CH15-bin.0.xml
# CH7-bin.4.xml
# CH7-bin.23.xml
# CH15-bin.22.xml
# CH13-bin.4.xml
# CH13-bin.14.xml
# CH15-bin.23.xml
# CH7-bin.20.xml
# CH8-bin.8.xml
# CH8-bin.9.xml
# CH8-bin.25.xml
# CH14-bin.1.xml
# CH8-bin.21.xml
# CH14-bin.2.xml
# CH8-bin.22.xml
# CH8-bin.2.xml
# CH8-bin.7.xml
# CH8-bin.6.xml
# CH3-bin.2.xml
# CH8-bin.14.xml
# CH8-bin.16.xml
# CH8-bin.4.xml
# CH8-bin.5.xml
# CH3-bin.1.xml
# CH8-bin.17.xml
# CH7-bin.11.xml
# CH9-bin.1.xml
# CH15-bin.12.xml
# CH13-bin.25.xml
# CH15-bin.13.xml
# CH9-bin.0.xml
# CH7-bin.12.xml
# CH9-bin.2.xml
# CH7-bin.9.xml
# CH15-bin.10.xml
# CH7-bin.8.xml
# CH7-bin.13.xml
# CH7-bin.17.xml
# CH15-bin.8.xml
# CH15-bin.15.xml
# CH7-bin.16.xml
# CH9-bin.6.xml
# CH9-bin.4.xml
# CH15-bin.17.xml
# CH1-bin.8.xml
# CH1-bin.9.xml
# CH15-bin.16.xml
# CH9-bin.5.xml

# %%
GEMs_adapt = {}

directory = os.fsencode("output/GEMs/GEMs_adapt/")

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)

    GEMs_adapt[filename[:-4]]= reframed.load_cbmodel("output/GEMs/GEMs_adapt/"+filename)
# Out:
# CH7-bin.18.xml
# CH15-bin.7.xml
# CH13-bin.0.xml
# CH1-bin.4.xml
# CH13-bin.1.xml
# CH13-bin.11.xml
# CH15-bin.6.xml
# CH7-bin.2.xml
# CH15-bin.18.xml
# CH13-bin.13.xml
# CH1-bin.7.xml
# CH1-bin.6.xml
# CH13-bin.2.xml
# CH13-bin.12.xml
# CH15-bin.5.xml
# CH7-bin.1.xml
# CH15-bin.1.xml
# CH1-bin.3.xml
# CH13-bin.17.xml
# CH15-bin.0.xml
# CH7-bin.4.xml
# CH7-bin.23.xml
# CH15-bin.22.xml
# CH13-bin.4.xml
# CH13-bin.14.xml
# CH15-bin.23.xml
# CH7-bin.20.xml
# CH8-bin.8.xml
# CH8-bin.9.xml
# CH8-bin.25.xml
# CH14-bin.1.xml
# CH8-bin.21.xml
# CH14-bin.2.xml
# CH8-bin.22.xml
# CH8-bin.2.xml
# CH8-bin.7.xml
# CH8-bin.6.xml
# CH3-bin.2.xml
# CH8-bin.14.xml
# CH8-bin.16.xml
# CH8-bin.4.xml
# CH8-bin.5.xml
# CH3-bin.1.xml
# CH8-bin.17.xml
# CH7-bin.11.xml
# CH9-bin.1.xml
# .ipynb_checkpoints
# line 1: (01006 [Error]) XML content is not well-formed.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 9
#       6 filename = os.fsdecode(file)
#       7 print(filename)
# ----> 9 GEMs_adapt[filename[:-4]]= reframed.load_cbmodel("output/GEMs/GEMs_adapt/"+filename)
#
# File ~/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/io/sbml.py:149, in load_cbmodel(filename, flavor, exchange_detection, external_compartment, load_gprs, load_metadata, reversibility_check, use_infinity)
#     146     except:
#     147         raise RuntimeError("Exchange detection must be: 'unbalanced', 'boundary', or a valid regular expression.")
# --> 149 sbml_model = load_sbml(filename)
#     150 model = CBModel(sbml_model.getId())
#     151 load_compartments(sbml_model, model, load_metadata)
#
# File ~/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/io/sbml.py:80, in load_sbml(filename)
#      78 if sbml_model is None:
#      79     document.printErrors()
# ---> 80     raise IOError(f'Failed to load model {filename}.')
#      82 return sbml_model
#
# OSError: Failed to load model output/GEMs/GEMs_adapt/.ipynb_checkpoints.

# %% [markdown]
# ## Check difference between models

# %%
rxns_added = {}
count_GEMs_rxns_added = {}
for MAG in GEMs_adapt.keys():
    GEMs_adapt_rxns = set(GEMs_adapt[MAG].reactions.keys())
    GEMs_adapt_media_rxns = set(GEMs_adapt_media[MAG].reactions.keys())
    
    difference = GEMs_adapt_media_rxns-GEMs_adapt_rxns
    
    count_GEMs_rxns_added[MAG]=len(difference)
    print(MAG)
    for rxn in difference:
        
        if rxn in rxns_added.keys():
            rxns_added[rxn]=rxns_added[rxn]+1
        else:
            rxns_added[rxn]=1
        
        print(GEMs_adapt_media[MAG].reactions[rxn])
# Out:
# CH7-bin.18
# R_PPND2: M_nadp_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadph_c
# CH15-bin.7
# R_PRAIi: M_pran_c --> M_2cpr5p_c
# R_ANS2: M_chor_c + M_nh4_c --> M_anth_c + M_h2o_c + M_h_c + M_pyr_c
# R_IGPS: M_2cpr5p_c + M_h_c --> M_3ig3p_c + M_co2_c + M_h2o_c
# R_PPND2: M_nadp_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadph_c
# R_ANPRT: M_anth_c + M_prpp_c --> M_ppi_c + M_pran_c
# R_TRPS1: M_3ig3p_c + M_ser__L_c --> M_g3p_c + M_h2o_c + M_trp__L_c
# CH13-bin.0
# R_KARA1: M_23dhmb_c + M_nadp_c <-> M_alac__S_c + M_h_c + M_nadph_c
# R_DHAD1: M_23dhmb_c --> M_3mob_c + M_h2o_c
# R_DHAD2: M_23dhmp_c --> M_3mop_c + M_h2o_c
# R_KARA2: M_2ahbut_c + M_h_c + M_nadph_c <-> M_23dhmp_c + M_nadp_c
# R_ilvg: M_2obut_c + M_hethmpp_c --> M_2ahbut_c + M_thmpp_c
# R_MTHFR: M_fadh2_c + M_h_c + M_mlthf_c --> M_5mthf_c + M_fad_c
# R_METS: M_5mthf_c + M_hcys__L_c --> M_h_c + M_met__L_c + M_thf_c
# CH1-bin.4
# R_LASP2OA: M_Largn_c + M_oaa_c <-> M_asp__L_c + M_pphn_c + M_h_c
# CH13-bin.1
# R_HSERTA: M_accoa_c + M_hom__L_c --> M_achms_c + M_coa_c
# R_PPND: M_nad_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadh_c
# R_AHSERL2: M_achms_c + M_h2s_c --> M_ac_c + M_h_c + M_hcys__L_c
# CH13-bin.11
# R_PPND2: M_nadp_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadph_c
# R_VALTA: M_akg_c + M_val__L_c <-> M_3mob_c + M_glu__L_c
# CH15-bin.6
# R_PPND2: M_nadp_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadph_c
# CH7-bin.2
# CH15-bin.18
# CH13-bin.13
# R_CYS: M_h2s_c + M_ser__L_c <-> M_cys__L_c + M_h2o_c
# R_PPNDH: M_h_c + M_pphn_c --> M_co2_c + M_h2o_c + M_phpyr_c
# CH1-bin.7
# CH1-bin.6
# CH13-bin.2
# CH13-bin.12
# R_ITPOXAL: M_itp_c + M_oaa_c <-> M_co2_c + M_idp_c + M_pep_c
# CH15-bin.5
# R_OCBT: M_cbp_c + M_orn_c <-> M_citr__L_c + M_h_c + M_pi_c
# R_PDX5PO2: M_nad_c + M_pdx5p_c --> M_h_c + M_nadh_c + M_pydx5p_c
# R_PPND: M_nad_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadh_c
# CH7-bin.1
# CH15-bin.1
# R_OCBT: M_cbp_c + M_orn_c <-> M_citr__L_c + M_h_c + M_pi_c
# R_PDX5PO2: M_nad_c + M_pdx5p_c --> M_h_c + M_nadh_c + M_pydx5p_c
# R_PPND: M_nad_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadh_c
# CH1-bin.3
# R_PPND2: M_nadp_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadph_c
# R_OCBT: M_cbp_c + M_orn_c <-> M_citr__L_c + M_h_c + M_pi_c
# CH13-bin.17
# R_PPND: M_nad_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadh_c
# CH15-bin.0
# R_CYS: M_h2s_c + M_ser__L_c <-> M_cys__L_c + M_h2o_c
# R_PPNDH: M_h_c + M_pphn_c --> M_co2_c + M_h2o_c + M_phpyr_c
# CH7-bin.4
# R_PPND2: M_nadp_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadph_c
# R_PPNDH: M_h_c + M_pphn_c --> M_co2_c + M_h2o_c + M_phpyr_c
# R_CHORM: M_chor_c --> M_pphn_c
# CH7-bin.23
# R_ORNCD: M_orn_c <-> M_nh4_c + M_pro__L_c
# R_PPND: M_nad_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadh_c
# CH15-bin.22
# CH13-bin.4
# R_PPND2: M_nadp_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadph_c
# R_OCBT: M_cbp_c + M_orn_c <-> M_citr__L_c + M_h_c + M_pi_c
# R_PPItex: M_h_c + M_ppi_c <-> M_h_e + M_ppi_e
# CH13-bin.14
# CH15-bin.23
# R_TRPS3: M_3ig3p_c --> M_g3p_c + M_indole_c
# R_PRAIi: M_pran_c --> M_2cpr5p_c
# R_ANSN: M_chor_c + M_nh3_c --> M_anth_c + M_h2o_c + M_pyr_c
# R_IGPS: M_2cpr5p_c + M_h_c --> M_3ig3p_c + M_co2_c + M_h2o_c
# R_ANPRT: M_anth_c + M_prpp_c --> M_ppi_c + M_pran_c
# CH7-bin.20
# CH8-bin.8
# R_HSERTA: M_accoa_c + M_hom__L_c --> M_achms_c + M_coa_c
# R_AHSERL2: M_achms_c + M_h2s_c --> M_ac_c + M_h_c + M_hcys__L_c
# CH8-bin.9
# R_TRPS3: M_3ig3p_c --> M_g3p_c + M_indole_c
# R_PRAIi: M_pran_c --> M_2cpr5p_c
# R_ANS2: M_chor_c + M_nh4_c --> M_anth_c + M_h2o_c + M_h_c + M_pyr_c
# R_IGPS: M_2cpr5p_c + M_h_c --> M_3ig3p_c + M_co2_c + M_h2o_c
# R_ANPRT: M_anth_c + M_prpp_c --> M_ppi_c + M_pran_c
# CH8-bin.25
# R_PPND: M_nad_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadh_c
# CH14-bin.1
# CH8-bin.21
# R_OCBT: M_cbp_c + M_orn_c <-> M_citr__L_c + M_h_c + M_pi_c
# R_ORNCD_2: M_orn_c --> M_nh4_c + M_pro__L_c
# R_PPND: M_nad_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadh_c
# CH14-bin.2
# CH8-bin.22
# CH8-bin.2
# R_PPND2: M_nadp_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadph_c
# R_HSERTA: M_accoa_c + M_hom__L_c --> M_achms_c + M_coa_c
# R_AHSERL2: M_achms_c + M_h2s_c --> M_ac_c + M_h_c + M_hcys__L_c
# CH8-bin.7
# R_OCBT: M_cbp_c + M_orn_c <-> M_citr__L_c + M_h_c + M_pi_c
# R_KGD2_1: M_co2_c + 2.0 M_fdxrd_c + M_h_c + M_succoa_c <-> M_akg_c + M_coa_c + 2.0 M_fdxo_2_2_c
# R_PRATPP_1: M_h2o_c + M_prbatp_c --> M_ppi_c + M_prbamp_c + M_h_c
# R_KARA1: M_23dhmb_c + M_nadp_c <-> M_alac__S_c + M_h_c + M_nadph_c
# R_HISTP: M_h2o_c + M_hisp_c --> M_histd_c + M_pi_c
# R_PRAIi: M_pran_c --> M_2cpr5p_c
# R_THRS_2: M_h2o_c + M_phom_c --> M_pi_c + M_thr__L_c
# R_ANS2: M_chor_c + M_nh4_c --> M_anth_c + M_h2o_c + M_h_c + M_pyr_c
# R_ARGSL: M_argsuc_c <-> M_arg__L_c + M_fum_c
# R_VALDHr: M_h2o_c + M_nad_c + M_val__L_c <-> M_3mob_c + M_h_c + M_nadh_c + M_nh4_c
# R_ILETA2: M_3mop_c + M_glu__L_c <-> M_akg_c + M_ile__L_c
# R_IPPMIb: M_2ippm_c + M_h2o_c <-> M_3c3hmp_c
# R_ACHBS: M_2obut_c + M_h_c + M_pyr_c --> M_2ahbut_c + M_co2_c
# R_PRAMPC_1: M_h2o_c + M_prbamp_c --> M_prfp_c
# R_HSTPT: M_glu__L_c + M_imacp_c --> M_akg_c + M_hisp_c
# R_IPMD2: M_2ip3os_c + M_h_c --> M_4mop_c + M_co2_c
# R_HSDy: M_hom__L_c + M_nadp_c <-> M_aspsa_c + M_h_c + M_nadph_c
# R_IGPDH: M_eig3p_c --> M_h2o_c + M_imacp_c
# R_ORNTA: M_akg_c + M_orn_c <-> M_glu5sa_c + M_glu__L_c
# R_HSK: M_atp_c + M_hom__L_c --> M_adp_c + M_h_c + M_phom_c
# R_LEUTAi: M_4mop_c + M_glu__L_c --> M_akg_c + M_leu__L_c
# R_TRPS1: M_3ig3p_c + M_ser__L_c --> M_g3p_c + M_h2o_c + M_trp__L_c
# R_ATPPRT: M_atp_c + M_prpp_c --> M_ppi_c + M_prbatp_c
# R_IPPS: M_3mob_c + M_accoa_c + M_h2o_c --> M_3c3hmp_c + M_coa_c + M_h_c
# R_IG3PS_1: M_gln__L_c + M_prlp_c --> M_aicar_c + M_eig3p_c + M_glu__L_c + M_h_c
# R_G5SD: M_glu5p_c + M_h_c + M_nadph_c --> M_glu5sa_c + M_nadp_c + M_pi_c
# R_DHAD2: M_23dhmp_c --> M_3mop_c + M_h2o_c
# R_KARA2: M_2ahbut_c + M_h_c + M_nadph_c <-> M_23dhmp_c + M_nadp_c
# R_IPPMIa: M_3c2hmp_c <-> M_2ippm_c + M_h2o_c
# R_ASPTA6: M_ala__L_c + M_oaa_c <-> M_asp__L_c + M_pyr_c
# R_GLU5K: M_atp_c + M_glu__L_c --> M_adp_c + M_glu5p_c
# R_HDH: M_h2o_c + M_histd_c + 2.0 M_nad_c --> 3.0 M_h_c + M_his__L_c + 2.0 M_nadh_c
# R_DAPDC: M_26dap__M_c + M_h_c --> M_co2_c + M_lys__L_c
# R_ARGSS2: M_asp__L_c + M_atp_c + M_citr__L_c --> M_amp_c + M_argsuc_c + M_ppi_c + M_h_c
# R_PPND: M_nad_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadh_c
# R_CBMKr2: M_atp_c + M_co2_c + M_nh4_c --> M_adp_c + M_cbp_c + 2.0 M_h_c
# R_AROH: M_Largn_c --> M_co2_c + M_h2o_c + M_phe__L_c
# R_AHSERL2_1: M_achms_c + M_h2s_c --> M_ac_c + M_hcys__L_c + M_h_c
# R_HSERTA: M_accoa_c + M_hom__L_c --> M_achms_c + M_coa_c
# R_DHAD1: M_23dhmb_c --> M_3mob_c + M_h2o_c
# R_LASP2OA: M_Largn_c + M_oaa_c <-> M_asp__L_c + M_pphn_c + M_h_c
# R_IGPS: M_2cpr5p_c + M_h_c --> M_3ig3p_c + M_co2_c + M_h2o_c
# R_CITabc: M_atp_c + M_cit_e + M_h2o_c --> M_adp_c + M_cit_c + M_h_c + M_pi_c
# R_ACLS: M_h_c + 2.0 M_pyr_c --> M_alac__S_c + M_co2_c
# R_CHORM: M_chor_c --> M_pphn_c
# R_PRMICI: M_prfp_c <-> M_prlp_c
# R_ANPRT: M_anth_c + M_prpp_c --> M_ppi_c + M_pran_c
# R_IPMD_1: M_3c2hmp_c + M_nad_c --> M_2ip3os_c + M_h_c + M_nadh_c
# CH8-bin.6
# CH3-bin.2
# CH8-bin.14
# CH8-bin.16
# R_OCBT: M_cbp_c + M_orn_c <-> M_citr__L_c + M_h_c + M_pi_c
# R_ARNO: M_Largn_c + M_nad_c --> M_co2_c + M_h_c + M_nadh_c + M_tyr__L_c
# CH8-bin.4
# R_TRPS3: M_3ig3p_c --> M_g3p_c + M_indole_c
# R_PRAIi: M_pran_c --> M_2cpr5p_c
# R_ANS2: M_chor_c + M_nh4_c --> M_anth_c + M_h2o_c + M_h_c + M_pyr_c
# R_IGPS: M_2cpr5p_c + M_h_c --> M_3ig3p_c + M_co2_c + M_h2o_c
# R_ANPRT: M_anth_c + M_prpp_c --> M_ppi_c + M_pran_c
# CH8-bin.5
# R_PPND2: M_nadp_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadph_c
# CH3-bin.1
# CH8-bin.17
# CH7-bin.11
# R_TMDPK: M_atp_c + M_thm_c --> M_amp_c + M_h_c + M_thmpp_c
# R_PPND: M_nad_c + M_pphn_c --> M_34hpp_c + M_co2_c + M_nadh_c
# CH9-bin.1
# R_DHORD_NAD: M_dhor__S_c + M_nad_c <-> M_nadh_c + M_orot_c + M_h_c
# R_OMPDC: M_h_c + M_orot5p_c --> M_co2_c + M_ump_c
# R_ORPT: M_orot5p_c + M_ppi_c <-> M_orot_c + M_prpp_c

# %%
pd.Series(count_GEMs_rxns_added).sort_values(ascending=False).head(15)
# Out:
# CH8-bin.7      48
# CH13-bin.0      7
# CH15-bin.7      6
# CH8-bin.4       5
# CH8-bin.9       5
# CH15-bin.23     5
# CH13-bin.4      3
# CH15-bin.5      3
# CH8-bin.2       3
# CH8-bin.21      3
# CH7-bin.4       3
# CH15-bin.1      3
# CH9-bin.1       3
# CH13-bin.1      3
# CH8-bin.8       2
# dtype: int64

# %%
all_mags_paper.loc["CH8-bin.7",:]
# Out:
# Source                   Cow_Manure
# Substrate                    Avicel
# Completeness (%)              99.44
# Contamination (%)               0.0
# Domain                     Bacteria
# Phylum                   Firmicutes
# Class                       Bacilli
# Order                         RFN20
# Family                      CAG-826
# Genus                       UBA7706
# Species                         NaN
# Genome size (bp)            1586037
# Scaffolds                        15
# N50                         1021092
# CDS prediction (DRAM)          1455
# Coverage (%)                   3.94
# Name: CH8-bin.7, dtype: object

# %%
pd.Series(rxns_added).sort_values(ascending=False).head(15)
# Out:
# R_PPND2      9
# R_PPND       9
# R_OCBT       7
# R_IGPS       5
# R_PRAIi      5
# R_ANPRT      5
# R_HSERTA     4
# R_ANS2       4
# R_TRPS3      3
# R_PPNDH      3
# R_AHSERL2    3
# R_PDX5PO2    2
# R_CYS        2
# R_CHORM      2
# R_LASP2OA    2
# dtype: int64

# %% [markdown]
# - PPND2 - Prephenate dehydrogenase NADP - nadp_c + pphn_c ⇌ 34hpp_c + co2_c + nadph_c - "[Prephenate dehydrogenase](https://en.wikipedia.org/wiki/Prephenate_dehydrogenase) is an enzyme found in the shikimate pathway (links metabolism of carbohydrates to biosynthesis of aromatic compounds), and helps catalyze the reaction from prephenate to **tyrosine**."
#
# - PPND - Prephenate dehydrogenase - nad_c + pphn_c ⇌ 34hpp_c + co2_c + nadh_c - "[Prephenate dehydrogenase](https://en.wikipedia.org/wiki/Prephenate_dehydrogenase) is an enzyme found in the shikimate pathway (links metabolism of carbohydrates to biosynthesis of aromatic compounds), and helps catalyze the reaction from prephenate to **tyrosine**."
#
# - OCBT - Ornithine carbamoyltransferase - cbp_c + orn_c ⇌ citr__L_c + h_c + pi_c - "[Ornithine transcarbamylase](https://en.wikipedia.org/wiki/Ornithine_transcarbamylase) (OTC) (also called ornithine carbamoyltransferase) is an enzyme (EC 2.1.3.3) that catalyzes the reaction between carbamoyl phosphate (CP) and ornithine (Orn) to form citrulline (Cit) and phosphate (Pi)... Anabolic OTC facilitates the sixth step in the biosynthesis of the amino acid **arginine** in prokaryotes."
#
# - IGPS - Indole-3-glycerol-phosphate synthase - 2cpr5p_c + h_c ⇌ 3ig3p_c + co2_c + h2o_c. [(indole-3-glycerol-phosphate synthase)](https://en.wikipedia.org/wiki/Indole-3-glycerol-phosphate_synthase) participates in **phenylalanine, tyrosine and tryptophan biosynthesis** and two-component system - general.
#
# - PRAIi - Phosphoribosylanthranilate isomerase (irreversible) - pran_c ⇌ 2cpr5p_c. [Iphosphoribosylanthranilate isomerase (PRAI)](https://en.wikipedia.org/wiki/Phosphoribosylanthranilate_isomerase) (EC 5.3.1.24) is an enzyme that catalyzes the third step of the synthesis of the amino acid **tryptophan**
#
# - ANPRT - Anthranilate phosphoribosyltransferase - anth_c + prpp_c ⇌ ppi_c + pran_c. [( anthranilate phosphoribosyltransferase)](https://en.wikipedia.org/wiki/Anthranilate_phosphoribosyltransferase) participates in aromatic **amino acid biosynthesis** and two-component system (general).
