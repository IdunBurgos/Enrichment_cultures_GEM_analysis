# %%
from urllib.request import urlopen

from io import TextIOWrapper

from Bio import SeqIO 

import pandas as pd

import reframed

import re

# %%
possible_transporters = pd.read_excel("/Users/idunmariaburgos/Documents/Work/Project/chain elongation/Clostridia BL3 and BL4/possible_transporters_tcdb.xlsx",sheet_name="overview")
possible_transporters
# Out:
#         Acetate   Propionate     Butyrate    Valerate   Hexanoate  \
# 0   3.A.1.120.5   1.A.46.2.1   2.A.1.13.1  2.A.73.1.1  1.B.25.1.8
# 1    1.A.14.2.2   2.A.21.4.1  2.A.1.19.18         NaN         NaN
# 2    2.A.1.13.1   2.A.21.5.3   2.A.21.4.1         NaN         NaN
# 3    2.A.1.6.11   2.A.21.7.3   2.A.21.5.3         NaN         NaN
# 4  2.A.102.4.13   2.A.8.1.13   2.A.21.5.4         NaN         NaN
# 5    2.A.21.7.3  3.A.1.205.3   2.A.21.5.5         NaN         NaN
# 6   2.A.23.1.10          NaN   2.A.73.1.1         NaN         NaN
# 7     2.A.6.2.9          NaN   2.A.8.1.13         NaN         NaN
# 8   2.A.96.1.11          NaN          NaN         NaN         NaN
# 9    2.A.96.1.4          NaN          NaN         NaN         NaN
#
#    Iso-butyrate
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN

# %% [markdown]
# - 3.A.1.120.5 - abc
# - 1.A.14.2.2 - acetate uptake
# - 2.A.23.1.10 - uptake
# - 2.A.6.2.9 - abc
# - 2.A.96.1.11 - uptake
#
#
# - 2.A.1.13.1 - proton linked efflux/influx
# - 2.A.1.6.11 - Acetate/haloacid transporter (no mechanism)
# - 2.A.102.4.13 - acetate transporter
# - 2.A.21.7.3 - Pyruvate/acetate/propionate: H+ symporter
# - 2.A.96.1.4 - acetate permease

# %%
possible_transporters = ['2.A.1.13.1','2.A.1.6.11','2.A.102.4.13','2.A.21.7.3','2.A.96.1.4']

# %%
possible_transporters_regex = "|".join(possible_transporters)

# %%
possible_transporters_regex
# Out:
# '2.A.1.13.1|2.A.1.6.11|2.A.102.4.13|2.A.21.7.3|2.A.96.1.4'

# %% [markdown]
# **Filter data from tcdb**

# %%
handle = TextIOWrapper(urlopen("https://www.tcdb.org/public/tcdb"))
recs = list(SeqIO.parse(handle, 'fasta'))
handle.close()

# %%
ofile = open("transporters/transporters.faa","w")

for rec in recs:
    id_ = str(rec.id)
    
    if re.search(possible_transporters_regex, id_):
        
        
        sequence = str(rec.seq)
        
        ofile.write(">"+id_+"\n"+sequence+"\n")
ofile.close()

# %%
import os

# %%
ACt2r_MAGs = []

ACt2r_MAGs_data = []
for filename in os.listdir("transporters/"):
    
    if filename.endswith(".tsv"):

        transport= pd.read_csv("transporters/"+filename,sep="\t",header=None)
        transport.columns = ["query acc.ver", "subject acc.ver", "% identity", "alignment length", "mismatches", "gap opens", "q. start", "q. end", "s. start", "s. end", "evalue", "bit score"]
        transport.reset_index(inplace=True)
        
        if transport.shape[0]>1:
            
            transport.sort_values(by="evalue",ascending=True,inplace=True)
            transport.reset_index(inplace=True)
            
            query = transport.loc[0,"query acc.ver"]
            gene = transport.loc[0,"subject acc.ver"]
            best_evalue = transport.loc[0,"evalue"]
            bit_score = transport.loc[0,"bit score"]
            
            if best_evalue<1e-5 and bit_score>20:
                if "2.A.1.13.1" in query:
                    ACt2r_MAGs.append(filename[:-4])
                    
                    ACt2r_MAGs_data.append((filename[:-4],gene,best_evalue,bit_score,"2.A.1.13.1"))

                elif "2.A.21.7.3" in query: 
                    ACt2r_MAGs.append(filename[:-4])
                    ACt2r_MAGs_data.append((filename[:-4],gene,best_evalue,bit_score,"2.A.21.7.3"))

# %%
len(ACt2r_MAGs)
# Out:
# 55

# %%
pd.DataFrame(ACt2r_MAGs_data,columns=["MAG","gene","evalue","bit_score","TCDB_id"]).sort_values("evalue")
# Out:
#             MAG      gene         evalue  bit_score     TCDB_id
# 43  CH15-bin.17   gene545  4.900000e-157      456.0  2.A.21.7.3
# 12   CH13-bin.1   gene374  4.910000e-157      456.0  2.A.21.7.3
# 40   CH7-bin.16  gene2185  8.200000e-156      452.0  2.A.21.7.3
# 2     CH7-bin.4  gene3341  4.480000e-153      445.0  2.A.21.7.3
# 28   CH8-bin.25  gene3105  2.220000e-151      441.0  2.A.21.7.3
# 41    CH1-bin.9   gene769  1.280000e-150      439.0  2.A.21.7.3
# 13   CH15-bin.6  gene1704  1.430000e-142      420.0  2.A.21.7.3
# 11    CH1-bin.1   gene727   3.590000e-56      191.0  2.A.21.7.3
# 25   CH14-bin.2  gene1003   9.490000e-23       99.0  2.A.21.7.3
# 49    CH9-bin.1  gene3888   1.190000e-22       99.0  2.A.21.7.3
# 18  CH13-bin.10  gene2510   4.490000e-19       87.0  2.A.21.7.3
# 15    CH9-bin.8     gene1   1.140000e-18       84.3  2.A.1.13.1
# 22  CH15-bin.18   gene948   2.010000e-17       82.4  2.A.21.7.3
# 7   CH13-bin.14  gene5876   2.620000e-17       82.4  2.A.21.7.3
# 48   CH7-bin.11  gene2382   4.360000e-17       80.5  2.A.21.7.3
# 39    CH8-bin.2   gene979   4.580000e-17       80.5  2.A.21.7.3
# 37   CH8-bin.12   gene529   5.030000e-17       80.1  2.A.21.7.3
# 38   CH8-bin.11  gene2414   8.090000e-17       79.7  2.A.21.7.3
# 35    CH8-bin.4    gene68   8.480000e-17       78.6  2.A.1.13.1
# 30   CH8-bin.14   gene546   9.540000e-17       79.7  2.A.21.7.3
# 19   CH13-bin.0  gene2567   1.030000e-16       79.3  2.A.21.7.3
# 16   CH7-bin.24   gene385   6.930000e-16       75.5  2.A.1.13.1
# 53   CH7-bin.13  gene2195   1.170000e-15       75.9  2.A.21.7.3
# 6    CH13-bin.4  gene2613   1.580000e-15       75.9  2.A.21.7.3
# 3    CH15-bin.1  gene2599   1.620000e-15       75.9  2.A.21.7.3
# 34   CH8-bin.16  gene1114   2.510000e-15       75.1  2.A.21.7.3
# 23  CH13-bin.13   gene458   2.780000e-15       74.7  2.A.21.7.3
# 26    CH8-bin.9   gene614   3.530000e-15       73.9  2.A.21.7.3
# 32    CH3-bin.1  gene4869   3.850000e-15       75.1  2.A.21.7.3
# 8   CH15-bin.23  gene1853   7.300000e-15       73.6  2.A.21.7.3
# 27   CH8-bin.27   gene588   7.450000e-15       73.6  2.A.21.7.3
# 9    CH7-bin.20   gene898   2.310000e-14       70.9  2.A.1.13.1
# 29    CH3-bin.2  gene2757   2.650000e-14       72.4  2.A.21.7.3
# 24   CH14-bin.1  gene1344   6.140000e-14       71.2  2.A.21.7.3
# 21   CH13-bin.2  gene1742   6.680000e-14       70.9  2.A.21.7.3
# 52    CH7-bin.8  gene2703   1.350000e-13       69.7  2.A.21.7.3
# 42   CH7-bin.15  gene1972   3.030000e-13       68.6  2.A.21.7.3
# 5     CH1-bin.0  gene2609   3.480000e-13       68.2  2.A.21.7.3
# 17   CH15-bin.7   gene621   3.000000e-12       65.1  2.A.21.7.3
# 50  CH13-bin.25   gene855   3.060000e-12       65.1  2.A.21.7.3
# 20    CH1-bin.4  gene2269   8.890000e-12       63.2  2.A.1.13.1
# 44  CH13-bin.20  gene1181   4.790000e-11       61.2  2.A.21.7.3
# 51  CH15-bin.10    gene75   7.650000e-11       60.8  2.A.21.7.3
# 10   CH7-bin.21  gene1580   1.220000e-10       60.1  2.A.21.7.3
# 36    CH8-bin.0  gene1211   1.460000e-10       58.5  2.A.1.13.1
# 4   CH13-bin.16   gene888   1.740000e-10       58.9  2.A.21.7.3
# 54    CH7-bin.9  gene1470   4.890000e-10       58.5  2.A.21.7.3
# 45    CH1-bin.8  gene2827   1.340000e-08       54.3  2.A.21.7.3
# 46  CH13-bin.24   gene534   2.740000e-08       51.6  2.A.1.13.1
# 14   CH7-bin.25   gene808   3.460000e-07       48.9  2.A.21.7.3
# 33   CH8-bin.17    gene51   3.780000e-07       48.9  2.A.21.7.3
# 1    CH15-bin.0  gene1303   6.750000e-07       48.1  2.A.21.7.3
# 0   CH13-bin.17   gene572   8.200000e-07       47.8  2.A.21.7.3
# 31    CH8-bin.5  gene1101   8.840000e-07       47.8  2.A.21.7.3
# 47  CH15-bin.13  gene1023   4.300000e-06       45.4  2.A.1.13.1
