# %% [markdown]
# # Single model pFBA predictions

# %%
import reframed
import pandas as pd
import numpy as np

import seaborn as sns

import os
import json

# %% [markdown]
# #### Load data

# %%
all_mags_paper = pd.read_excel("input/files_from_fairdomhub/All_Mags_for_paper_analysis.xlsx",sheet_name="Coverage")
all_mags_paper.set_index("MAG",inplace=True)
all_mags_paper.head(2)
# Out:
#                Source Substrate  Completeness (%)  Contamination (%)  \
# MAG
# CH3-bin.2   Marshland     Xylan             99.19               1.61
# CH9-bin.0  Cow_Manure     Xylan             99.03               2.82
#
#              Domain            Phylum          Class            Order  \
# MAG
# CH3-bin.2  Bacteria      Firmicutes_A     Clostridia    Clostridiales
# CH9-bin.0  Bacteria  Actinobacteriota  Actinomycetia  Actinomycetales
#
#                        Family            Genus                  Species  \
# MAG
# CH3-bin.2      Clostridiaceae      Clostridium  Clostridium sp000230835
# CH9-bin.0  Bifidobacteriaceae  Bifidobacterium                      NaN
#
#            Genome size (bp)  Scaffolds     N50  CDS prediction (DRAM)  \
# MAG
# CH3-bin.2           6175525         63  230012                   5840
# CH9-bin.0           2513253         38  128964                   2055
#
#            Coverage (%)
# MAG
# CH3-bin.2         74.31
# CH9-bin.0         65.10

# %% [markdown]
# #### Load models

# %%
with open("output/GEMs/GEMs_adapt.json") as json_file:
    GEMs_adapt = json.load(json_file)
    
gems_adapt_dict = {"no_constr":"output/GEMs/GEMs_no_constraints/",
                  "constr0_1":"output/GEMs/GEMs_soft_constraints_score_0.1/"}

# %%
with open("output/soft_constraints_v2/relevant_MAGs_99.txt") as text_file:
    relevant_MAGs = text_file.read().split("\n")

relevant_MAGs = [string.replace("\t","") for string in relevant_MAGs]

# %%
GEMs_dict = {}
for MAG in relevant_MAGs:
    print(MAG)
    directory = gems_adapt_dict[GEMs_adapt[MAG]]
    GEMs_dict[MAG]= reframed.load_cbmodel(directory+MAG+".xml")
# Out:
# CH3-bin.2
# CH9-bin.0
# CH14-bin.1
# CH1-bin.6
# CH7-bin.23
# CH8-bin.22
# CH13-bin.12
# CH1-bin.9
# CH3-bin.1
# CH14-bin.2
# CH15-bin.0
# CH13-bin.14
# CH9-bin.6
# CH13-bin.4
# CH15-bin.1
# CH15-bin.23
# CH8-bin.17
# CH13-bin.11
# CH15-bin.7
# CH7-bin.16
# CH15-bin.16
# CH15-bin.8
# CH13-bin.25
# CH7-bin.11
# CH8-bin.25
# CH9-bin.1
# CH7-bin.13
# CH8-bin.2
# CH15-bin.17
# CH15-bin.22
# CH1-bin.8
# CH15-bin.6
# CH8-bin.6
# CH13-bin.0
# CH8-bin.7
# CH13-bin.17
# CH1-bin.3
# CH15-bin.5
# CH15-bin.13
# CH7-bin.8
# CH1-bin.4
# CH7-bin.18
# CH8-bin.5
# CH9-bin.2
# CH7-bin.2
# CH9-bin.5
# CH7-bin.4
# CH8-bin.8
# CH15-bin.10
# CH7-bin.1
# CH15-bin.12
# CH7-bin.17
# CH9-bin.4
# CH1-bin.7
# CH15-bin.15
# CH8-bin.16
# CH8-bin.9
# CH7-bin.12
# CH13-bin.1
# CH7-bin.20
# CH8-bin.21
# CH8-bin.14
# CH7-bin.9
# CH13-bin.13
# CH13-bin.2
# CH8-bin.4
# CH15-bin.18

# %% [markdown]
# ### Define environment

# %% [markdown]
# **From SynCon2 to SynCon1**
#
# "SynCon2 had the same composition, but it lacked ascorbic acid, and it had two additional trace elements (selenium and wolfram)"
#
# Add
# - Ascorbate: ascb__L
#
# Remove
# - Selenite (inorganic selenium): slnt
# - (wolfram: not in BiGG database)

# %%
syncon2 = pd.read_csv("input/syncon2media_combined.csv",header=None)

syncon1 = list(syncon2[0].values)
syncon1.remove("slnt")
syncon1.append("ascb__L")

# %%
substrate_composition = {"Avicel":["cellb","cell3","cell4","cell5"],
                         "PASC":["cellb","cell3","cell4","cell5"],
                         "Xylan":["xylb","xyl3","xylan4","xylan8"]}

# %%
syncon1_environments = {}
for substrate_name,met_mols in substrate_composition.items():
    syncon1_environments[substrate_name]= reframed.Environment.from_compounds(syncon1)
    for met in met_mols:
        syncon1_environments[substrate_name]["R_EX_"+met+"_e"]=(-10,0)

# %% [markdown]
# ### FBA growth predictions

# %%
community_groups = all_mags_paper.groupby(by= ["Source","Substrate"]).groups

# %%
FBA_growth = {}
for community, MAGs in community_groups.items(): 
    FBA_growth[community]={}
    for MAG in MAGs:
        
        if MAG not in relevant_MAGs:
            continue
            
        print(MAG)
        model = GEMs_dict[MAG]
        syncon1_environments[community[1]].apply(model,inplace=True,exclusive=True)
        sol = reframed.FBA(model)
        
        if sol is None:
            FBA_growth[community][MAG]=None
        else:
            FBA_growth[community][MAG]=sol
# Out:
# CH13-bin.12
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-03-14
# CH13-bin.14
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_b12_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_ribflv_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_pydxn_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_ni2_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_rbflvrd_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_fol_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_pnto__R_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_na1_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_tungs_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_mobd_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_4abz_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_nac_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_thm_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_ascb__L_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_cell3_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_btn_e
#   warn(f'Exchange reaction not in model: {r_id}')
# CH13-bin.4
# CH13-bin.11
# CH13-bin.25
# CH13-bin.0
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_cellb_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_cell4_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_cell5_e
#   warn(f'Exchange reaction not in model: {r_id}')
# CH13-bin.17
# CH13-bin.1
# CH13-bin.13
# CH13-bin.2
# CH15-bin.0
# CH15-bin.1
# CH15-bin.23
# CH15-bin.7
# CH15-bin.16
# CH15-bin.8
# CH15-bin.17
# CH15-bin.22
# CH15-bin.6
# CH15-bin.5
# CH15-bin.13
# CH15-bin.10
# CH15-bin.12
# CH15-bin.15
# CH15-bin.18
# CH14-bin.1
# CH14-bin.2
# CH8-bin.22
# CH8-bin.17
# CH8-bin.25
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_xylb_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_xyl3_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_xylan8_e
#   warn(f'Exchange reaction not in model: {r_id}')
# CH8-bin.2
# CH8-bin.6
# CH8-bin.7
# CH8-bin.5
# CH8-bin.8
# CH8-bin.16
# CH8-bin.9
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_cys__L_e
#   warn(f'Exchange reaction not in model: {r_id}')
# CH8-bin.21
# CH8-bin.14
# CH8-bin.4
# CH7-bin.23
# CH7-bin.16
# CH7-bin.11
# CH7-bin.13
# CH7-bin.8
# CH7-bin.18
# CH7-bin.2
# CH7-bin.4
# CH7-bin.1
# CH7-bin.17
# CH7-bin.12
# CH7-bin.20
# CH7-bin.9
# CH9-bin.0
# CH9-bin.6
# CH9-bin.1
# CH9-bin.2
# CH9-bin.5
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_xylan4_e
#   warn(f'Exchange reaction not in model: {r_id}')
# CH9-bin.4
# CH1-bin.6
# CH1-bin.9
# CH1-bin.8
# CH1-bin.3
# CH1-bin.4
# CH1-bin.7
# CH3-bin.2
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_so4_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_fe2_e
#   warn(f'Exchange reaction not in model: {r_id}')
# CH3-bin.1

# %%
# Add the source and substrate to this data
growth_community_df = pd.concat([all_mags_paper.loc[:,["Source","Substrate"]],pd.Series({GEM:sol.fobj for sour_sub,GEM_sol_dict in FBA_growth.items() for GEM,sol in GEM_sol_dict.items()})],axis=1)
# Change from float to False or positive
growth_community_df["Grows"] = growth_community_df[0].map(lambda x:x>1e-6)
# Drop the growth float column
growth_community_df.drop(0,axis=1,inplace=True)

# Group by source and substrate
growth_community_grouped_df = growth_community_df.groupby(["Source","Substrate"]).value_counts()


# Change grows index to column
growth_community_grouped_df = growth_community_grouped_df.reset_index(level="Grows")

# Make different columns for grows and does not grow
growth_community_grouped_df = pd.concat([growth_community_grouped_df[growth_community_grouped_df["Grows"]].drop("Grows",axis=1),growth_community_grouped_df[~growth_community_grouped_df["Grows"]].drop("Grows",axis=1)],axis=1)

# Name columns
growth_community_grouped_df.columns = ["# growing","# not growing"]

growth_community_grouped_df.fillna(0,inplace=True)
growth_community_grouped_df["# growing"] = growth_community_grouped_df["# growing"].map(int)

# %%
growth_community_grouped_df
# Out:
#                              # growing  # not growing
# Source            Substrate
# Compost_Digestate Avicel             1             18
#                   PASC               2             18
#                   Xylan              1              2
# Cow_Manure        Avicel             3             16
#                   PASC               4             15
# Marshland         PASC               1             10
#                   Xylan              1              2
# Cow_Manure        Xylan              0              7

# %%
import matplotlib.pyplot as plt



growth_community_grouped_df.plot(kind="bar",color=['mediumseagreen','indianred'])
plt.savefig("grows_count.png",bbox_inches='tight')

# %%
all_mags_paper[all_mags_paper.index.isin(growth_community_df[growth_community_df.Grows].index)]
# Out:
#                         Source Substrate  Completeness (%)  Contamination (%)  \
# MAG
# CH14-bin.1   Compost_Digestate     Xylan             99.37               0.32
# CH3-bin.1            Marshland     Xylan             99.31               4.52
# CH8-bin.17          Cow_Manure    Avicel             96.62               2.03
# CH7-bin.16          Cow_Manure      PASC             99.11               0.00
# CH15-bin.16  Compost_Digestate      PASC             99.37               2.22
# CH15-bin.22  Compost_Digestate      PASC             99.35               0.65
# CH1-bin.8            Marshland      PASC             97.11               0.63
# CH8-bin.6           Cow_Manure    Avicel             97.97               1.35
# CH7-bin.2           Cow_Manure      PASC             97.30               0.68
# CH7-bin.1           Cow_Manure      PASC             98.91               3.84
# CH7-bin.20          Cow_Manure      PASC             97.72               1.61
# CH8-bin.14          Cow_Manure    Avicel             97.98               1.15
# CH13-bin.2   Compost_Digestate    Avicel             98.30               2.01
#
#                Domain              Phylum             Class  \
# MAG
# CH14-bin.1   Bacteria        Firmicutes_A        Clostridia
# CH3-bin.1    Bacteria        Firmicutes_A        Clostridia
# CH8-bin.17   Bacteria   Verrucomicrobiota  Verrucomicrobiae
# CH7-bin.16   Bacteria  Desulfobacterota_I  Desulfovibrionia
# CH15-bin.16  Bacteria        Firmicutes_A        Clostridia
# CH15-bin.22  Bacteria    Desulfobacterota  Desulfuromonadia
# CH1-bin.8    Bacteria        Firmicutes_A        Clostridia
# CH8-bin.6    Bacteria   Verrucomicrobiota  Verrucomicrobiae
# CH7-bin.2    Bacteria   Verrucomicrobiota  Verrucomicrobiae
# CH7-bin.1    Bacteria          Firmicutes           Bacilli
# CH7-bin.20   Bacteria        Firmicutes_A        Clostridia
# CH8-bin.14   Bacteria        Firmicutes_A        Clostridia
# CH13-bin.2   Bacteria        Firmicutes_A        Clostridia
#
#                           Order               Family              Genus  \
# MAG
# CH14-bin.1       Lachnospirales      Lachnospiraceae       Lacrimispora
# CH3-bin.1         Clostridiales       Clostridiaceae      Clostridium_S
# CH8-bin.17           Opitutales           Verruco-01         Verruco-01
# CH7-bin.16   Desulfovibrionales  Desulfovibrionaceae  Humidesulfovibrio
# CH15-bin.16      Lachnospirales      Lachnospiraceae       Lacrimispora
# CH15-bin.22  Desulfuromonadales   Syntrophotaleaceae     Syntrophotalea
# CH1-bin.8        Lachnospirales      Lachnospiraceae       Lacrimispora
# CH8-bin.6            Opitutales           Verruco-01         Verruco-01
# CH7-bin.2            Opitutales           Verruco-01         Verruco-01
# CH7-bin.1       Lactobacillales        Aerococcaceae       Trichococcus
# CH7-bin.20   Christensenellales               CAG-74                NaN
# CH8-bin.14   Christensenellales               CAG-74         Limiplasma
# CH13-bin.2       Lachnospirales      Lachnospiraceae        Mobilitalea
#
#                                    Species  Genome size (bp)  Scaffolds  \
# MAG
# CH14-bin.1       Lacrimispora amygdalina_A           5147597         48
# CH3-bin.1                              NaN           6360127        130
# CH8-bin.17                             NaN           2927393         59
# CH7-bin.16                             NaN           3127892         27
# CH15-bin.16                            NaN           5604339         23
# CH15-bin.22     Syntrophotalea acetylenica           2967869         82
# CH1-bin.8    Lacrimispora celerecrescens_B           5085002         53
# CH8-bin.6           Verruco-01 sp016928295           2685015         37
# CH7-bin.2           Verruco-01 sp016928295           2529650         33
# CH7-bin.1                             N/A            2925786         51
# CH7-bin.20                             NaN           3414990         98
# CH8-bin.14                             NaN           3950459        143
# CH13-bin.2         Mobilitalea sp014174405           3801925        177
#
#                 N50  CDS prediction (DRAM)  Coverage (%)
# MAG
# CH14-bin.1   197896                   4902         56.45
# CH3-bin.1     86322                   5672         21.93
# CH8-bin.17   179071                   2477          8.69
# CH7-bin.16   407700                   2927          7.56
# CH15-bin.16  423081                   5254          7.44
# CH15-bin.22   59021                   2733          4.90
# CH1-bin.8    230023                   4663          4.81
# CH8-bin.6    199123                   2147          4.37
# CH7-bin.2    128050                   2023          2.87
# CH7-bin.1    109473                   2727          2.14
# CH7-bin.20    74193                   3154          1.59
# CH8-bin.14    44209                   3489          1.45
# CH13-bin.2    37666                   3385          1.10

# %% [markdown]
# **Production**

# %%
FBA_production = {}

interesting_compounds = ["etoh","lac__L","ac","ppa","but","2mpa","isobuta","ibt","pta","hxa","isocap"]

for community, MAGs in community_groups.items(): 
    FBA_production[community]={}
    
    for MAG in MAGs:
        if MAG not in relevant_MAGs:
            continue
        print(MAG)
            
        model = GEMs_dict[MAG]
        syncon1_environments[community[1]].apply(model,inplace=True,exclusive=True)
        
        FBA_production[community][MAG] = {}
        
        for met in interesting_compounds:
            if "R_EX_"+met+"_e" not in model.get_exchange_reactions():
                FBA_production[community][MAG][met]=None
                continue
            
            sol = reframed.FBA(model,objective={"R_EX_"+met+"_e":1})

            if sol is None:
                FBA_production[community][MAG][met]=None
            else:
                FBA_production[community][MAG][met]=sol.fobj
# Out:
# CH13-bin.12
# CH13-bin.14
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_b12_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_ribflv_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_pydxn_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_ni2_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_rbflvrd_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_fol_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_pnto__R_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_na1_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_tungs_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_mobd_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_4abz_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_nac_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_thm_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_ascb__L_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_cell3_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_btn_e
#   warn(f'Exchange reaction not in model: {r_id}')
# CH13-bin.4
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_cellb_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_cell4_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_cell5_e
#   warn(f'Exchange reaction not in model: {r_id}')
# CH13-bin.11
# CH13-bin.25
# CH13-bin.0
# CH13-bin.17
# CH13-bin.1
# CH13-bin.13
# CH13-bin.2
# CH15-bin.0
# CH15-bin.1
# CH15-bin.23
# CH15-bin.7
# CH15-bin.16
# CH15-bin.8
# CH15-bin.17
# CH15-bin.22
# CH15-bin.6
# CH15-bin.5
# CH15-bin.13
# CH15-bin.10
# CH15-bin.12
# CH15-bin.15
# CH15-bin.18
# CH14-bin.1
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_xylb_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_xyl3_e
#   warn(f'Exchange reaction not in model: {r_id}')
# CH14-bin.2
# CH8-bin.22
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_xylan8_e
#   warn(f'Exchange reaction not in model: {r_id}')
# CH8-bin.17
# CH8-bin.25
# CH8-bin.2
# CH8-bin.6
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_cys__L_e
#   warn(f'Exchange reaction not in model: {r_id}')
# CH8-bin.7
# CH8-bin.5
# CH8-bin.8
# CH8-bin.16
# CH8-bin.9
# CH8-bin.21
# CH8-bin.14
# CH8-bin.4
# CH7-bin.23
# CH7-bin.16
# CH7-bin.11
# CH7-bin.13
# CH7-bin.8
# CH7-bin.18
# CH7-bin.2
# CH7-bin.4
# CH7-bin.1
# CH7-bin.17
# CH7-bin.12
# CH7-bin.20
# CH7-bin.9
# CH9-bin.0
# CH9-bin.6
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_xylan4_e
#   warn(f'Exchange reaction not in model: {r_id}')
# CH9-bin.1
# CH9-bin.2
# CH9-bin.5
# CH9-bin.4
# CH1-bin.6
# CH1-bin.9
# CH1-bin.8
# CH1-bin.3
# CH1-bin.4
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_so4_e
#   warn(f'Exchange reaction not in model: {r_id}')
# /Users/idunmariaburgos/opt/anaconda3/envs/MAGs_RecAndAn2/lib/python3.9/site-packages/reframed/core/environment.py:75: UserWarning: Exchange reaction not in model: R_EX_fe2_e
#   warn(f'Exchange reaction not in model: {r_id}')
# CH1-bin.7
# CH3-bin.2
# CH3-bin.1

# %%
pd.DataFrame({GEM:sol for sour_sub,GEM_sol_dict in FBA_production.items() for GEM,sol in GEM_sol_dict.items()}).transpose()
# Out:
#                    etoh     lac__L         ac        ppa        but  2mpa  \
# CH13-bin.12         NaN  10.000000  30.000000        NaN        NaN   NaN
# CH13-bin.14         NaN  70.000000  70.000000  -0.000000        NaN   NaN
# CH13-bin.4          NaN        NaN  -0.000000  -0.000000  -0.000000   NaN
# CH13-bin.11         NaN  20.000000  20.000000  11.764706  -0.000000   NaN
# CH13-bin.25         NaN        NaN  37.777778  48.571429  59.000000   NaN
# ...                 ...        ...        ...        ...        ...   ...
# CH1-bin.3           NaN        NaN  74.883721        NaN        NaN  77.0
# CH1-bin.4           NaN        NaN  10.000000        NaN  10.000000   NaN
# CH1-bin.7     10.000000  -0.000000  21.052632  16.666667  25.833333   NaN
# CH3-bin.2    182.694656  50.000000  50.000000        NaN  50.000000   NaN
# CH3-bin.1           NaN  47.893639  36.666667  41.803279        NaN   NaN
#
#              isobuta   ibt        pta        hxa  isocap
# CH13-bin.12      NaN   NaN        NaN        NaN     NaN
# CH13-bin.14      NaN   NaN  70.000000  70.000000   111.5
# CH13-bin.4      -0.0   NaN  -0.000000  -0.000000     NaN
# CH13-bin.11      NaN   NaN        NaN  -0.000000     NaN
# CH13-bin.25      NaN   NaN        NaN  -0.000000     NaN
# ...              ...   ...        ...        ...     ...
# CH1-bin.3        NaN   NaN  -0.000000  -0.000000     NaN
# CH1-bin.4        NaN   NaN        NaN  -0.000000     NaN
# CH1-bin.7        NaN   NaN  20.666667   4.615385     NaN
# CH3-bin.2      122.8  50.0        NaN  -0.000000     NaN
# CH3-bin.1        NaN   NaN  45.348837  41.417910     NaN
#
# [67 rows x 11 columns]

# %%
# Add the source and substrate to this data
prod_sour_sub_df= pd.concat([all_mags_paper.loc[:,["Source","Substrate"]],pd.DataFrame({GEM:sol for sour_sub,GEM_sol_dict in FBA_production.items() for GEM,sol in GEM_sol_dict.items()}).transpose()],axis=1)

prod_sour_sub_df.fillna(0,inplace=True)

# %%
# Change from floats to binary
prod_sour_sub_df_bools =  prod_sour_sub_df.iloc[:,:2]

prod_sour_sub_df_bools = pd.concat([prod_sour_sub_df_bools,prod_sour_sub_df.iloc[:,2:].map(lambda x:x>1e-6)],axis=1)

prod_sour_sub_df_bools
# Out:
#                         Source Substrate   etoh  lac__L     ac    ppa    but  \
# CH3-bin.2            Marshland     Xylan   True    True   True  False   True
# CH9-bin.0           Cow_Manure     Xylan  False   False   True  False  False
# CH14-bin.1   Compost_Digestate     Xylan   True    True   True  False   True
# CH1-bin.6            Marshland      PASC  False    True   True  False   True
# CH7-bin.23          Cow_Manure      PASC  False    True   True  False  False
# ...                        ...       ...    ...     ...    ...    ...    ...
# CH7-bin.25          Cow_Manure      PASC  False   False  False  False  False
# CH13-bin.22  Compost_Digestate    Avicel  False   False  False  False  False
# CH1-bin.0            Marshland      PASC  False   False  False  False  False
# CH13-bin.16  Compost_Digestate    Avicel  False   False  False  False  False
# CH15-bin.4   Compost_Digestate      PASC  False   False  False  False  False
#
#               2mpa  isobuta    ibt    pta    hxa  isocap
# CH3-bin.2    False     True   True  False  False   False
# CH9-bin.0    False    False   True  False  False   False
# CH14-bin.1   False    False   True   True   True    True
# CH1-bin.6    False    False  False  False  False    True
# CH7-bin.23   False    False   True  False  False   False
# ...            ...      ...    ...    ...    ...     ...
# CH7-bin.25   False    False  False  False  False   False
# CH13-bin.22  False    False  False  False  False   False
# CH1-bin.0    False    False  False  False  False   False
# CH13-bin.16  False    False  False  False  False   False
# CH15-bin.4   False    False  False  False  False   False
#
# [101 rows x 13 columns]

# %%
# Group by source and substrate
prod_sour_sub_grouped_df = prod_sour_sub_df_bools.groupby(["etoh"]).value_counts()

# %%
prod_sour_sub_df_bools.groupby(["Source","Substrate"]).sum().transpose().plot(kind="barh",figsize=(12,10))
plt.xlabel("Count")
plt.ylabel("fermentation product")
plt.title("Count of fermentation products procuers")
plt.show()

# %% [markdown]
# #### Production in complete media

# %%
FBA_production_complete = {}

interesting_compounds = ["etoh","lac__L","ac","ppa","but","2mpa","isobuta","ibt","pta","hxa","isocap"]


for MAG,model in GEMs_dict.items(): 
    print(MAG)
    FBA_production_complete[MAG]={}
        
    model = GEMs_dict[MAG]
    reframed.Environment.complete(model=model,inplace=True)
    
    for met in interesting_compounds:
        if "R_EX_"+met+"_e" not in model.get_exchange_reactions():
            FBA_production_complete[MAG][met]=None
            continue

        sol = reframed.FBA(model,objective={"R_EX_"+met+"_e":1})

        if sol is None:
            FBA_production_complete[MAG][met]=None
        else:
            FBA_production_complete[MAG][met]=sol.fobj
# Out:
# CH3-bin.2
# CH9-bin.0
# CH14-bin.1
# CH1-bin.6
# CH7-bin.23
# CH8-bin.22
# CH13-bin.12
# CH1-bin.9
# CH3-bin.1
# CH14-bin.2
# CH15-bin.0
# CH13-bin.14
# CH9-bin.6
# CH13-bin.4
# CH15-bin.1
# CH15-bin.23
# CH8-bin.17
# CH13-bin.11
# CH15-bin.7
# CH7-bin.16
# CH15-bin.16
# CH15-bin.8
# CH13-bin.25
# CH7-bin.11
# CH8-bin.25
# CH9-bin.1
# CH7-bin.13
# CH8-bin.2
# CH15-bin.17
# CH15-bin.22
# CH1-bin.8
# CH15-bin.6
# CH8-bin.6
# CH13-bin.0
# CH8-bin.7
# CH13-bin.17
# CH1-bin.3
# CH15-bin.5
# CH15-bin.13
# CH7-bin.8
# CH1-bin.4
# CH7-bin.18
# CH8-bin.5
# CH9-bin.2
# CH7-bin.2
# CH9-bin.5
# CH7-bin.4
# CH8-bin.8
# CH15-bin.10
# CH7-bin.1
# CH15-bin.12
# CH7-bin.17
# CH9-bin.4
# CH1-bin.7
# CH15-bin.15
# CH8-bin.16
# CH8-bin.9
# CH7-bin.12
# CH13-bin.1
# CH7-bin.20
# CH8-bin.21
# CH8-bin.14
# CH7-bin.9
# CH13-bin.13
# CH13-bin.2
# CH8-bin.4
# CH15-bin.18

# %%
prod_complete = pd.DataFrame(FBA_production_complete)
prod_complete
# Out:
#            CH3-bin.2  CH9-bin.0   CH14-bin.1    CH1-bin.6  CH7-bin.23  \
# etoh     3038.740741        NaN  3344.960317          NaN         NaN
# lac__L   1495.000000        NaN  1334.261364  1675.000000  786.818182
# ac       1505.000000      695.0  1318.389640  1675.000000  952.430011
# ppa              NaN        NaN    -0.000000    -0.000000   -0.000000
# but      1505.000000        NaN  1366.948718  1695.000000         NaN
# 2mpa             NaN        NaN          NaN          NaN         NaN
# isobuta  1567.583333        NaN          NaN          NaN         NaN
# ibt      1438.076923      695.0  1353.375000          NaN  541.105006
# pta              NaN       -0.0  1197.000000          NaN         NaN
# hxa        -0.000000        NaN  1354.396552          NaN   -0.000000
# isocap           NaN        NaN  1540.892857  1556.846611         NaN
#
#          CH8-bin.22  CH13-bin.12   CH1-bin.9    CH3-bin.1   CH14-bin.2  ...  \
# etoh            NaN          NaN  702.578231          NaN          NaN  ...
# lac__L    10.000000    10.000000  645.388889  1211.911765          NaN  ...
# ac       384.196595   400.952381  682.236842  1027.830189  1559.166667  ...
# ppa      375.208333          NaN  221.475410  1145.819672  1549.166667  ...
# but             NaN          NaN  557.756410          NaN          NaN  ...
# 2mpa            NaN          NaN         NaN          NaN          NaN  ...
# isobuta         NaN          NaN         NaN          NaN          NaN  ...
# ibt             NaN          NaN         NaN          NaN          NaN  ...
# pta             NaN          NaN   -0.000000  1156.148649          NaN  ...
# hxa             NaN          NaN   -0.000000   941.488095    -0.000000  ...
# isocap          NaN          NaN         NaN          NaN          NaN  ...
#
#          CH7-bin.12  CH13-bin.1   CH7-bin.20  CH8-bin.21  CH8-bin.14  \
# etoh            NaN         NaN  2311.504209         NaN         NaN
# lac__L          NaN  742.440863          NaN         NaN         NaN
# ac       417.500000  917.500000   936.855556  510.104167  1010.00000
# ppa       -0.000000         NaN   851.262755         NaN   968.28125
# but      106.349206         NaN  1002.500000   30.024393  1020.00000
# 2mpa            NaN         NaN          NaN         NaN         NaN
# isobuta         NaN  730.562914          NaN         NaN         NaN
# ibt             NaN         NaN   992.500000  520.700000         NaN
# pta             NaN   -0.000000          NaN         NaN         NaN
# hxa       -0.000000   -0.000000    -0.000000   -0.000000    10.00000
# isocap          NaN         NaN          NaN         NaN         NaN
#
#           CH7-bin.9  CH13-bin.13  CH13-bin.2   CH8-bin.4  CH15-bin.18
# etoh            NaN          NaN         NaN         NaN  3001.027858
# lac__L   231.328125          NaN  617.903226         NaN  1577.500000
# ac       537.122123   797.361111  814.529412  647.500000  1587.500000
# ppa             NaN   765.694444   -0.000000   -0.000000  1429.125000
# but      877.277795  1153.541667         NaN  832.333333  1587.500000
# 2mpa            NaN          NaN         NaN         NaN          NaN
# isobuta         NaN          NaN         NaN         NaN          NaN
# ibt             NaN          NaN         NaN         NaN          NaN
# pta       -0.000000          NaN         NaN  591.017422  1417.192982
# hxa      624.499731    -0.000000   -0.000000  531.492823  1441.779661
# isocap          NaN          NaN         NaN         NaN  1308.037348
#
# [11 rows x 67 columns]
