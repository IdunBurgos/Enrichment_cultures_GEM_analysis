# %% [markdown]
# # Data showing MAG-community association

# %%
import pandas as pd
import reframed
import os
import json
import sys
sys.path.append('../functions')

import translation_dicts
import general_functions as general_func

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
compounds_dict, source_dict,substrate_dict, gas_sheet_dict, community_dict = translation_dicts.translation_dicts()

# %% [markdown]
# ### Read data and models

# %% [markdown]
# **Read data**

# %%
all_Mags_for_paper_analysis = general_func.read_allmags_data()
all_Mags_for_paper_analysis
# Out:
#                        Source Substrate  Completeness (%)  Contamination (%)  \
# MAG
# CH14-bin.1  Compost_Digestate     Xylan             99.37               0.32
# CH14-bin.2  Compost_Digestate     Xylan             99.37               0.63
# CH14-bin.4  Compost_Digestate     Xylan             99.41               0.59
# CH9-bin.0          Cow_Manure     Xylan             99.03               2.82
# CH9-bin.6          Cow_Manure     Xylan            100.00               0.00
# ...                       ...       ...               ...                ...
# CH8-bin.21         Cow_Manure    Avicel             94.43               3.02
# CH8-bin.8          Cow_Manure    Avicel            100.00               0.00
# CH8-bin.29         Cow_Manure    Avicel             95.99               0.55
# CH8-bin.14         Cow_Manure    Avicel             97.98               1.15
# CH14-bin.0  Compost_Digestate     Xylan               NaN                NaN
#
#               Domain            Phylum             Class               Order  \
# MAG
# CH14-bin.1  Bacteria        Firmicutes        Clostridia      Lachnospirales
# CH14-bin.2  Bacteria        Firmicutes        Clostridia      Lachnospirales
# CH14-bin.4  Bacteria  Desulfobacterota  Desulfovibrionia  Desulfovibrionales
# CH9-bin.0   Bacteria  Actinobacteriota     Actinomycetia     Actinomycetales
# CH9-bin.6   Bacteria        Firmicutes           Bacilli  Erysipelotrichales
# ...              ...               ...               ...                 ...
# CH8-bin.21  Bacteria      Bacteroidota       Bacteroidia       Bacteroidales
# CH8-bin.8   Bacteria  Desulfobacterota  Desulfovibrionia  Desulfovibrionales
# CH8-bin.29  Bacteria      Bacteroidota       Bacteroidia       Bacteroidales
# CH8-bin.14  Bacteria        Firmicutes        Clostridia  Christensenellales
# CH14-bin.0  Bacteria         Bacillota        Clostridia       Eubacteriales
#
#                          Family                   Genus  \
# MAG
# CH14-bin.1      Lachnospiraceae            Lacrimispora
# CH14-bin.2      Lachnospiraceae           Robinsoniella
# CH14-bin.4  Desulfovibrionaceae           Desulfovibrio
# CH9-bin.0    Bifidobacteriaceae         Bifidobacterium
# CH9-bin.6      Coprobacillaceae  Erysipelatoclostridium
# ...                         ...                     ...
# CH8-bin.21               UBA932                  DMER64
# CH8-bin.8   Desulfovibrionaceae      Desulfocurvibacter
# CH8-bin.29    Dysgonomonadaceae          Proteiniphilum
# CH8-bin.14               CAG-74              Limiplasma
# CH14-bin.0   Acutalibacteraceae        Caproicproducens
#
#                                    Species  Genome size (bp)  Scaffolds  \
# MAG
# CH14-bin.1       Lacrimispora amygdalina_A         5147597.0       48.0
# CH14-bin.2        Robinsoniella peoriensis         5647052.0       70.0
# CH14-bin.4          Desulfovibrio legallii         2785393.0      156.0
# CH9-bin.0                              NaN         2513253.0       38.0
# CH9-bin.6   Erysipelatoclostridium ramosum         3208880.0       42.0
# ...                                    ...               ...        ...
# CH8-bin.21              DMER64 sp002408205         2584209.0      141.0
# CH8-bin.8                              NaN         3921615.0       63.0
# CH8-bin.29      Proteiniphilum sp012837345         2514759.0      114.0
# CH8-bin.14                             NaN         3950459.0      143.0
# CH14-bin.0                             NaN               NaN        NaN
#
#                  N50  CDS prediction (DRAM)     Column1  new_coverage
# MAG
# CH14-bin.1  197896.0                 4902.0  CH14-bin.1     54.707294
# CH14-bin.2  172899.0                 4618.0  CH14-bin.2     18.831114
# CH14-bin.4   29605.0                 2420.0  CH14-bin.4      2.741818
# CH9-bin.0   128964.0                 2055.0   CH9-bin.0     70.451904
# CH9-bin.6   126720.0                 3152.0   CH9-bin.6      9.662049
# ...              ...                    ...         ...           ...
# CH8-bin.21   46653.0                 2199.0  CH8-bin.21      1.713873
# CH8-bin.8   193203.0                 3587.0   CH8-bin.8      1.574371
# CH8-bin.29   36600.0                 2110.0  CH8-bin.29      1.084728
# CH8-bin.14   44209.0                 3489.0  CH8-bin.14      1.051194
# CH14-bin.0       NaN                    NaN  CH14-bin.0     15.617491
#
# [73 rows x 17 columns]

# %%
all_Mags_for_paper_analysis.groupby(["Source","Substrate"]).sum()["new_coverage"]
# Out:
# Source             Substrate
# Compost_Digestate  Avicel       85.726371
#                    PASC         89.666909
#                    Xylan        91.897717
# Cow_Manure         Avicel       83.446857
#                    PASC         87.168208
#                    Xylan        89.437796
# Marshland          PASC         94.517337
#                    Xylan        97.097080
# Name: new_coverage, dtype: float64

# %%
MAG2community_id = pd.Series({MAG:community_dict[community_id] for community_id,MAGs in all_Mags_for_paper_analysis.groupby(["Source","Substrate"]).groups.items() for MAG in MAGs})
MAG2community_id
# Out:
# CH13-bin.12    CD_A
# CH13-bin.11    CD_A
# CH13-bin.4     CD_A
# CH13-bin.14    CD_A
# CH13-bin.25    CD_A
#                ...
# CH1-bin.1       M_P
# CH1-bin.10      M_P
# CH3-bin.2       M_X
# CH3-bin.1       M_X
# CH3-bin.0       M_X
# Length: 73, dtype: object

# %% [markdown]
# ## Save data

# %%
MAG2community_id.to_csv("../output/MAG2community_id.tsv",sep="\t",header=False)
