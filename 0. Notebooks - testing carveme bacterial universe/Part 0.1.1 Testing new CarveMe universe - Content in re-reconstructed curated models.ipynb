# %% [markdown]
# # Testing the reconstruction of our previous models

# %% [markdown]
# - GCF_902809985.1 - BL-3 -> original model: iIB931.xml
# - GCF_902809935.1 - BL-4 -> original model: iIB600.xml
# - GCF_000022065.1 - R. cellulolyticum -> orginial model: iIB746

# %%
import reframed
import pandas as pd
import matplotlib_venn

# %%
import pandas as pd

# %% [markdown]
# ### Load universal model additions

# %%
rxns_add = pd.read_csv("~/universal_model_extension/output/universal_model_changes/rxns_add.tsv",sep="\t")
rxns_add
# Out:
#             rxn         origin  part
# 0   R_EX_XAXX_e         iIB746   2.1
# 1     R_QLQGabc         iIB746   2.1
# 2        R_BUTt         iIB933   2.1
# 3     R_PPAdiff         iIB600   2.1
# 4     R_XYLqqqg         iIB746   2.1
# ..          ...            ...   ...
# 63  R_GHAa23xx2         iIB746   2.1
# 64   R_GHAxa23x         iIB746   2.1
# 65    R_QQQGabc         iIB746   2.1
# 66      R_Acabc         iIB600   2.1
# 67      R_IBTCT  iIB933,iIB600   2.1
#
# [68 rows x 3 columns]

# %%
bigg_gprs = pd.read_csv("/Users/idunmariaburgos/universal_model_extension/output/bigg_gprs.csv")

# %%
bigg_gprs
# Out:
#                    gene                                            protein  \
# 0       G_ABAYE_RS01830                                    P_ABAYE_RS01830
# 1       G_ABAYE_RS14015                                    P_ABAYE_RS14015
# 2       G_ABAYE_RS07335  P_ABAYE_RS07335+ABAYE_RS07340+ABAYE_RS07345+AB...
# 3       G_ABAYE_RS07340  P_ABAYE_RS07335+ABAYE_RS07340+ABAYE_RS07345+AB...
# 4       G_ABAYE_RS07345  P_ABAYE_RS07335+ABAYE_RS07340+ABAYE_RS07345+AB...
# ...                 ...                                                ...
# 108288          G_s0001                                            P_s0001
# 108289          G_s0001                                            P_s0001
# 108290          G_s0001                                            P_s0001
# 108291          G_s0001                                            P_s0001
# 108292          G_s0001                                            P_s0001
#
#          reaction   model
# 0         R_HCO3E  iCN718
# 1         R_HCO3E  iCN718
# 2         R_CYTBD  iCN718
# 3         R_CYTBD  iCN718
# 4         R_CYTBD  iCN718
# ...           ...     ...
# 108288  R_HXAdiff  iIB600
# 108289  R_IBTdiff  iIB600
# 108290  R_PTAdiff  iIB933
# 108291  R_HXAdiff  iIB933
# 108292  R_IBTdiff  iIB933
#
# [108293 rows x 4 columns]

# %%
rxns_list = list(rxns_add["rxn"].values)
models_list = [models.split(",") for models in rxns_add["origin"].values]
rxns_dict = dict(zip(rxns_list, models_list))

# %% [markdown]
# ### Check models

# %% [markdown]
# #### R. cellulolyticum

# %%
rxns_origin = list(set(bigg_gprs[bigg_gprs["model"]=="iIB746"]["reaction"].values))

model_rcel = reframed.load_cbmodel("output/GEMs_test/RCell_H10_test.xml")
rxns_carve = list(model_rcel.reactions.keys())

# %%
matplotlib_venn.venn2([set(rxns_origin),set(rxns_carve)],set_labels=["original model","carved model"])

# %% [markdown]
# #### Clostridia BL-3

# %% [markdown]
# It is missing the transporter because this one was not in the refseq system (does not have gene starting with WP_ but with CAB_).

# %%
rxns_origin = list(set(bigg_gprs[bigg_gprs["model"]=="iIB933"]["reaction"].values))

model_bl3 = reframed.load_cbmodel("output/GEMs_test/clostridiaBL3_test.xml")
rxns_carve = list(model_bl3.reactions.keys())

# %%
matplotlib_venn.venn2([set(rxns_origin),set(rxns_carve)],set_labels=["original model","carved model"])

# %%
set(rxns_origin)-set(rxns_carve)
# Out:
# set()

# %%
env = reframed.Environment.complete(model_bl3)
sol = reframed.pFBA(model_bl3, constraints=env)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-03-14

# %%
model_bl3.get_metabolite_reactions("M_fdxo_2_2_c")
# Out:
# ['R_POR_syn',
#  'R_FNRR3_1',
#  'R_VOR2bE_1',
#  'R_BCD3',
#  'R_BCD1',
#  'R_FRROX',
#  'R_BCD2']

# %% [markdown]
# #### Clostridia BL-4

# %% [markdown]
# It is missing the transporter because this one was not in the refseq system (does not have gene starting with WP_ but with CAB_).

# %%
rxns_origin = list(set(bigg_gprs[bigg_gprs["model"]=="iIB600"]["reaction"].values))

model_bl4 = reframed.load_cbmodel("output/GEMs_test/clostridiaBL4_test.xml")
rxns_carve = list(model_bl4.reactions.keys())

# %%
matplotlib_venn.venn2([set(rxns_origin),set(rxns_carve)],set_labels=["original model","carved model"])

# %%
set(rxns_origin)-set(rxns_carve)
# Out:
# set()

# %%
model_bl4_orig = reframed.load_cbmodel("/Users/idunmariaburgos/universal_model_extension/input/curated_models_newId/iIB600.xml")

# %%
matplotlib_venn.venn2([set(model_bl4_orig.reactions.keys()),set(model_bl4.reactions.keys())],set_labels=["original model","carved model"])

# %%
matplotlib_venn.venn2([set(model_bl4_orig.metabolites.keys()),set(model_bl4.metabolites.keys())],set_labels=["original model","carved model"])

# %%
matplotlib_venn.venn2([set(model_bl4_orig.genes.keys()),set(model_bl4.genes.keys())],set_labels=["original model","carved model"])

# %%
model_rcel_orig = reframed.load_cbmodel("/Users/idunmariaburgos/universal_model_extension/input/curated_models_newId/iIB746.xml")

# %%
matplotlib_venn.venn2([set(model_rcel_orig.reactions.keys()),set(model_rcel.reactions.keys())],set_labels=["original model","carved model"]);

# %%
matplotlib_venn.venn2([set(model_rcel_orig.metabolites.keys()),set(model_rcel.metabolites.keys())],set_labels=["original model","carved model"]);

# %%
matplotlib_venn.venn2([set([gene.replace("G_","") for gene in model_rcel_orig.genes.keys()]),set([gene.replace("G_","") for gene in model_rcel.genes.keys()])],set_labels=["original model","carved model"]);

# %%
rcel_gene_stats = pd.read_csv("output/GEMs_test/RCell_H10_test_gene_scores.tsv",sep="\t")
rcel_gene_stats
# Out:
#         query_gene             BiGG_gene  score             gene  \
# 0              NaN  iCN718.ABAYE_RS01830    NaN  G_ABAYE_RS01830
# 1              NaN  iCN718.ABAYE_RS14015    NaN  G_ABAYE_RS14015
# 2              NaN  iCN718.ABAYE_RS07335    NaN  G_ABAYE_RS07335
# 3              NaN  iCN718.ABAYE_RS07340    NaN  G_ABAYE_RS07340
# 4              NaN  iCN718.ABAYE_RS07345    NaN  G_ABAYE_RS07345
# ...            ...                   ...    ...              ...
# 47185  spontaneous          iIB600.s0001    0.0          G_s0001
# 47186  spontaneous          iIB600.s0001    0.0          G_s0001
# 47187  spontaneous          iIB933.s0001    0.0          G_s0001
# 47188  spontaneous          iIB933.s0001    0.0          G_s0001
# 47189  spontaneous          iIB933.s0001    0.0          G_s0001
#
#                                                  protein   reaction   model
# 0                                        P_ABAYE_RS01830    R_HCO3E  iCN718
# 1                                        P_ABAYE_RS14015    R_HCO3E  iCN718
# 2      P_ABAYE_RS07335+ABAYE_RS07340+ABAYE_RS07345+AB...    R_CYTBD  iCN718
# 3      P_ABAYE_RS07335+ABAYE_RS07340+ABAYE_RS07345+AB...    R_CYTBD  iCN718
# 4      P_ABAYE_RS07335+ABAYE_RS07340+ABAYE_RS07345+AB...    R_CYTBD  iCN718
# ...                                                  ...        ...     ...
# 47185                                            P_s0001  R_HXAdiff  iIB600
# 47186                                            P_s0001  R_IBTdiff  iIB600
# 47187                                            P_s0001  R_PTAdiff  iIB933
# 47188                                            P_s0001  R_HXAdiff  iIB933
# 47189                                            P_s0001  R_IBTdiff  iIB933
#
# [47190 rows x 7 columns]

# %%
genes_not_in_model = list(set([gene.replace("G_","") for gene in model_rcel_orig.genes.keys()])-set([gene.replace("G_","") for gene in model_rcel.genes.keys()]))

genes_not_in_model = [gene.replace("G_","") for gene in genes_not_in_model]
genes_not_in_model = [gene.replace("_1",".1") for gene in genes_not_in_model]

# %%
rcel_gene_stats[rcel_gene_stats["query_gene"].isin(genes_not_in_model)]
# Out:
#            query_gene                    BiGG_gene  score  \
# 163    WP_015925543.1         iCN718.ABAYE_RS17405  112.5
# 1154   WP_015925219.1              iYO844.BSU23610  144.8
# 1313   WP_015925108.1              iYO844.BSU32000  124.8
# 2632   WP_015924192.1           iCN900.CD630_15430  282.0
# 3419   WP_015925432.1           iCN900.CD630_24640  338.2
# 3420   WP_242651714.1           iCN900.CD630_27410  399.1
# 3484   WP_041706909.1           iCN900.CD630_19040  253.1
# 3627   WP_015925219.1          iHN637.CLJU_RS05505  156.8
# 5801   WP_015924526.1                iML1515.b2091  253.1
# 5968   WP_015924795.1                iML1515.b2738  109.0
# 7300   WP_015925223.1                iML1515.b2975  104.8
# 7895   WP_015925223.1                iML1515.b2975  104.8
# 8365   WP_015925223.1                iML1515.b2975  104.8
# 11478  WP_015926714.1                iIT341.HP0381  132.5
# 13016  WP_015924795.1            iYL1228.KPN_01603  119.8
# 13306  WP_015924526.1            iYL1228.KPN_03551  248.8
# 15524  WP_015924405.1          iNF517.LLMG_RS07160  145.6
# 17868  WP_015926061.1               iEK1008.Rv3175  146.0
# 18346  WP_015924498.1              iEK1008.Rv2383c  520.8
# 18853  WP_015925343.1               iEK1008.Rv0125  111.3
# 22149  WP_015924622.1              iJN1463.PP_0310  161.8
# 22304  WP_015925223.1              iJN1463.PP_4735  104.0
# 22827  WP_015925223.1              iJN1463.PP_4735  104.0
# 23318  WP_015924088.1              iJN1463.PP_3461  194.1
# 23340  WP_015925543.1              iJN1463.PP_0416  121.3
# 23869  WP_015924622.1              iJN1463.PP_1478  177.6
# 23878  WP_015924622.1              iJN1463.PP_1478  177.6
# 24777  WP_015925223.1              iJN1463.PP_4735  104.0
# 26518  WP_015924795.1             STM_v1_0.STM2916  114.0
# 28773  WP_015924526.1             STM_v1_0.STM3261  266.9
# 28926  WP_015925101.1             STM_v1_0.STM2065  194.9
# 28932  WP_015925101.1             STM_v1_0.STM2065  194.9
# 28940  WP_015925101.1             STM_v1_0.STM2065  194.9
# 30034  WP_015924795.1  iSbBS512_1146.SbBS512_E3136  109.0
# 30389  WP_015924526.1  iSbBS512_1146.SbBS512_E1147  251.9
# 33455  WP_015924526.1           iSDY_1059.SDY_2263  248.4
# 36513  WP_015924526.1              iSF_1195.SF2151  252.3
# 39646  WP_015924795.1         iSSON_1240.SSON_2886  109.0
# 39962  WP_015924526.1         iSSON_1240.SSON_2138  248.8
# 42311  WP_015925722.1     iYS854.USA300HOU_RS04115  273.5
# 42353  WP_015925219.1     iYS854.USA300HOU_RS08015  149.8
# 44202  WP_015926349.1        iSynCJ816.SGL_RS16645  134.4
#
#                       gene                                            protein  \
# 163        G_ABAYE_RS17405                                    P_ABAYE_RS17405
# 1154            G_BSU23610                                         P_BSU23610
# 1313            G_BSU32000                                         P_BSU32000
# 2632         G_CD630_15430                                      P_CD630_15430
# 3419         G_CD630_24640                                      P_CD630_24640
# 3420         G_CD630_27410                                      P_CD630_27410
# 3484         G_CD630_19040              P_CD630_19040+CD630_29890+CD630_29900
# 3627        G_CLJU_RS05505                                     P_CLJU_RS05505
# 5801               G_b2091                                            P_b2091
# 5968               G_b2738                                            P_b2738
# 7300               G_b2975                                            P_b2975
# 7895               G_b2975                                            P_b2975
# 8365               G_b2975                                            P_b2975
# 11478             G_HP0381                                           P_HP0381
# 13016          G_KPN_01603                                        P_KPN_01603
# 13306          G_KPN_03551                                        P_KPN_03551
# 15524       G_LLMG_RS07160                                     P_LLMG_RS07160
# 17868             G_Rv3175                                           P_Rv3175
# 18346            G_Rv2383c  P_Rv2378c+Rv2379c+Rv2380c+Rv2381c+Rv2382c+Rv23...
# 18853             G_Rv0125                                           P_Rv0125
# 22149            G_PP_0310                                  P_PP_0310+PP_0311
# 22304            G_PP_4735                                          P_PP_4735
# 22827            G_PP_4735                                          P_PP_4735
# 23318            G_PP_3461                  P_PP_3459+PP_3460+PP_3461+PP_3462
# 23340            G_PP_0416                                          P_PP_0416
# 23869            G_PP_1478                                          P_PP_1478
# 23878            G_PP_1478                                          P_PP_1478
# 24777            G_PP_4735                                          P_PP_4735
# 26518            G_STM2916                                          P_STM2916
# 28773            G_STM3261                                          P_STM3261
# 28926            G_STM2065                          P_STM2063+STM2064+STM2065
# 28932            G_STM2065                          P_STM2063+STM2064+STM2065
# 28940            G_STM2065                          P_STM2063+STM2064+STM2065
# 30034      G_SbBS512_E3136                                    P_SbBS512_E3136
# 30389      G_SbBS512_E1147                                    P_SbBS512_E1147
# 33455           G_SDY_2263                                         P_SDY_2263
# 36513             G_SF2151                                           P_SF2151
# 39646          G_SSON_2886                                        P_SSON_2886
# 39962          G_SSON_2138                                        P_SSON_2138
# 42311  G_USA300HOU_RS04115                                P_USA300HOU_RS04115
# 42353  G_USA300HOU_RS08015                                P_USA300HOU_RS08015
# 44202        G_SGL_RS16645  P_SGL_RS16640+SGL_RS16645+SGL_RS16650+SGL_RS17635
#
#               reaction          model
# 163           R_PGLYCP         iCN718
# 1154          R_ADPRDP         iYO844
# 1313            R_DHBD         iYO844
# 2632           R_ACPPD         iCN900
# 3419         R_CPPPGO2         iCN900
# 3420         R_CPPPGO2         iCN900
# 3484          R_NO3abc         iCN900
# 3627          R_ADPRDP         iHN637
# 5801           R_GLTPD        iML1515
# 5968           R_FCLPA        iML1515
# 7300      R_L_LACt2rpp        iML1515
# 7895     R_GLYCLTt2rpp        iML1515
# 8365       R_D_LACt2pp        iML1515
# 11478          R_PPPGO         iIT341
# 13016          R_FCLPA        iYL1228
# 13306          R_GLTPD        iYL1228
# 15524         R_CPPPGO         iNF517
# 17868          R_AMID4        iEK1008
# 18346         R_MCBTS3        iEK1008
# 18853           R_PEPA        iEK1008
# 22149           R_GBDM        iJN1463
# 22304    R_GLYCLTt2rpp        iJN1463
# 22827     R_L_LACt2rpp        iJN1463
# 23318      R_PEAMNO2pp        iJN1463
# 23340         R_PGLYCP        iJN1463
# 23869          R_TNTR1        iJN1463
# 23878          R_TNTR2        iJN1463
# 24777      R_D_LACt2pp        iJN1463
# 26518          R_FCLPA       STM_v1_0
# 28773          R_GLTPD       STM_v1_0
# 28926      R_TSULDHpp1       STM_v1_0
# 28932      R_TSULDHpp2       STM_v1_0
# 28940      R_TSULDHpp3       STM_v1_0
# 30034          R_FCLPA  iSbBS512_1146
# 30389          R_GLTPD  iSbBS512_1146
# 33455          R_GLTPD      iSDY_1059
# 36513          R_GLTPD       iSF_1195
# 39646          R_FCLPA     iSSON_1240
# 39962          R_GLTPD     iSSON_1240
# 42311        R_AMANK_1         iYS854
# 42353       R_ADPRDP_1         iYS854
# 44202  R_SUCRabcpp_syn      iSynCJ816

# %%
RCell_H10_test_protein_scores = pd.read_csv("output/GEMs_test/RCell_H10_test_protein_scores.tsv",sep="\t")
RCell_H10_test_protein_scores
# Out:
#            protein       reaction          model  GPR  score
# 0            P_100          R_ADA    iAT_PLT_636  NaN    0.0
# 1            P_100         R_DADA    iAT_PLT_636  NaN    0.0
# 2      P_100043349         R_GAPD        iMM1415  NaN    0.0
# 3         P_100678        R_PSP_L        iMM1415  NaN    0.0
# 4      P_100689028         R_DHFR         iCHOv1  NaN    0.0
# ...            ...            ...            ...  ...    ...
# 38436       P_yjjL  R_GALCTNLt2pp      iSDY_1059  NaN    0.0
# 38437       P_yjjL  R_GALCTNLt2pp     iSSON_1240  NaN    0.0
# 38438       P_yjjL  R_GALCTNLt2pp  iSbBS512_1146  NaN    0.0
# 38439       P_yliF        R_DGUNC  iSbBS512_1146  NaN    0.0
# 38440       P_yneF        R_DGUNC  iSbBS512_1146  NaN    0.0
#
# [38441 rows x 5 columns]

# %%
RCell_H10_test_protein_scores[RCell_H10_test_protein_scores["GPR"].isin(genes_not_in_model)]
# Out:
#                                                  protein         reaction  \
# 2733                                     P_ABAYE_RS17405         R_PGLYCP
# 3318                                          P_BSU23610         R_ADPRDP
# 3531                                          P_BSU32000           R_DHBD
# 4190                                       P_CD630_15430          R_ACPPD
# 4339               P_CD630_19040+CD630_29890+CD630_29900         R_NO3abc
# 4514                                       P_CD630_24640        R_CPPPGO2
# 4603                                       P_CD630_27410        R_CPPPGO2
# 5038                                      P_CLJU_RS05505         R_ADPRDP
# 7098                                            P_HP0381          R_PPPGO
# 8680                                         P_KPN_01603          R_FCLPA
# 9773                                         P_KPN_03551          R_GLTPD
# 10580                                     P_LLMG_RS07160         R_CPPPGO
# 13243                                  P_PP_0310+PP_0311           R_GBDM
# 13290                                          P_PP_0416         R_PGLYCP
# 13865                                          P_PP_1478          R_TNTR1
# 13866                                          P_PP_1478          R_TNTR2
# 14713                  P_PP_3459+PP_3460+PP_3461+PP_3462      R_PEAMNO2pp
# 15214                                          P_PP_4735      R_D_LACt2pp
# 15215                                          P_PP_4735    R_GLYCLTt2rpp
# 15216                                          P_PP_4735     R_L_LACt2rpp
# 16091                                           P_Rv0125           R_PEPA
# 16573  P_Rv2378c+Rv2379c+Rv2380c+Rv2381c+Rv2382c+Rv23...         R_MCBTS3
# 16727                                           P_Rv3175          R_AMID4
# 17826                                         P_SDY_2263          R_GLTPD
# 20570                                           P_SF2151          R_GLTPD
# 22353  P_SGL_RS16640+SGL_RS16645+SGL_RS16650+SGL_RS17635  R_SUCRabcpp_syn
# 24048                                        P_SSON_2138          R_GLTPD
# 24608                                        P_SSON_2886          R_FCLPA
# 26883                          P_STM2063+STM2064+STM2065      R_TSULDHpp1
# 26884                          P_STM2063+STM2064+STM2065      R_TSULDHpp2
# 26885                          P_STM2063+STM2064+STM2065      R_TSULDHpp3
# 27442                                          P_STM2916          R_FCLPA
# 27631                                          P_STM3261          R_GLTPD
# 29107                                    P_SbBS512_E1147          R_GLTPD
# 30361                                    P_SbBS512_E3136          R_FCLPA
# 31890                                P_USA300HOU_RS04115        R_AMANK_1
# 32131                                P_USA300HOU_RS08015       R_ADPRDP_1
# 36602                                            P_b2091          R_GLTPD
# 37197                                            P_b2738          R_FCLPA
# 37339                                            P_b2975      R_D_LACt2pp
# 37340                                            P_b2975    R_GLYCLTt2rpp
# 37341                                            P_b2975     R_L_LACt2rpp
#
#                model             GPR       score
# 2733          iCN718  WP_015925543.1  112.500000
# 3318          iYO844  WP_015925219.1  144.800000
# 3531          iYO844  WP_015925108.1  124.800000
# 4190          iCN900  WP_015924192.1  282.000000
# 4339          iCN900  WP_041706909.1   84.366667
# 4514          iCN900  WP_015925432.1  338.200000
# 4603          iCN900  WP_242651714.1  399.100000
# 5038          iHN637  WP_015925219.1  156.800000
# 7098          iIT341  WP_015926714.1  132.500000
# 8680         iYL1228  WP_015924795.1  119.800000
# 9773         iYL1228  WP_015924526.1  248.800000
# 10580         iNF517  WP_015924405.1  145.600000
# 13243        iJN1463  WP_015924622.1   80.900000
# 13290        iJN1463  WP_015925543.1  121.300000
# 13865        iJN1463  WP_015924622.1  177.600000
# 13866        iJN1463  WP_015924622.1  177.600000
# 14713        iJN1463  WP_015924088.1   48.525000
# 15214        iJN1463  WP_015925223.1  104.000000
# 15215        iJN1463  WP_015925223.1  104.000000
# 15216        iJN1463  WP_015925223.1  104.000000
# 16091        iEK1008  WP_015925343.1  111.300000
# 16573        iEK1008  WP_015924498.1   74.400000
# 16727        iEK1008  WP_015926061.1  146.000000
# 17826      iSDY_1059  WP_015924526.1  248.400000
# 20570       iSF_1195  WP_015924526.1  252.300000
# 22353      iSynCJ816  WP_015926349.1   33.600000
# 24048     iSSON_1240  WP_015924526.1  248.800000
# 24608     iSSON_1240  WP_015924795.1  109.000000
# 26883       STM_v1_0  WP_015925101.1   64.966667
# 26884       STM_v1_0  WP_015925101.1   64.966667
# 26885       STM_v1_0  WP_015925101.1   64.966667
# 27442       STM_v1_0  WP_015924795.1  114.000000
# 27631       STM_v1_0  WP_015924526.1  266.900000
# 29107  iSbBS512_1146  WP_015924526.1  251.900000
# 30361  iSbBS512_1146  WP_015924795.1  109.000000
# 31890         iYS854  WP_015925722.1  273.500000
# 32131         iYS854  WP_015925219.1  149.800000
# 36602        iML1515  WP_015924526.1  253.100000
# 37197        iML1515  WP_015924795.1  109.000000
# 37339        iML1515  WP_015925223.1  104.800000
# 37340        iML1515  WP_015925223.1  104.800000
# 37341        iML1515  WP_015925223.1  104.800000
